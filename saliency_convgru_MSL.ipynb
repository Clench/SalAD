# %%
from ast import literal_eval
from csv import reader
from os import listdir, makedirs, path
from pickle import dump
import pickle
import numpy as np
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from model import Seq2Seq, RecurrentAutoencoder, DNNAE, SalTransformer, SalAE, SalSCINet, SalGATSCINet, SalGATSCINetV2, SalGATConvLSTM, SalGATConvGRU, ConvGRU, SalGATConvGRUwoSal, SalConvGRUwoALL, SalGATConvGRUwoGAT


import os, random
import torch
from torch.nn import TransformerAE
from torch.utils.data import DataLoader, Dataset, SubsetRandomSampler
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

random_seed = 42
torch.manual_seed(random_seed)
torch.cuda.manual_seed(random_seed)
torch.cuda.manual_seed_all(random_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
np.random.seed(random_seed)
random.seed(random_seed)
# from args import get_parser


def load_and_save(category, filename, dataset, dataset_folder, output_folder):
    temp = np.genfromtxt(
        path.join(dataset_folder, category, filename),
        dtype=np.float32,
        delimiter=",",
    )
    print(dataset, category, filename, temp.shape)
    with open(path.join(output_folder, dataset + "_" + category + ".pkl"), "wb") as file:
        dump(temp, file)


def load_data(dataset):
    """ Method from OmniAnomaly (https://github.com/NetManAIOps/OmniAnomaly) """

    if dataset == "SMD":
        dataset_folder = "/home/sangyup/saliency_anomaly_detection/dataset/ServerMachineDataset"
        output_folder = "/home/sangyup/saliency_anomaly_detection/dataset/ServerMachineDataset/processed"
        makedirs(output_folder, exist_ok=True)
        file_list = listdir(path.join(dataset_folder, "train"))
        for filename in file_list:
            if filename.endswith(".txt"):
                load_and_save(
                    "train",
                    filename,
                    filename.strip(".txt"),
                    dataset_folder,
                    output_folder,
                )
                load_and_save(
                    "test_label",
                    filename,
                    filename.strip(".txt"),
                    dataset_folder,
                    output_folder,
                )
                load_and_save(
                    "test",
                    filename,
                    filename.strip(".txt"),
                    dataset_folder,
                    output_folder,
                )

    elif dataset == "SMAP" or dataset == "MSL":
        dataset_folder = "/home/sangyup/saliency_anomaly_detection/dataset/SMAPMSL/data"
        output_folder = "/home/sangyup/saliency_anomaly_detection/dataset/SMAPMSL/data/processed"
        makedirs(output_folder, exist_ok=True)
        with open(path.join(dataset_folder, "labeled_anomalies.csv"), "r") as file:
            csv_reader = reader(file, delimiter=",")
            res = [row for row in csv_reader][1:]
        res = sorted(res, key=lambda k: k[0])
        data_info = [row for row in res if row[1] == dataset and row[0] != "P-2"]
        labels = []
        for row in data_info:
            anomalies = literal_eval(row[2])
            length = int(row[-1])
            label = np.zeros([length], dtype=np.bool_)
            for anomaly in anomalies:
                label[anomaly[0] : anomaly[1] + 1] = True
            labels.extend(label)

        labels = np.asarray(labels)
        print(dataset, "test_label", labels.shape)

        with open(path.join(output_folder, dataset + "_" + "test_label" + ".pkl"), "wb") as file:
            dump(labels, file)

        def concatenate_and_save(category):
            data = []
            for row in data_info:
                filename = row[0]
                temp = np.load(path.join(dataset_folder, category, filename + ".npy"))
                data.extend(temp)
            data = np.asarray(data)
            print(dataset, category, data.shape)
            with open(path.join(output_folder, dataset + "_" + category + ".pkl"), "wb") as file:
                dump(data, file)

        for c in ["train", "test"]:
            concatenate_and_save(c)

def normalize_data(data, scaler=None):
    data = np.asarray(data, dtype=np.float32)
    if np.any(sum(np.isnan(data))):
        data = np.nan_to_num(data)

    if scaler is None:
        scaler = MinMaxScaler()
        scaler.fit(data)
    data = scaler.transform(data)
    print("Data normalized")

    return data, scaler

def get_data_dim(dataset):
    """
    :param dataset: Name of dataset
    :return: Number of dimensions in data
    """
    if dataset == "SMAP":
        return 25
    elif dataset == "MSL":
        return 55
    elif str(dataset).startswith("machine"):
        return 38
    else:
        raise ValueError("unknown dataset " + str(dataset))

        
def get_data(dataset, max_train_size=None, max_test_size=None,
             normalize=False, spec_res=False, train_start=0, test_start=0):
    """
    Get data from pkl files

    return shape: (([train_size, x_dim], [train_size] or None), ([test_size, x_dim], [test_size]))
    Method from OmniAnomaly (https://github.com/NetManAIOps/OmniAnomaly)
    """
    prefix = "/home/sangyup/saliency_anomaly_detection/dataset"
    if str(dataset).startswith("machine"):
        prefix += "/ServerMachineDataset/processed"
    elif dataset in ["MSL", "SMAP"]:
        prefix += "/SMAPMSL/data/processed"
    if max_train_size is None:
        train_end = None
    else:
        train_end = train_start + max_train_size
    if max_test_size is None:
        test_end = None
    else:
        test_end = test_start + max_test_size
    print("load data of:", dataset)
    print("train: ", train_start, train_end)
    print("test: ", test_start, test_end)
    x_dim = get_data_dim(dataset)
    f = open(os.path.join(prefix, dataset + "_train.pkl"), "rb")
    train_data = pickle.load(f).reshape((-1, x_dim))[train_start:train_end, :]
    f.close()
    try:
        f = open(os.path.join(prefix, dataset + "_test.pkl"), "rb")
        test_data = pickle.load(f).reshape((-1, x_dim))[test_start:test_end, :]
        f.close()
    except (KeyError, FileNotFoundError):
        test_data = None
    try:
        f = open(os.path.join(prefix, dataset + "_test_label.pkl"), "rb")
        test_label = pickle.load(f).reshape((-1))[test_start:test_end]
        f.close()
    except (KeyError, FileNotFoundError):
        test_label = None

    if normalize:
        train_data, scaler = normalize_data(train_data, scaler=None)
        test_data, _ = normalize_data(test_data, scaler=scaler)

    print("train set shape: ", train_data.shape)
    print("test set shape: ", test_data.shape)
    print("test set label shape: ", None if test_label is None else test_label.shape)
    return (train_data, None), (test_data, test_label)

# %%
ds = 'MSL'
load_data(ds.upper())
# Out:
# MSL test_label (73729,)
# MSL train (58317, 55)
# MSL test (73729, 55)

# %%
# (x_train, _), (x_test, y_test) = get_data('machine-1-3', normalize=True)
(x_train, _), (x_test, y_test) = get_data('MSL', normalize=True)
# Out:
# load data of: MSL
# train:  0 None
# test:  0 None
# Data normalized
# Data normalized
# train set shape:  (58317, 55)
# test set shape:  (73729, 55)
# test set label shape:  (73729,)

# %%
def split_series(series, n_past, n_future):
    '''

    :param series: input time series
    :param n_past: number of past observations
    :param n_future: number of future series
    :return: X, y(label)
    '''
    X, y = list(), list()
    for window_start in range(len(series)):
        past_end = window_start + n_past
        future_end = past_end + n_future
        if future_end > len(series):
            break
        # slicing the past and future parts of the window
        past, future = series[window_start:past_end, :], series[past_end:future_end, :]
        X.append(past)
        y.append(future)

    return X, y

x_test_windowed, _ = split_series(x_test, 100, 1)
np.array(x_test_windowed).shape
# Out:
# (73629, 100, 55)

# %%
from torch.utils.data import Dataset, DataLoader
class ReconDataset(Dataset):
    def __init__(self, data, window, target_cols):
        self.data = torch.Tensor(data)
        self.window = window
        self.target_cols = target_cols
        self.shape = self.__getshape__()
        self.size = self.__getsize__()

    def __getitem__(self, index):
        x = self.data[index:index+self.window]
        y = self.data[index:index+self.window]
        return x, y

    def __len__(self):
        return len(self.data) -  self.window 
    
    def __getshape__(self):
        return (self.__len__(), *self.__getitem__(0)[0].shape)

    def __getsize__(self):
        return (self.__len__())

class ForecastDataset(Dataset):
    def __init__(self, data, window, target_cols):
        self.data = torch.Tensor(data)
        self.window = window
        self.target_cols = target_cols
        self.shape = self.__getshape__()
        self.size = self.__getsize__()

    def __getitem__(self, index):
        x = self.data[index:index+self.window]
        y = self.data[index+self.window,0:self.target_cols]
        return x, y

    def __len__(self):
        return len(self.data) -  self.window 
    
    def __getshape__(self):
        return (self.__len__(), *self.__getitem__(0)[0].shape)
    
    def __getsize__(self):
        return (self.__len__())

class ReconForecastDataset(Dataset):
    def __init__(self, data, window, horizon):
        self.data = torch.Tensor(data)
        self.window = window
        self.horizon = horizon
        self.shape = self.__getshape__()
        self.size = self.__getsize__()

    def __getitem__(self, index):
        x = self.data[index:index+self.window]
        y_recon = self.data[index:index+self.window]
        y_fore = self.data[index+self.window:index+self.window+self.horizon]
        return x, y_recon, y_fore

    def __len__(self):
        return len(self.data) -  self.window 
    
    def __getshape__(self):
        return (self.__len__(), *self.__getitem__(0)[0].shape), (self.__len__(), *self.__getitem__(0)[1].shape), (self.__len__(), *self.__getitem__(0)[2].shape)
    
    def __getsize__(self):
        return (self.__len__())


def create_data_loaders(train_dataset, batch_size, val_split=0.1, shuffle=False, test_dataset=None):
    train_loader, val_loader, test_loader = None, None, None
    if val_split == 0.0:
        print(f"train_size: {len(train_dataset)}")
        train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=shuffle, drop_last=True)

    else:
        dataset_size = len(train_dataset)
        indices = list(range(dataset_size))
        split = int(np.floor(val_split * dataset_size))
        if shuffle:
            np.random.shuffle(indices)
        train_indices, val_indices = indices[split:], indices[:split]

        train_sampler = SubsetRandomSampler(train_indices)
        valid_sampler = SubsetRandomSampler(val_indices)

        train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=shuffle, sampler=train_sampler, drop_last=True)
        val_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=shuffle, sampler=valid_sampler, drop_last=True)

        print(f"train_size: {len(train_indices)}")
        print(f"validation_size: {len(val_indices)}")

    if test_dataset is not None:
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=True)
        print(f"test_size: {len(test_dataset)}")

    return train_loader, val_loader, test_loader


# From Informer

class StandardScaler():
    def __init__(self):
        self.mean = 0.
        self.std = 1.
    
    def fit(self, data):
        self.mean = data.mean(0)
        self.std = data.std(0)

    def transform(self, data):
        mean = torch.from_numpy(self.mean).type_as(data).to(data.device) if torch.is_tensor(data) else self.mean
        std = torch.from_numpy(self.std).type_as(data).to(data.device) if torch.is_tensor(data) else self.std
        return (data - mean) / std

    def inverse_transform(self, data):
        mean = torch.from_numpy(self.mean).type_as(data).to(data.device) if torch.is_tensor(data) else self.mean
        std = torch.from_numpy(self.std).type_as(data).to(data.device) if torch.is_tensor(data) else self.std
        return (data * std) + mean

# 시간 특징을 freq에 따라 추출
def time_features(dates, freq='h'):
    dates['month'] = dates.date.apply(lambda row:row.month,1)
    dates['day'] = dates.date.apply(lambda row:row.day,1)
    dates['weekday'] = dates.date.apply(lambda row:row.weekday(),1)
    dates['hour'] = dates.date.apply(lambda row:row.hour,1)
    dates['minute'] = dates.date.apply(lambda row:row.minute,1)
    dates['minute'] = dates.minute.map(lambda x:x//15)
    freq_map = {
        'y':[],'m':['month'],'w':['month'],'d':['month','day','weekday'],
        'b':['month','day','weekday'],'h':['month','day','weekday','hour'],
        't':['month','day','weekday','hour','minute'],
    }
    return dates[freq_map[freq.lower()]].values

# 한번의 batch를 실행하는 코드
def _process_one_batch(batch_x, batch_y, batch_x_mark, batch_y_mark):
    batch_x = batch_x.float().to(device)
    batch_y = batch_y.float()
    batch_x_mark = batch_x_mark.float().to(device)
    batch_y_mark = batch_y_mark.float().to(device)
    dec_inp = torch.zeros([batch_y.shape[0], pred_len, batch_y.shape[-1]]).float()
    dec_inp = torch.cat([batch_y[:,:label_len,:], dec_inp], dim=1).float().to(device)
    outputs = model(batch_x, batch_x_mark, dec_inp, batch_y_mark)
    batch_y = batch_y[:,-pred_len:,0:].to(device)
    return outputs, batch_y


class Dataset_Pred(Dataset):
    def __init__(self, dataframe, size=None, scale=True):
        self.seq_len = size[0]
        self.label_len = size[1]
        self.pred_len = size[2]
        self.dataframe = dataframe
        
        self.scale = scale
        self.__read_data__()

    def __read_data__(self):
        self.scaler = StandardScaler()
        df_raw = self.dataframe
        df_raw["date"] = pd.to_datetime(df_raw["date"])

        delta = df_raw["date"].iloc[1] - df_raw["date"].iloc[0]
        if delta>=timedelta(hours=1):
            self.freq='h'
        else:
            self.freq='t'

        border1 = 0
        border2 = len(df_raw)
        cols_data = df_raw.columns[1:]
        df_data = df_raw[cols_data]


        if self.scale:
            self.scaler.fit(df_data.values)
            data = self.scaler.transform(df_data.values)
        else:
            data = df_data.values
            
        tmp_stamp = df_raw[['date']][border1:border2]
        tmp_stamp['date'] = pd.to_datetime(tmp_stamp.date)
        pred_dates = pd.date_range(tmp_stamp.date.values[-1], periods=self.pred_len+1, freq=self.freq)
        
        df_stamp = pd.DataFrame(columns = ['date'])
        df_stamp.date = list(tmp_stamp.date.values) + list(pred_dates[1:])
        data_stamp = time_features(df_stamp, freq=self.freq)

        self.data_x = data[border1:border2]
        self.data_y = data[border1:border2]
        self.data_stamp = data_stamp
    
    def __getitem__(self, index):
        s_begin = index
        s_end = s_begin + self.seq_len
        r_begin = s_end - self.label_len
        r_end = r_begin + self.label_len + self.pred_len

        seq_x = self.data_x[s_begin:s_end]
        seq_y = self.data_y[r_begin:r_end]
        seq_x_mark = self.data_stamp[s_begin:s_end]
        seq_y_mark = self.data_stamp[r_begin:r_end]
        return seq_x, seq_y, seq_x_mark, seq_y_mark

    def __len__(self):
        return len(self.data_x) - self.seq_len- self.pred_len + 1

# %%
window_size = 100
batch_size = 512

train_dataset = ReconDataset(x_train, window_size, 1)
test_dataset = ReconDataset(x_test, window_size, 1)
train_loader, val_loader, test_loader = create_data_loaders(train_dataset, batch_size, val_split=0.0, shuffle=True, test_dataset=test_dataset)
# Out:
# train_size: 58217
# test_size: 73629

# %%
indices = torch.arange(len(train_dataset)-horizon)
temp = torch.utils.data.Subset(train_dataset, indices)
print(len(train_dataset))
print(len(temp))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_41473/2309456973.py in <module>
# ----> 1 indices = torch.arange(len(train_dataset)-horizon)
#       2 temp = torch.utils.data.Subset(train_dataset, indices)
#       3 print(len(train_dataset))
#       4 print(len(temp))
#
# NameError: name 'horizon' is not defined

# %%
window_size = 100
batch_size = 512
horizon = 10




train_dataset = ReconForecastDataset(x_train, window_size, horizon)
indices = torch.arange(len(train_dataset)-horizon)
train_dataset = torch.utils.data.Subset(train_dataset, indices)
test_dataset = ReconForecastDataset(x_test, window_size, horizon)

# val_split = 0.3
# split = int(np.floor(val_split * len(train_dataset)))
# train_dataset, val_dataset = torch.utils.data.random_split(train_dataset, [len(train_dataset) - split, split])


# print(len(train_dataset))
# print(len(val_dataset))
# print(len(test_dataset))

# train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=False, drop_last=True)
# val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=True)
# test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=True)

train_loader, val_loader, test_loader = create_data_loaders(train_dataset, batch_size, val_split=0.3, shuffle=False, test_dataset=test_dataset)
# Out:
# train_size: 40745
# validation_size: 17462
# test_size: 73629

# %%
from time import time

def train(dataloader, model, batch_size, n_epochs):
    # dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    optimizer = torch.optim.AdamW(model.parameters())
    loss_fn = torch.nn.MSELoss()
    epochs = range(n_epochs)
    best = {"loss": sys.float_info.max}
    loss_history = []
    for e in epochs:
        epoch_loss = 0
        for i, (x,y) in enumerate(dataloader):  
            optimizer.zero_grad()
            x = x.cuda()
            # guess = model(given,given)  # Transformer
            enc_output, guess = model(x)  # AE
            y = y.cuda()
            loss = loss_fn(y, guess)
            loss.backward()
            epoch_loss += loss.item()
            optimizer.step()
        loss_history.append(epoch_loss)
#         epochs.set_postfix_str(f"loss: {epoch_loss:.6f}")
        
        print(f'Training loss EPOCH: [{e+1}|{len(epochs)}], training loss: [{epoch_loss}]')
        if epoch_loss < best["loss"]:
            best["state"] = model.state_dict()
            best["loss"] = epoch_loss
            best["epoch"] = e + 1
    return best, loss_history


def train_DNN(dataloader, model, batch_size, n_epochs):
    # dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    optimizer = torch.optim.AdamW(model.parameters())
    loss_fn = torch.nn.MSELoss()
    epochs = range(n_epochs)
    best = {"loss": sys.float_info.max}
    loss_history = []
    for e in epochs:
        epoch_loss = 0
        for i, (x,y) in enumerate(dataloader):  
            optimizer.zero_grad()
            x = x.reshape(x.shape[0], x.shape[1]*x.shape[2]).cuda()
            # guess = model(given,given)  # Transformer
            enc_output, guess = model(x)  # AE
            y = y.reshape(y.shape[0], y.shape[1]*y.shape[2]).cuda()
            loss = loss_fn(y, guess)
            loss.backward()
            epoch_loss += loss.item()
            optimizer.step()
        loss_history.append(epoch_loss)
#         epochs.set_postfix_str(f"loss: {epoch_loss:.6f}")
        
        print(f'Training loss EPOCH: [{e+1}|{len(epochs)}], training loss: [{epoch_loss}]')
        if epoch_loss < best["loss"]:
            best["state"] = model.state_dict()
            best["loss"] = epoch_loss
            best["epoch"] = e + 1
    return best, loss_history


def train_transformer(dataloader, model, batch_size, n_epochs):
    optimizer = torch.optim.AdamW(model.parameters())
    
    loss_fn_AE = torch.nn.MSELoss()
    loss_fn_transformer = torch.nn.MSELoss()

    epochs = range(n_epochs)
    best = {"loss": sys.float_info.max}
    loss_history, loss_history_AE, loss_history_TF = [], [], []
    for e in epochs:
        start = time()
        epoch_loss = 0
        epoch_loss_AE = 0
        epoch_loss_transformer = 0
        for i, (x,y) in enumerate(dataloader):  
            optimizer.zero_grad()
            x = x.cuda()
            sal, dec_x, out = model(x)
            y = y.cuda()
            loss_AE = loss_fn_AE(y, dec_x)
            loss_transformer = loss_fn_transformer(y, out)
            loss = loss_AE + loss_transformer
            loss.backward()
            epoch_loss += loss.item()
            epoch_loss_AE += loss_AE.item()
            epoch_loss_transformer += loss_transformer.item()
            optimizer.step()
        loss_history.append(epoch_loss)
        loss_history_AE.append(epoch_loss_AE)
        loss_history_TF.append(epoch_loss_transformer)

#         epochs.set_postfix_str(f"loss: {epoch_loss:.6f}")
        
        print(f'Training loss EPOCH: [{e+1}|{len(epochs)}], training loss: [{epoch_loss}], AE loss: [{epoch_loss_AE}], TF loss: [{epoch_loss_transformer}] took', time()-start)
        if epoch_loss < best["loss"]:
            best["state"] = model.state_dict()
            best["loss"] = epoch_loss
            best["loss_AE"] = epoch_loss_AE
            best["loss_TF"] = epoch_loss_transformer
            best["epoch"] = e + 1
    return best, loss_history, loss_history_AE, loss_history_TF


def train_SCI(dataloader, model, batch_size, n_epochs):
    optimizer = torch.optim.AdamW(model.parameters())
    
    loss_fn_AE = torch.nn.MSELoss()
    loss_fn_sci = torch.nn.MSELoss()

    epochs = range(n_epochs)
    best = {"loss": sys.float_info.max}
    loss_history, loss_history_AE, loss_history_TF = [], [], []
    for e in epochs:
        start = time()
        epoch_loss = 0
        epoch_loss_AE = 0
        epoch_loss_sci = 0
        for i, (x,y_recon,y_fore) in enumerate(dataloader):  
            optimizer.zero_grad()
            x = x.cuda()
            y_recon = y_recon.cuda()
            y_fore = y_fore.cuda()
            sal, dec_x, out = model(x)
            
            loss_AE = loss_fn_AE(y_recon, dec_x)
            loss_sci = loss_fn_sci(y_fore, out)
            loss = loss_AE + loss_sci
            loss.backward()
            epoch_loss += loss.item()
            epoch_loss_AE += loss_AE.item()
            epoch_loss_sci += loss_sci.item()
            optimizer.step()
        loss_history.append(epoch_loss)
        loss_history_AE.append(epoch_loss_AE)
        loss_history_TF.append(epoch_loss_sci)

#         epochs.set_postfix_str(f"loss: {epoch_loss:.6f}")
        
        print(f'Training loss EPOCH: [{e+1}|{len(epochs)}], training loss: [{epoch_loss}], AE loss: [{epoch_loss_AE}], TF loss: [{epoch_loss_sci}] took', time()-start)
        if epoch_loss < best["loss"]:
            best["state"] = model.state_dict()
            best["loss"] = epoch_loss
            best["loss_AE"] = epoch_loss_AE
            best["loss_TF"] = epoch_loss_sci
            best["epoch"] = e + 1
    return best, loss_history, loss_history_AE, loss_history_TF
 

def train_model(dataloader, val_loader, model, batch_size, n_epochs, model_name):
    optimizer = torch.optim.AdamW(model.parameters())
    
    loss_fn_AE = torch.nn.MSELoss()
    loss_fn_sci = torch.nn.MSELoss()

    epochs = range(n_epochs)
    best = {"loss": sys.float_info.max}
    loss_history, loss_history_AE, loss_history_TF = [], [], []
    val_loss_history, val_loss_history_AE, val_loss_history_TF = [], [], []
    for e in epochs:
        model.train()
        start = time()
        epoch_loss = 0
        epoch_loss_AE = 0
        epoch_loss_sci = 0
        for i, (x,y_recon,y_fore) in enumerate(dataloader):  
            optimizer.zero_grad()
            x = x.cuda()
            y_recon = y_recon.cuda()
            y_fore = y_fore.cuda()
            sal, dec_x, out = model(x)
            
            loss_AE = loss_fn_AE(y_recon, dec_x)
            loss_sci = loss_fn_sci(y_fore, out)
            loss = loss_AE + loss_sci
            loss.backward()
            epoch_loss += loss.item()
            epoch_loss_AE += loss_AE.item()
            epoch_loss_sci += loss_sci.item()
            optimizer.step()
        loss_history.append(epoch_loss)
        loss_history_AE.append(epoch_loss_AE)
        loss_history_TF.append(epoch_loss_sci)

#         epochs.set_postfix_str(f"loss: {epoch_loss:.6f}")
        
        # Validation step
        model.eval()
        val_epoch_loss = 0
        val_epoch_loss_AE = 0
        val_epoch_loss_sci = 0
        with torch.no_grad():
            for i, (x,y_recon,y_fore) in enumerate(val_loader):  
                x = x.cuda()
                y_recon = y_recon.cuda()
                y_fore = y_fore.cuda()
                sal, dec_x, out = model(x)

                valloss_AE = loss_fn_AE(y_recon, dec_x)
                valloss_sci = loss_fn_sci(y_fore, out)
                valloss = valloss_AE + valloss_sci
                
                val_epoch_loss += valloss.item()
                val_epoch_loss_AE += valloss_AE.item()
                val_epoch_loss_sci += valloss_sci.item()
                
                val_loss_history.append(val_epoch_loss)
                val_loss_history_AE.append(val_epoch_loss_AE)
                val_loss_history_TF.append(val_epoch_loss_sci)  

        print(f'Training loss EPOCH: [{e+1}|{len(epochs)}], training loss: [{epoch_loss}], AE loss: [{epoch_loss_AE}], TF loss: [{epoch_loss_sci}] took', time()-start)
        print(f'Validation loss EPOCH: [{e+1}|{len(epochs)}], validation loss: [{val_epoch_loss}], AE loss: [{val_epoch_loss_AE}], TF loss: [{val_epoch_loss_sci}]')
        if val_epoch_loss < best["loss"]:
            best["state"] = model.state_dict()
            best["loss"] = val_epoch_loss
            best["loss_AE"] = val_epoch_loss_AE
            best["loss_TF"] = val_epoch_loss_sci
            best["epoch"] = e + 1
            with open("result/model_" + model_name + "_best.pt", "wb") as f:
                torch.save(
                    {
                        "state": best["state"],
                        "best_epoch": best["epoch"],
                        "loss_history": val_loss_history,
                        "loss_AE_history": val_loss_history_AE,
                        "loss_TF_history": val_loss_history_TF,
                    },
                    f,
                )

    # Save last epoch
    with open("result/model_" + model_name + "_last.pt", "wb") as f:
        torch.save(
            {
                "state": model.state_dict(),
                "best_epoch": e + 1,
                "loss_history": val_loss_history,
                "loss_AE_history": val_loss_history_AE,
                "loss_TF_history": val_loss_history_TF,
            },
            f,
        )

    return best, loss_history, loss_history_AE, loss_history_TF

# %%
# MODEL = RecurrentAutoencoder(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2))
# MODEL = SalTransformer(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, n_head=5, cell='lstm')
# MODEL = SalAE(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
# MODEL = SalSCINet(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')

# MODEL = SalGATSCINet(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
# MODEL = SalGATSCINetV2(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
# MODEL = SalGATConvLSTM(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
# MODEL = SalGATConvGRU(seq_len=window_size, output_len=10, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
# MODEL = SalGATConvGRUwoSal(seq_len=window_size, output_len=10, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
MODEL = SalConvGRUwoALL(seq_len=window_size, output_len=10, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
MODEL.cuda()
MODEL.train()
# Out:
# SalConvGRUwoALL(
#   (encoder): RecurEncoder(
#     (rnn1): GRU(55, 54, batch_first=True)
#     (rnn2): GRU(54, 27, batch_first=True)
#   )
#   (decoder): RecurDecoder(
#     (rnn1): GRU(27, 27, batch_first=True)
#     (rnn2): GRU(27, 54, batch_first=True)
#     (output_layer): Linear(in_features=54, out_features=55, bias=True)
#     (timedist): TimeDistributed(
#       (module): Linear(in_features=54, out_features=55, bias=True)
#     )
#   )
#   (feature_gat): FeatureAttentionLayer(
#     (lin): Linear(in_features=100, out_features=100, bias=True)
#     (leakyrelu): LeakyReLU(negative_slope=0.2)
#     (sigmoid): Sigmoid()
#   )
#   (temporal_gat): TemporalAttentionLayer(
#     (lin): Linear(in_features=55, out_features=55, bias=True)
#     (leakyrelu): LeakyReLU(negative_slope=0.2)
#     (sigmoid): Sigmoid()
#   )
#   (convGRU): ConvGRU(
#     (cell_list): ModuleList(
#       (0): ConvGRUCell(
#         (conv_gates): Conv2d(87, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv_can): Conv2d(87, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): ConvGRUCell(
#         (conv_gates): Conv2d(96, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (conv_can): Conv2d(96, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   (linear): Linear(in_features=64, out_features=55, bias=True)
# )

# %%
model_name = 'SalGATConvGRUwoAll_saliency_MSL'
BEST_MODEL, LOSS_HISTORY, LOSS_HISTORY_AE, LOSS_HISTORY_TF = train_model(train_loader, val_loader, MODEL, batch_size, 1000, model_name)
# with open("result/model_SalGATConvGRU_saliency_MSL.pt", "wb") as f:
#     torch.save(
#         {
#             "state": BEST_MODEL["state"],
#             "best_epoch": BEST_MODEL["epoch"],
#             "loss_history": LOSS_HISTORY,
#             "loss_AE_history": LOSS_HISTORY_AE,
#             "loss_TF_history": LOSS_HISTORY_TF,
#         },
#         f,
#     )
# Out:
# Training loss EPOCH: [1|1000], training loss: [0.8351437486708164], AE loss: [0.4062061086297035], TF loss: [0.42893764143809676] took 9.77617073059082
# Validation loss EPOCH: [1|1000], validation loss: [0.33475812152028084], AE loss: [0.16696897009387612], TF loss: [0.167789151892066]
# Training loss EPOCH: [2|1000], training loss: [0.6546003115363419], AE loss: [0.3240144355222583], TF loss: [0.33058587717823684] took 9.586318969726562
# Validation loss EPOCH: [2|1000], validation loss: [0.3115943782031536], AE loss: [0.1542913462035358], TF loss: [0.15730303199961782]
# Training loss EPOCH: [3|1000], training loss: [0.635971758980304], AE loss: [0.31510387430898845], TF loss: [0.3208678839728236] took 9.682246685028076
# Validation loss EPOCH: [3|1000], validation loss: [0.2977301552891731], AE loss: [0.1492515429854393], TF loss: [0.14847861416637897]
# Training loss EPOCH: [4|1000], training loss: [0.6292705605737865], AE loss: [0.3122178551275283], TF loss: [0.3170527059119195] took 8.986626625061035
# Validation loss EPOCH: [4|1000], validation loss: [0.28632965171709657], AE loss: [0.14342643599957228], TF loss: [0.1429032157175243]
# Training loss EPOCH: [5|1000], training loss: [0.6241303011775017], AE loss: [0.31015755888074636], TF loss: [0.3139727453235537] took 9.348122119903564
# Validation loss EPOCH: [5|1000], validation loss: [0.28005252964794636], AE loss: [0.13922699494287372], TF loss: [0.140825534472242]
# Training loss EPOCH: [6|1000], training loss: [0.6194960419088602], AE loss: [0.30872484226711094], TF loss: [0.31077120266854763] took 9.000938177108765
# Validation loss EPOCH: [6|1000], validation loss: [0.277893609367311], AE loss: [0.13816661410965025], TF loss: [0.13972699455916882]
# Training loss EPOCH: [7|1000], training loss: [0.6163503373973072], AE loss: [0.3080669045448303], TF loss: [0.3082834321539849] took 9.538730144500732
# Validation loss EPOCH: [7|1000], validation loss: [0.27705089561641216], AE loss: [0.13780994550324976], TF loss: [0.1392409480176866]
# Training loss EPOCH: [8|1000], training loss: [0.6139257270842791], AE loss: [0.3077822995837778], TF loss: [0.3061434286646545] took 10.205691576004028
# Validation loss EPOCH: [8|1000], validation loss: [0.2764178579673171], AE loss: [0.13751437002792954], TF loss: [0.13890348630957305]
# Training loss EPOCH: [9|1000], training loss: [0.6115551963448524], AE loss: [0.30744841881096363], TF loss: [0.3041067759040743] took 9.621559143066406
# Validation loss EPOCH: [9|1000], validation loss: [0.27624251460656524], AE loss: [0.1373459321912378], TF loss: [0.1388965817168355]
# Training loss EPOCH: [10|1000], training loss: [0.6101630302146077], AE loss: [0.30740966508165], TF loss: [0.3027533639688045] took 11.467192649841309
# Validation loss EPOCH: [10|1000], validation loss: [0.2760308547876775], AE loss: [0.13728455873206258], TF loss: [0.1387462974525988]
# Training loss EPOCH: [11|1000], training loss: [0.608187307137996], AE loss: [0.3070828823838383], TF loss: [0.30110442684963346] took 9.567961931228638
# Validation loss EPOCH: [11|1000], validation loss: [0.27595645980909467], AE loss: [0.13709120033308864], TF loss: [0.13886525970883667]
# Training loss EPOCH: [12|1000], training loss: [0.6068200166337192], AE loss: [0.3070243245456368], TF loss: [0.2997956923209131] took 11.55317497253418
# Validation loss EPOCH: [12|1000], validation loss: [0.27567105926573277], AE loss: [0.1368585559539497], TF loss: [0.13881250470876694]
# Training loss EPOCH: [13|1000], training loss: [0.6057501868344843], AE loss: [0.30697326152585447], TF loss: [0.29877692623995245] took 9.665128946304321
# Validation loss EPOCH: [13|1000], validation loss: [0.2755118487402797], AE loss: [0.13671426521614194], TF loss: [0.13879758212715387]
# Training loss EPOCH: [14|1000], training loss: [0.604898929130286], AE loss: [0.3069732484873384], TF loss: [0.29792567784897983] took 17.652838706970215
# Validation loss EPOCH: [14|1000], validation loss: [0.2754008583724499], AE loss: [0.1366638164035976], TF loss: [0.13873704127036035]
# Training loss EPOCH: [15|1000], training loss: [0.6032721162773669], AE loss: [0.3067884617485106], TF loss: [0.2964836545288563] took 23.84848666191101
# Validation loss EPOCH: [15|1000], validation loss: [0.27590835001319647], AE loss: [0.1366770318709314], TF loss: [0.13923131953924894]
# Training loss EPOCH: [16|1000], training loss: [0.6020808350294828], AE loss: [0.30671495478600264], TF loss: [0.2953658795449883] took 20.3430016040802
# Validation loss EPOCH: [16|1000], validation loss: [0.2753812721930444], AE loss: [0.136447140481323], TF loss: [0.13893413124606013]
# Training loss EPOCH: [17|1000], training loss: [0.6007030848413706], AE loss: [0.3066302319057286], TF loss: [0.2940728508401662] took 20.917885065078735
# Validation loss EPOCH: [17|1000], validation loss: [0.27546550100669265], AE loss: [0.13641389505937696], TF loss: [0.13905160734429955]
# Training loss EPOCH: [18|1000], training loss: [0.5997018669731915], AE loss: [0.3066318838391453], TF loss: [0.2930699842981994] took 23.985634803771973
# Validation loss EPOCH: [18|1000], validation loss: [0.275259533431381], AE loss: [0.13623137841932476], TF loss: [0.1390281547792256]
# Training loss EPOCH: [19|1000], training loss: [0.5986822852864861], AE loss: [0.30655829631723464], TF loss: [0.29212398803792894] took 23.648763179779053
# Validation loss EPOCH: [19|1000], validation loss: [0.27530408650636673], AE loss: [0.13626875216141343], TF loss: [0.13903533248230815]
# Training loss EPOCH: [20|1000], training loss: [0.5978482449427247], AE loss: [0.3066544975154102], TF loss: [0.2911937478929758] took 24.34563946723938
# Validation loss EPOCH: [20|1000], validation loss: [0.27539259381592274], AE loss: [0.1363166207447648], TF loss: [0.13907597260549664]
# Training loss EPOCH: [21|1000], training loss: [0.5971592986024916], AE loss: [0.30672581773251295], TF loss: [0.29043348133563995] took 30.609954118728638
# Validation loss EPOCH: [21|1000], validation loss: [0.2750992556102574], AE loss: [0.13613332505337894], TF loss: [0.13896592915989459]
# Training loss EPOCH: [22|1000], training loss: [0.5963715496473014], AE loss: [0.3064257053192705], TF loss: [0.28994584549218416] took 30.506108045578003
# Validation loss EPOCH: [22|1000], validation loss: [0.27535515930503607], AE loss: [0.13614977453835309], TF loss: [0.1392053854651749]
# Training loss EPOCH: [23|1000], training loss: [0.5954611171036959], AE loss: [0.3064274883363396], TF loss: [0.2890336306300014] took 29.741992712020874
# Validation loss EPOCH: [23|1000], validation loss: [0.2752767940983176], AE loss: [0.13601535162888467], TF loss: [0.13926144293509424]
# Training loss EPOCH: [24|1000], training loss: [0.5946506857872009], AE loss: [0.30634904582984746], TF loss: [0.288301641587168] took 32.73847198486328
# Validation loss EPOCH: [24|1000], validation loss: [0.27560423873364925], AE loss: [0.13606069865636528], TF loss: [0.1395435407757759]
# Training loss EPOCH: [25|1000], training loss: [0.5938385874032974], AE loss: [0.3062407716643065], TF loss: [0.2875978173688054] took 30.538737773895264
# Validation loss EPOCH: [25|1000], validation loss: [0.2758892076089978], AE loss: [0.13607948296703398], TF loss: [0.13980972720310092]
# Training loss EPOCH: [26|1000], training loss: [0.5938336537219584], AE loss: [0.30643153958953917], TF loss: [0.2874021145980805] took 28.370853900909424
# Validation loss EPOCH: [26|1000], validation loss: [0.275411712937057], AE loss: [0.13600481767207384], TF loss: [0.13940689503215253]
# Training loss EPOCH: [27|1000], training loss: [0.5930422353558242], AE loss: [0.3064530217088759], TF loss: [0.2865892122499645] took 29.89420795440674
# Validation loss EPOCH: [27|1000], validation loss: [0.27548602875322104], AE loss: [0.1358275911770761], TF loss: [0.13965843641199172]
# Training loss EPOCH: [28|1000], training loss: [0.5925720385275781], AE loss: [0.3064164612442255], TF loss: [0.28615557635203004] took 36.52826905250549
# Validation loss EPOCH: [28|1000], validation loss: [0.27576075680553913], AE loss: [0.13590283505618572], TF loss: [0.13985791755840182]
# Training loss EPOCH: [29|1000], training loss: [0.5921146334148943], AE loss: [0.30645102355629206], TF loss: [0.2856636110227555] took 42.83589291572571
# Validation loss EPOCH: [29|1000], validation loss: [0.27593483636155725], AE loss: [0.13593835174106061], TF loss: [0.13999648462049663]
# Training loss EPOCH: [30|1000], training loss: [0.5913564404472709], AE loss: [0.30635125283151865], TF loss: [0.2850051855202764] took 41.90253233909607
# Validation loss EPOCH: [30|1000], validation loss: [0.2759592882357538], AE loss: [0.1358737382106483], TF loss: [0.14008554932661355]
# Training loss EPOCH: [31|1000], training loss: [0.5907676052302122], AE loss: [0.30631261388771236], TF loss: [0.2844549920409918] took 44.58194851875305
# Validation loss EPOCH: [31|1000], validation loss: [0.275934305973351], AE loss: [0.13576072151772678], TF loss: [0.14017358515411615]
# Training loss EPOCH: [32|1000], training loss: [0.5904699568636715], AE loss: [0.30640978645533323], TF loss: [0.28406017180532217] took 41.4997775554657
# Validation loss EPOCH: [32|1000], validation loss: [0.2761322883889079], AE loss: [0.13574911397881806], TF loss: [0.14038317534141243]
# Training loss EPOCH: [33|1000], training loss: [0.5895685805007815], AE loss: [0.306171587202698], TF loss: [0.28339699376374483] took 42.91056489944458
# Validation loss EPOCH: [33|1000], validation loss: [0.27626542653888464], AE loss: [0.13573968294076622], TF loss: [0.14052574546076357]
# Training loss EPOCH: [34|1000], training loss: [0.5893128286115825], AE loss: [0.30643237358890474], TF loss: [0.28288045478984714] took 42.75218439102173
# Validation loss EPOCH: [34|1000], validation loss: [0.27639396116137505], AE loss: [0.135768071282655], TF loss: [0.1406258896458894]
# Training loss EPOCH: [35|1000], training loss: [0.5882757259532809], AE loss: [0.30624496401287615], TF loss: [0.2820307619404048] took 44.58726692199707
# Validation loss EPOCH: [35|1000], validation loss: [0.27661119494587183], AE loss: [0.13578153564594686], TF loss: [0.14082965860143304]
# Training loss EPOCH: [36|1000], training loss: [0.5882178856991231], AE loss: [0.30626291083171964], TF loss: [0.28195497393608093] took 42.269519090652466
# Validation loss EPOCH: [36|1000], validation loss: [0.27663359185680747], AE loss: [0.1356943417340517], TF loss: [0.14093925175257027]
# Training loss EPOCH: [37|1000], training loss: [0.5875008613802493], AE loss: [0.30632060253992677], TF loss: [0.2811802588403225] took 44.833313941955566
# Validation loss EPOCH: [37|1000], validation loss: [0.27689555613324046], AE loss: [0.1357009462080896], TF loss: [0.14119461178779602]
# Training loss EPOCH: [38|1000], training loss: [0.5867410944774747], AE loss: [0.3061501723714173], TF loss: [0.2805909216403961] took 42.11984729766846
# Validation loss EPOCH: [38|1000], validation loss: [0.27676461078226566], AE loss: [0.13557344488799572], TF loss: [0.1411911635659635]
# Training loss EPOCH: [39|1000], training loss: [0.5860224580392241], AE loss: [0.30614410410635173], TF loss: [0.2798783553298563] took 39.4372501373291
# Validation loss EPOCH: [39|1000], validation loss: [0.2771101435646415], AE loss: [0.13554943655617535], TF loss: [0.14156070863828063]
# Training loss EPOCH: [40|1000], training loss: [0.5854905522428453], AE loss: [0.3060972588136792], TF loss: [0.27939329319633543] took 40.989086866378784
# Validation loss EPOCH: [40|1000], validation loss: [0.27709290012717247], AE loss: [0.13556757918559015], TF loss: [0.14152532164007425]
# Training loss EPOCH: [41|1000], training loss: [0.5847501652315259], AE loss: [0.30606958735734224], TF loss: [0.27868057624436915] took 41.656564474105835
# Validation loss EPOCH: [41|1000], validation loss: [0.2770187486894429], AE loss: [0.13551570824347436], TF loss: [0.1415030409116298]
# Training loss EPOCH: [42|1000], training loss: [0.5848634764552116], AE loss: [0.30623085028491914], TF loss: [0.27863262640312314] took 40.26066875457764
# Validation loss EPOCH: [42|1000], validation loss: [0.27721769316121936], AE loss: [0.13542091753333807], TF loss: [0.1417967793531716]
# Training loss EPOCH: [43|1000], training loss: [0.5836969092488289], AE loss: [0.30605887877754867], TF loss: [0.277638032566756] took 38.7966685295105
# Validation loss EPOCH: [43|1000], validation loss: [0.27755984757095575], AE loss: [0.1354172369465232], TF loss: [0.14214261225424707]
# Training loss EPOCH: [44|1000], training loss: [0.5832827701233327], AE loss: [0.3061286478769034], TF loss: [0.27715412387624383] took 42.8451771736145
# Validation loss EPOCH: [44|1000], validation loss: [0.2775003146380186], AE loss: [0.13538007414899766], TF loss: [0.1421202407218516]
# Training loss EPOCH: [45|1000], training loss: [0.5826102602295578], AE loss: [0.306078159250319], TF loss: [0.2765321016777307] took 42.55974054336548
# Validation loss EPOCH: [45|1000], validation loss: [0.27797446912154555], AE loss: [0.1354425207246095], TF loss: [0.14253194769844413]
# Training loss EPOCH: [46|1000], training loss: [0.5819768579676747], AE loss: [0.3061239826492965], TF loss: [0.2758528769481927] took 40.556761741638184
# Validation loss EPOCH: [46|1000], validation loss: [0.27800733176991343], AE loss: [0.1354074717964977], TF loss: [0.14259986416436732]
# Training loss EPOCH: [47|1000], training loss: [0.5812169783748686], AE loss: [0.30594602646306157], TF loss: [0.27527095191180706] took 42.494405031204224
# Validation loss EPOCH: [47|1000], validation loss: [0.2784593845717609], AE loss: [0.13534749881364405], TF loss: [0.14311188529245555]
# Training loss EPOCH: [48|1000], training loss: [0.5811293153092265], AE loss: [0.3062445723917335], TF loss: [0.27488474175333977] took 40.204219341278076
# Validation loss EPOCH: [48|1000], validation loss: [0.2786067835986614], AE loss: [0.1354135274887085], TF loss: [0.14319325215183198]
# Training loss EPOCH: [49|1000], training loss: [0.5801484826952219], AE loss: [0.30604702117852867], TF loss: [0.2741014619823545] took 40.23355793952942
# Validation loss EPOCH: [49|1000], validation loss: [0.2786035481840372], AE loss: [0.13528491044417024], TF loss: [0.14331863867118955]
# Training loss EPOCH: [50|1000], training loss: [0.5798953846096992], AE loss: [0.3062185838352889], TF loss: [0.2736768026370555] took 43.814857006073
# Validation loss EPOCH: [50|1000], validation loss: [0.27859621914103627], AE loss: [0.13539628055877984], TF loss: [0.14319993508979678]
# Training loss EPOCH: [51|1000], training loss: [0.5787709848955274], AE loss: [0.30596760706976056], TF loss: [0.2728033773601055] took 43.156742334365845
# Validation loss EPOCH: [51|1000], validation loss: [0.2792179058305919], AE loss: [0.13541173026897013], TF loss: [0.143806176725775]
# Training loss EPOCH: [52|1000], training loss: [0.5783169325441122], AE loss: [0.3060657582245767], TF loss: [0.27225117292255163] took 41.23948383331299
# Validation loss EPOCH: [52|1000], validation loss: [0.27929823473095894], AE loss: [0.1353360505308956], TF loss: [0.1439621855970472]
# Training loss EPOCH: [53|1000], training loss: [0.577548642642796], AE loss: [0.30588291655294597], TF loss: [0.27166572539135814] took 43.02765250205994
# Validation loss EPOCH: [53|1000], validation loss: [0.27922759344801307], AE loss: [0.13527990970760584], TF loss: [0.14394768350757658]
# Training loss EPOCH: [54|1000], training loss: [0.5771930487826467], AE loss: [0.3060348548460752], TF loss: [0.27115819370374084] took 42.959754943847656
# Validation loss EPOCH: [54|1000], validation loss: [0.27931759785860777], AE loss: [0.13531856192275882], TF loss: [0.14399903477169573]
# Training loss EPOCH: [55|1000], training loss: [0.5766355521045625], AE loss: [0.306120831053704], TF loss: [0.27051472081802785] took 41.847283363342285
# Validation loss EPOCH: [55|1000], validation loss: [0.27997140353545547], AE loss: [0.13537626108154655], TF loss: [0.1445951471105218]
# Training loss EPOCH: [56|1000], training loss: [0.575843199621886], AE loss: [0.3060424558352679], TF loss: [0.26980074401944876] took 44.92909789085388
# Validation loss EPOCH: [56|1000], validation loss: [0.2800774900242686], AE loss: [0.13537763385102153], TF loss: [0.14469985710456967]
# Training loss EPOCH: [57|1000], training loss: [0.5749188866466284], AE loss: [0.30588599597103894], TF loss: [0.26903289183974266] took 40.857972383499146
# Validation loss EPOCH: [57|1000], validation loss: [0.28081584395840764], AE loss: [0.13535196520388126], TF loss: [0.14546387922018766]
# Training loss EPOCH: [58|1000], training loss: [0.57455979520455], AE loss: [0.3059733116533607], TF loss: [0.2685864814557135] took 42.29933714866638
# Validation loss EPOCH: [58|1000], validation loss: [0.2804561499506235], AE loss: [0.1352114798501134], TF loss: [0.14524467149749398]
# Training loss EPOCH: [59|1000], training loss: [0.5735907992348075], AE loss: [0.30589669616892934], TF loss: [0.2676941021345556] took 42.91078329086304
# Validation loss EPOCH: [59|1000], validation loss: [0.28057992504909635], AE loss: [0.1353238474112004], TF loss: [0.1452560795005411]
# Training loss EPOCH: [60|1000], training loss: [0.5734504046849906], AE loss: [0.30601777182891965], TF loss: [0.2674326319247484] took 43.21253275871277
# Validation loss EPOCH: [60|1000], validation loss: [0.2809184081852436], AE loss: [0.1352097864728421], TF loss: [0.14570862194523215]
# Training loss EPOCH: [61|1000], training loss: [0.5722844460979104], AE loss: [0.3059110939502716], TF loss: [0.2663733537774533] took 40.99218678474426
# Validation loss EPOCH: [61|1000], validation loss: [0.28101700358092785], AE loss: [0.13532988796941936], TF loss: [0.14568711817264557]
# Training loss EPOCH: [62|1000], training loss: [0.5716873249039054], AE loss: [0.3059515196364373], TF loss: [0.2657358052674681] took 42.45288014411926
# Validation loss EPOCH: [62|1000], validation loss: [0.2813458936288953], AE loss: [0.13516511162742972], TF loss: [0.1461807822342962]
# Training loss EPOCH: [63|1000], training loss: [0.5711428015492857], AE loss: [0.3060199455358088], TF loss: [0.2651228541508317] took 44.03069519996643
# Validation loss EPOCH: [63|1000], validation loss: [0.28184230579063296], AE loss: [0.13521360256709158], TF loss: [0.14662870089523494]
# Training loss EPOCH: [64|1000], training loss: [0.5703765619546175], AE loss: [0.3058513237629086], TF loss: [0.26452523516491055] took 40.72279500961304
# Validation loss EPOCH: [64|1000], validation loss: [0.28156325314193964], AE loss: [0.1350956312380731], TF loss: [0.14646762213669717]
# Training loss EPOCH: [65|1000], training loss: [0.5696023344062269], AE loss: [0.3059264940675348], TF loss: [0.2636758401058614] took 42.28201389312744
# Validation loss EPOCH: [65|1000], validation loss: [0.28133542323485017], AE loss: [0.13497994281351566], TF loss: [0.14635547972284257]
# Training loss EPOCH: [66|1000], training loss: [0.5692927879281342], AE loss: [0.306011235807091], TF loss: [0.26328155561350286] took 42.865817070007324
# Validation loss EPOCH: [66|1000], validation loss: [0.28186118695884943], AE loss: [0.13509552157483995], TF loss: [0.1467656665481627]
# Training loss EPOCH: [67|1000], training loss: [0.5684914165176451], AE loss: [0.305928195361048], TF loss: [0.2625632209237665] took 41.16912245750427
# Validation loss EPOCH: [67|1000], validation loss: [0.28228712920099497], AE loss: [0.13506521563977003], TF loss: [0.1472219154238701]
# Training loss EPOCH: [68|1000], training loss: [0.5674430206418037], AE loss: [0.30582833755761385], TF loss: [0.2616146819200367] took 38.496649742126465
# Validation loss EPOCH: [68|1000], validation loss: [0.2828856837004423], AE loss: [0.1350476525258273], TF loss: [0.1478380316402763]
# Training loss EPOCH: [69|1000], training loss: [0.5674807536415756], AE loss: [0.30605379631742835], TF loss: [0.26142695848830044] took 42.45249009132385
# Validation loss EPOCH: [69|1000], validation loss: [0.28279532538726926], AE loss: [0.1350543077569455], TF loss: [0.1477410199586302]
# Training loss EPOCH: [70|1000], training loss: [0.5665976162999868], AE loss: [0.30597552470862865], TF loss: [0.26062209345400333] took 41.13416337966919
# Validation loss EPOCH: [70|1000], validation loss: [0.28253370709717274], AE loss: [0.13491974491626024], TF loss: [0.14761396194808185]
# Training loss EPOCH: [71|1000], training loss: [0.5659075081348419], AE loss: [0.30588236288167536], TF loss: [0.26002514525316656] took 39.91959023475647
# Validation loss EPOCH: [71|1000], validation loss: [0.28335604071617126], AE loss: [0.13498288625851274], TF loss: [0.14837315259501338]
# Training loss EPOCH: [72|1000], training loss: [0.5654396396130323], AE loss: [0.30598845705389977], TF loss: [0.2594511832576245] took 42.10276675224304
# Validation loss EPOCH: [72|1000], validation loss: [0.2832035291939974], AE loss: [0.13485855143517256], TF loss: [0.14834497682750225]
# Training loss EPOCH: [73|1000], training loss: [0.5642664632759988], AE loss: [0.30576753290370107], TF loss: [0.2584989289753139] took 40.5264618396759
# Validation loss EPOCH: [73|1000], validation loss: [0.2833081176504493], AE loss: [0.13486016751267016], TF loss: [0.14844794874079525]
# Training loss EPOCH: [74|1000], training loss: [0.563901461660862], AE loss: [0.3059524456039071], TF loss: [0.257949014659971] took 41.55418157577515
# Validation loss EPOCH: [74|1000], validation loss: [0.2839979501441121], AE loss: [0.13491631671786308], TF loss: [0.14908163575455546]
# Training loss EPOCH: [75|1000], training loss: [0.5629484015516937], AE loss: [0.30569445458240807], TF loss: [0.2572539481334388] took 42.69853711128235
# Validation loss EPOCH: [75|1000], validation loss: [0.28365681786090136], AE loss: [0.1347212044056505], TF loss: [0.14893561694771051]
# Training loss EPOCH: [76|1000], training loss: [0.5625731754116714], AE loss: [0.3057753276079893], TF loss: [0.25679784431122243] took 40.43096160888672
# Validation loss EPOCH: [76|1000], validation loss: [0.2841373896226287], AE loss: [0.13478707266040146], TF loss: [0.14935031766071916]
# Training loss EPOCH: [77|1000], training loss: [0.5621309108100832], AE loss: [0.3059248602949083], TF loss: [0.256206049118191] took 40.48373246192932
# Validation loss EPOCH: [77|1000], validation loss: [0.2843571901321411], AE loss: [0.13486241060309112], TF loss: [0.14949477836489677]
# Training loss EPOCH: [78|1000], training loss: [0.5615461049601436], AE loss: [0.3059251874219626], TF loss: [0.2556209177710116] took 41.58705997467041
# Validation loss EPOCH: [78|1000], validation loss: [0.2846188135445118], AE loss: [0.13489200407639146], TF loss: [0.14972680853679776]
# Training loss EPOCH: [79|1000], training loss: [0.5611141789704561], AE loss: [0.3059370869304985], TF loss: [0.25517709203995764] took 39.57352948188782
# Validation loss EPOCH: [79|1000], validation loss: [0.2852161284536123], AE loss: [0.13492373353801668], TF loss: [0.15029239561408758]
# Training loss EPOCH: [80|1000], training loss: [0.5605193586088717], AE loss: [0.30589894158765674], TF loss: [0.2546204167883843] took 41.783984899520874
# Validation loss EPOCH: [80|1000], validation loss: [0.28534773038700223], AE loss: [0.13478387682698667], TF loss: [0.1505638542585075]
# Training loss EPOCH: [81|1000], training loss: [0.5599021194502711], AE loss: [0.30582073447294533], TF loss: [0.25408138311468065] took 41.12345004081726
# Validation loss EPOCH: [81|1000], validation loss: [0.2849302161484957], AE loss: [0.13478934834711254], TF loss: [0.1501408712938428]
# Training loss EPOCH: [82|1000], training loss: [0.5590720968320966], AE loss: [0.30589889944531024], TF loss: [0.253173197619617] took 41.09425330162048
# Validation loss EPOCH: [82|1000], validation loss: [0.28560419101268053], AE loss: [0.13477256754413247], TF loss: [0.15083162486553192]
# Training loss EPOCH: [83|1000], training loss: [0.5586166768334806], AE loss: [0.3059704911429435], TF loss: [0.2526461868546903] took 43.268234729766846
# Validation loss EPOCH: [83|1000], validation loss: [0.28540017642080784], AE loss: [0.13466525659896433], TF loss: [0.15073492005467415]
# Training loss EPOCH: [84|1000], training loss: [0.5578284249641001], AE loss: [0.3058677725493908], TF loss: [0.2519606512505561] took 40.423707246780396
# Validation loss EPOCH: [84|1000], validation loss: [0.28590790182352066], AE loss: [0.13472680002450943], TF loss: [0.15118110226467252]
# Training loss EPOCH: [85|1000], training loss: [0.5577104552648962], AE loss: [0.30603599920868874], TF loss: [0.2516744544263929] took 43.551363706588745
# Validation loss EPOCH: [85|1000], validation loss: [0.2858992153778672], AE loss: [0.13482225011102855], TF loss: [0.15107696410268545]
# Training loss EPOCH: [86|1000], training loss: [0.5568958087824285], AE loss: [0.30593486968427896], TF loss: [0.25096093979664147] took 42.00149607658386
# Validation loss EPOCH: [86|1000], validation loss: [0.2860707249492407], AE loss: [0.13473268924281], TF loss: [0.15133803291246295]
# Training loss EPOCH: [87|1000], training loss: [0.5563570400699973], AE loss: [0.3058257114607841], TF loss: [0.2505313279107213] took 41.19313406944275
# Validation loss EPOCH: [87|1000], validation loss: [0.28651196975260973], AE loss: [0.13475034735165536], TF loss: [0.15176162170246243]
# Training loss EPOCH: [88|1000], training loss: [0.5559119344688952], AE loss: [0.3059161838609725], TF loss: [0.2499957475811243] took 40.8461229801178
# Validation loss EPOCH: [88|1000], validation loss: [0.28597867488861084], AE loss: [0.13473069318570197], TF loss: [0.15124798053875566]
# Training loss EPOCH: [89|1000], training loss: [0.5554322525858879], AE loss: [0.30585737410001457], TF loss: [0.24957487639039755] took 41.05925965309143
# Validation loss EPOCH: [89|1000], validation loss: [0.2867573816329241], AE loss: [0.1347417247015983], TF loss: [0.152015658095479]
# Training loss EPOCH: [90|1000], training loss: [0.554504765663296], AE loss: [0.30578654957935214], TF loss: [0.24871821561828256] took 41.309364318847656
# Validation loss EPOCH: [90|1000], validation loss: [0.2870812355540693], AE loss: [0.1348475394770503], TF loss: [0.15223369607701898]
# Training loss EPOCH: [91|1000], training loss: [0.5535343647934496], AE loss: [0.30514513282105327], TF loss: [0.24838923220522702] took 39.945621967315674
# Validation loss EPOCH: [91|1000], validation loss: [0.2870138450525701], AE loss: [0.13472228241153061], TF loss: [0.15229156240820885]
# Training loss EPOCH: [92|1000], training loss: [0.5524009843356907], AE loss: [0.3045912263914943], TF loss: [0.24780975724570453] took 38.416476249694824
# Validation loss EPOCH: [92|1000], validation loss: [0.286893698386848], AE loss: [0.13460451597347856], TF loss: [0.15228918055072427]
# Training loss EPOCH: [93|1000], training loss: [0.5520269349217415], AE loss: [0.30444194516167045], TF loss: [0.24758498696610332] took 40.734657526016235
# Validation loss EPOCH: [93|1000], validation loss: [0.28687585797160864], AE loss: [0.13435669243335724], TF loss: [0.15251916483975947]
# Training loss EPOCH: [94|1000], training loss: [0.5512259579263628], AE loss: [0.30439063045196235], TF loss: [0.24683532817289233] took 38.459964990615845
# Validation loss EPOCH: [94|1000], validation loss: [0.28673816565424204], AE loss: [0.1343967574648559], TF loss: [0.1523414053954184]
# Training loss EPOCH: [95|1000], training loss: [0.5507345157675445], AE loss: [0.30429980368353426], TF loss: [0.2464347134809941] took 39.475573778152466
# Validation loss EPOCH: [95|1000], validation loss: [0.2870970172807574], AE loss: [0.13421750627458096], TF loss: [0.15287950728088617]
# Training loss EPOCH: [96|1000], training loss: [0.5500456970185041], AE loss: [0.3042453059460968], TF loss: [0.2458003901410848] took 39.800878047943115
# Validation loss EPOCH: [96|1000], validation loss: [0.28763339575380087], AE loss: [0.134319027652964], TF loss: [0.1533143692649901]
# Training loss EPOCH: [97|1000], training loss: [0.5498968837782741], AE loss: [0.30429032747633755], TF loss: [0.24560655583627522] took 40.533448457717896
# Validation loss EPOCH: [97|1000], validation loss: [0.2876650234684348], AE loss: [0.1343513943720609], TF loss: [0.15331362606957555]
# Training loss EPOCH: [98|1000], training loss: [0.5491912681609392], AE loss: [0.3040842602495104], TF loss: [0.24510700884275138] took 38.55301523208618
# Validation loss EPOCH: [98|1000], validation loss: [0.28777468390762806], AE loss: [0.1342672521714121], TF loss: [0.1535074315033853]
# Training loss EPOCH: [99|1000], training loss: [0.5487028420902789], AE loss: [0.3039758496452123], TF loss: [0.24472699197940528] took 39.63745355606079
# Validation loss EPOCH: [99|1000], validation loss: [0.2883249022997916], AE loss: [0.13476742035709321], TF loss: [0.15355748170986772]
# Training loss EPOCH: [100|1000], training loss: [0.5472417934797704], AE loss: [0.30319756362587214], TF loss: [0.2440442272927612] took 39.49767303466797
# Validation loss EPOCH: [100|1000], validation loss: [0.28831661213189363], AE loss: [0.1342356859240681], TF loss: [0.15408092783764005]
# Training loss EPOCH: [101|1000], training loss: [0.546200386248529], AE loss: [0.3024639612995088], TF loss: [0.24373642611317337] took 38.54383301734924
# Validation loss EPOCH: [101|1000], validation loss: [0.28850801661610603], AE loss: [0.13429361581802368], TF loss: [0.15421439846977592]
# Training loss EPOCH: [102|1000], training loss: [0.54512401483953], AE loss: [0.30179285909980536], TF loss: [0.24333115690387785] took 41.866912841796875
# Validation loss EPOCH: [102|1000], validation loss: [0.2884441753849387], AE loss: [0.1341876103542745], TF loss: [0.15425656456500292]
# Training loss EPOCH: [103|1000], training loss: [0.5437087994068861], AE loss: [0.3009195157792419], TF loss: [0.24278928409330547] took 41.91600155830383
# Validation loss EPOCH: [103|1000], validation loss: [0.2886470491066575], AE loss: [0.13414270873181522], TF loss: [0.15450433967635036]
# Training loss EPOCH: [104|1000], training loss: [0.542962939478457], AE loss: [0.3004746919032186], TF loss: [0.24248824594542384] took 42.221004247665405
# Validation loss EPOCH: [104|1000], validation loss: [0.288545947521925], AE loss: [0.1340136679355055], TF loss: [0.15453227749094367]
# Training loss EPOCH: [105|1000], training loss: [0.5421285829506814], AE loss: [0.3000671770423651], TF loss: [0.24206140590831637] took 37.73258972167969
# Validation loss EPOCH: [105|1000], validation loss: [0.28880439372733235], AE loss: [0.13425370398908854], TF loss: [0.15455069299787283]
# Training loss EPOCH: [106|1000], training loss: [0.5415188386105001], AE loss: [0.29979763459414244], TF loss: [0.24172120750881732] took 42.823514223098755
# Validation loss EPOCH: [106|1000], validation loss: [0.28850363101810217], AE loss: [0.13415664830245078], TF loss: [0.15434698341414332]
# Training loss EPOCH: [107|1000], training loss: [0.5404422776773572], AE loss: [0.2991125239059329], TF loss: [0.24132975307293236] took 43.56814527511597
# Validation loss EPOCH: [107|1000], validation loss: [0.2886363295838237], AE loss: [0.1340714015532285], TF loss: [0.15456492779776454]
# Training loss EPOCH: [108|1000], training loss: [0.5399743285961449], AE loss: [0.2988427036907524], TF loss: [0.24113162537105381] took 40.803202390670776
# Validation loss EPOCH: [108|1000], validation loss: [0.2885019015520811], AE loss: [0.1340551204048097], TF loss: [0.15444677975028753]
# Training loss EPOCH: [109|1000], training loss: [0.5387517279013991], AE loss: [0.2981169249396771], TF loss: [0.24063480366021395] took 39.8698308467865
# Validation loss EPOCH: [109|1000], validation loss: [0.28941132593899965], AE loss: [0.1340883185621351], TF loss: [0.15532300900667906]
# Training loss EPOCH: [110|1000], training loss: [0.5378291280940175], AE loss: [0.29755335790105164], TF loss: [0.24027577275410295] took 41.61089038848877
# Validation loss EPOCH: [110|1000], validation loss: [0.28884506318718195], AE loss: [0.13394604483619332], TF loss: [0.15489901835098863]
# Training loss EPOCH: [111|1000], training loss: [0.536728233564645], AE loss: [0.29695978364907205], TF loss: [0.2397684478200972] took 42.65374732017517
# Validation loss EPOCH: [111|1000], validation loss: [0.2893111202865839], AE loss: [0.13387131853960454], TF loss: [0.15543980011716485]
# Training loss EPOCH: [112|1000], training loss: [0.5361113646067679], AE loss: [0.2965510841459036], TF loss: [0.23956027952954173] took 39.145474910736084
# Validation loss EPOCH: [112|1000], validation loss: [0.28902815422043204], AE loss: [0.13388068112544715], TF loss: [0.15514747146517038]
# Training loss EPOCH: [113|1000], training loss: [0.535333885345608], AE loss: [0.2961764959618449], TF loss: [0.23915738705545664] took 39.712984561920166
# Validation loss EPOCH: [113|1000], validation loss: [0.289685714058578], AE loss: [0.13390678074210882], TF loss: [0.15577893564477563]
# Training loss EPOCH: [114|1000], training loss: [0.5343051012605429], AE loss: [0.2953881823923439], TF loss: [0.23891691863536835] took 42.164390325546265
# Validation loss EPOCH: [114|1000], validation loss: [0.2899887040257454], AE loss: [0.1338488389737904], TF loss: [0.15613986598327756]
# Training loss EPOCH: [115|1000], training loss: [0.5334492847323418], AE loss: [0.29516479396261275], TF loss: [0.23828449076972902] took 40.38974976539612
# Validation loss EPOCH: [115|1000], validation loss: [0.28999354504048824], AE loss: [0.13406519731506705], TF loss: [0.1559283477254212]
# Training loss EPOCH: [116|1000], training loss: [0.5329216769896448], AE loss: [0.29475439339876175], TF loss: [0.23816728312522173] took 41.957541704177856
# Validation loss EPOCH: [116|1000], validation loss: [0.29005314130336046], AE loss: [0.1339116431772709], TF loss: [0.15614149952307343]
# Training loss EPOCH: [117|1000], training loss: [0.5319388806819916], AE loss: [0.29426724556833506], TF loss: [0.2376716381404549] took 41.024397134780884
# Validation loss EPOCH: [117|1000], validation loss: [0.29007092770189047], AE loss: [0.13394489139318466], TF loss: [0.1561260400339961]
# Training loss EPOCH: [118|1000], training loss: [0.5309686926193535], AE loss: [0.2937478683888912], TF loss: [0.2372208246961236] took 40.07975649833679
# Validation loss EPOCH: [118|1000], validation loss: [0.289979905821383], AE loss: [0.13407738227397203], TF loss: [0.15590252308174968]
# Training loss EPOCH: [119|1000], training loss: [0.5307101281359792], AE loss: [0.2937327353283763], TF loss: [0.2369773918762803] took 39.69953680038452
# Validation loss EPOCH: [119|1000], validation loss: [0.2908050389960408], AE loss: [0.13415524875745177], TF loss: [0.15664979303255677]
# Training loss EPOCH: [120|1000], training loss: [0.5301111876033247], AE loss: [0.29336541797965765], TF loss: [0.23674576822668314] took 39.43880748748779
# Validation loss EPOCH: [120|1000], validation loss: [0.2904627090319991], AE loss: [0.13425446301698685], TF loss: [0.15620824694633484]
# Training loss EPOCH: [121|1000], training loss: [0.5298942383378744], AE loss: [0.29323708917945623], TF loss: [0.23665715008974075] took 39.85192012786865
# Validation loss EPOCH: [121|1000], validation loss: [0.29066125117242336], AE loss: [0.13426689011976123], TF loss: [0.15639436431229115]
# Training loss EPOCH: [122|1000], training loss: [0.5293817613273859], AE loss: [0.29302149754948914], TF loss: [0.23636026168242097] took 38.63859701156616
# Validation loss EPOCH: [122|1000], validation loss: [0.2915409980341792], AE loss: [0.13444125116802752], TF loss: [0.15709975082427263]
# Training loss EPOCH: [123|1000], training loss: [0.5284267915412784], AE loss: [0.2925630018580705], TF loss: [0.23586379061453044] took 38.34370470046997
# Validation loss EPOCH: [123|1000], validation loss: [0.29174668062478304], AE loss: [0.1343418143223971], TF loss: [0.15740486606955528]
# Training loss EPOCH: [124|1000], training loss: [0.527544085867703], AE loss: [0.2920730817131698], TF loss: [0.23547100485302508] took 39.955843687057495
# Validation loss EPOCH: [124|1000], validation loss: [0.29101509507745504], AE loss: [0.13444836298003793], TF loss: [0.15656673396006227]
# Training loss EPOCH: [125|1000], training loss: [0.5269788498990238], AE loss: [0.2919459664262831], TF loss: [0.23503288091160357] took 41.88868546485901
# Validation loss EPOCH: [125|1000], validation loss: [0.2920620432123542], AE loss: [0.1345661913510412], TF loss: [0.15749585116282105]
# Training loss EPOCH: [126|1000], training loss: [0.5269569205120206], AE loss: [0.2920241276733577], TF loss: [0.23493279260583222] took 40.05308699607849
# Validation loss EPOCH: [126|1000], validation loss: [0.2918935129418969], AE loss: [0.13460827735252678], TF loss: [0.1572852344252169]
# Training loss EPOCH: [127|1000], training loss: [0.5263839224353433], AE loss: [0.29170545982196927], TF loss: [0.2346784637775272] took 40.3760507106781
# Validation loss EPOCH: [127|1000], validation loss: [0.2913909247145057], AE loss: [0.13457358651794493], TF loss: [0.15681733563542366]
# Training loss EPOCH: [128|1000], training loss: [0.525691008195281], AE loss: [0.2912711778189987], TF loss: [0.23441983154043555] took 39.45709466934204
# Validation loss EPOCH: [128|1000], validation loss: [0.2921642241999507], AE loss: [0.13457536487840116], TF loss: [0.15758886048570275]
# Training loss EPOCH: [129|1000], training loss: [0.5251398584805429], AE loss: [0.2912229117937386], TF loss: [0.2339169487822801] took 41.11137080192566
# Validation loss EPOCH: [129|1000], validation loss: [0.2924126470461488], AE loss: [0.1346304677426815], TF loss: [0.1577821779064834]
# Training loss EPOCH: [130|1000], training loss: [0.5253197229467332], AE loss: [0.291345909005031], TF loss: [0.2339738116133958] took 40.784583568573
# Validation loss EPOCH: [130|1000], validation loss: [0.29295952152460814], AE loss: [0.13470915704965591], TF loss: [0.15825036354362965]
# Training loss EPOCH: [131|1000], training loss: [0.5243051419965923], AE loss: [0.2908026441000402], TF loss: [0.23350249719806015] took 41.611961126327515
# Validation loss EPOCH: [131|1000], validation loss: [0.2911862079054117], AE loss: [0.13458819803781807], TF loss: [0.15659801056608558]
# Training loss EPOCH: [132|1000], training loss: [0.5238112104125321], AE loss: [0.29054202092811465], TF loss: [0.23326918855309486] took 40.30280327796936
# Validation loss EPOCH: [132|1000], validation loss: [0.2924829740077257], AE loss: [0.13459526002407074], TF loss: [0.15788771444931626]
# Training loss EPOCH: [133|1000], training loss: [0.5236619296483696], AE loss: [0.29044292867183685], TF loss: [0.23321900004521012] took 37.08755445480347
# Validation loss EPOCH: [133|1000], validation loss: [0.29295030795037746], AE loss: [0.13469176460057497], TF loss: [0.15825854241847992]
# Training loss EPOCH: [134|1000], training loss: [0.5229740287177265], AE loss: [0.29016806930303574], TF loss: [0.23280595894902945] took 36.46604514122009
# Validation loss EPOCH: [134|1000], validation loss: [0.2931539276614785], AE loss: [0.13466364424675703], TF loss: [0.15849028248339891]
# Training loss EPOCH: [135|1000], training loss: [0.5226868721656501], AE loss: [0.2902563593816012], TF loss: [0.2324305137153715] took 38.263492584228516
# Validation loss EPOCH: [135|1000], validation loss: [0.29269818123430014], AE loss: [0.1345714449416846], TF loss: [0.15812673652544618]
# Training loss EPOCH: [136|1000], training loss: [0.5221493700519204], AE loss: [0.28999559790827334], TF loss: [0.23215377097949386] took 41.18046474456787
# Validation loss EPOCH: [136|1000], validation loss: [0.2923387214541435], AE loss: [0.1344365153927356], TF loss: [0.15790220582857728]
# Training loss EPOCH: [137|1000], training loss: [0.5220397640950978], AE loss: [0.2898548003286123], TF loss: [0.2321849660947919] took 40.092501401901245
# Validation loss EPOCH: [137|1000], validation loss: [0.29270304553210735], AE loss: [0.1345073515549302], TF loss: [0.15819569304585457]
# Training loss EPOCH: [138|1000], training loss: [0.5216098059900105], AE loss: [0.28970056725665927], TF loss: [0.23190924036316574] took 42.3175311088562
# Validation loss EPOCH: [138|1000], validation loss: [0.29330998938530684], AE loss: [0.13454035762697458], TF loss: [0.15876963594928384]
# Training loss EPOCH: [139|1000], training loss: [0.5210340307094157], AE loss: [0.2894319898914546], TF loss: [0.23160204151645303] took 39.98627305030823
# Validation loss EPOCH: [139|1000], validation loss: [0.2929123491048813], AE loss: [0.13447369262576103], TF loss: [0.1584386550821364]
# Training loss EPOCH: [140|1000], training loss: [0.5205959784798324], AE loss: [0.2892061909660697], TF loss: [0.23138978914357722] took 39.07758355140686
# Validation loss EPOCH: [140|1000], validation loss: [0.29318608343601227], AE loss: [0.1345742775592953], TF loss: [0.15861180564388633]
# Training loss EPOCH: [141|1000], training loss: [0.520295993424952], AE loss: [0.28918799106031656], TF loss: [0.23110800236463547] took 39.8080198764801
# Validation loss EPOCH: [141|1000], validation loss: [0.29365712963044643], AE loss: [0.13446660828776658], TF loss: [0.15919051971286535]
# Training loss EPOCH: [142|1000], training loss: [0.5198901924304664], AE loss: [0.289054294815287], TF loss: [0.2308358997106552] took 40.287700176239014
# Validation loss EPOCH: [142|1000], validation loss: [0.2932774741202593], AE loss: [0.13450479274615645], TF loss: [0.15877268137410283]
# Training loss EPOCH: [143|1000], training loss: [0.5193648701533675], AE loss: [0.28886112733744085], TF loss: [0.23050374304875731] took 39.116243839263916
# Validation loss EPOCH: [143|1000], validation loss: [0.2937859734520316], AE loss: [0.13466459745541215], TF loss: [0.1591213778592646]
# Training loss EPOCH: [144|1000], training loss: [0.5191895444877446], AE loss: [0.28881830838508904], TF loss: [0.2303712358698249] took 38.66419696807861
# Validation loss EPOCH: [144|1000], validation loss: [0.29340199660509825], AE loss: [0.13463320513255894], TF loss: [0.1587687903083861]
# Training loss EPOCH: [145|1000], training loss: [0.5189159805886447], AE loss: [0.2886353142093867], TF loss: [0.23028066847473383] took 40.52203297615051
# Validation loss EPOCH: [145|1000], validation loss: [0.293491005897522], AE loss: [0.1345752750057727], TF loss: [0.15891572972759604]
# Training loss EPOCH: [146|1000], training loss: [0.5185173121280968], AE loss: [0.2885196884162724], TF loss: [0.2299976209178567] took 41.571155309677124
# Validation loss EPOCH: [146|1000], validation loss: [0.2939576981589198], AE loss: [0.1347511967178434], TF loss: [0.15920650400221348]
# Training loss EPOCH: [147|1000], training loss: [0.5184913044795394], AE loss: [0.2885206483770162], TF loss: [0.22997065470553935] took 38.15772008895874
# Validation loss EPOCH: [147|1000], validation loss: [0.29399447701871395], AE loss: [0.13452680152840912], TF loss: [0.15946767712011933]
# Training loss EPOCH: [148|1000], training loss: [0.5178104410879314], AE loss: [0.2881707742344588], TF loss: [0.22963966499082744] took 40.92159914970398
# Validation loss EPOCH: [148|1000], validation loss: [0.29364934377372265], AE loss: [0.13440358568914235], TF loss: [0.1592457564547658]
# Training loss EPOCH: [149|1000], training loss: [0.5172495706938207], AE loss: [0.2877908619120717], TF loss: [0.22945870668627322] took 39.932637453079224
# Validation loss EPOCH: [149|1000], validation loss: [0.2938739862293005], AE loss: [0.13475766498595476], TF loss: [0.1591163189150393]
# Training loss EPOCH: [150|1000], training loss: [0.5170110412873328], AE loss: [0.2877706722356379], TF loss: [0.22924036998301744] took 39.34504055976868
# Validation loss EPOCH: [150|1000], validation loss: [0.29348526429384947], AE loss: [0.13461884367279708], TF loss: [0.15886641899123788]
# Training loss EPOCH: [151|1000], training loss: [0.5169888306409121], AE loss: [0.2879479546099901], TF loss: [0.22904087789356709] took 36.82307434082031
# Validation loss EPOCH: [151|1000], validation loss: [0.29418326960876584], AE loss: [0.1346365676727146], TF loss: [0.1595467021688819]
# Training loss EPOCH: [152|1000], training loss: [0.5164876319468021], AE loss: [0.287650391459465], TF loss: [0.22883724188432097] took 40.591649532318115
# Validation loss EPOCH: [152|1000], validation loss: [0.29461928736418486], AE loss: [0.13457063026726246], TF loss: [0.1600486570969224]
# Training loss EPOCH: [153|1000], training loss: [0.5162936146371067], AE loss: [0.28761475114151835], TF loss: [0.2286788639612496] took 40.066869497299194
# Validation loss EPOCH: [153|1000], validation loss: [0.2943181237205863], AE loss: [0.1347149652428925], TF loss: [0.15960315614938736]
# Training loss EPOCH: [154|1000], training loss: [0.516086355317384], AE loss: [0.28746634093113244], TF loss: [0.228620013454929] took 37.35395407676697
# Validation loss EPOCH: [154|1000], validation loss: [0.29473717883229256], AE loss: [0.13476551440544426], TF loss: [0.15997166652232409]
# Training loss EPOCH: [155|1000], training loss: [0.5154915181919932], AE loss: [0.2874239617958665], TF loss: [0.2280675561632961] took 38.538170337677
# Validation loss EPOCH: [155|1000], validation loss: [0.2939858864992857], AE loss: [0.13475283049046993], TF loss: [0.15923305274918675]
# Training loss EPOCH: [156|1000], training loss: [0.5152277289889753], AE loss: [0.28709593671374023], TF loss: [0.22813178994692862] took 39.19710659980774
# Validation loss EPOCH: [156|1000], validation loss: [0.29401158448308706], AE loss: [0.13473036675713956], TF loss: [0.15928122075274587]
# Training loss EPOCH: [157|1000], training loss: [0.5152793782763183], AE loss: [0.28730414784513414], TF loss: [0.22797523229382932] took 37.73708772659302
# Validation loss EPOCH: [157|1000], validation loss: [0.29434586875140667], AE loss: [0.1347300794441253], TF loss: [0.1596157900057733]
# Training loss EPOCH: [158|1000], training loss: [0.5151536478661001], AE loss: [0.28757481602951884], TF loss: [0.22757882997393608] took 37.430458784103394
# Validation loss EPOCH: [158|1000], validation loss: [0.29521541576832533], AE loss: [0.13492808397859335], TF loss: [0.16028732992708683]
# Training loss EPOCH: [159|1000], training loss: [0.5144290449097753], AE loss: [0.2867910750210285], TF loss: [0.22763797058723867] took 41.32331037521362
# Validation loss EPOCH: [159|1000], validation loss: [0.2954873130656779], AE loss: [0.1347508653998375], TF loss: [0.16073644533753395]
# Training loss EPOCH: [160|1000], training loss: [0.5138449231162667], AE loss: [0.286549573764205], TF loss: [0.2272953512147069] took 39.62161827087402
# Validation loss EPOCH: [160|1000], validation loss: [0.29508508648723364], AE loss: [0.13479475886560977], TF loss: [0.16029032599180937]
# Training loss EPOCH: [161|1000], training loss: [0.5135351214557886], AE loss: [0.2864426476880908], TF loss: [0.2270924709737301] took 36.749815225601196
# Validation loss EPOCH: [161|1000], validation loss: [0.29483166616410017], AE loss: [0.1348101960029453], TF loss: [0.1600214708596468]
# Training loss EPOCH: [162|1000], training loss: [0.5136185502633452], AE loss: [0.2866114913485944], TF loss: [0.22700706007890403] took 39.99586033821106
# Validation loss EPOCH: [162|1000], validation loss: [0.2956344448029995], AE loss: [0.13502629636786878], TF loss: [0.16060814959928393]
# Training loss EPOCH: [163|1000], training loss: [0.5129303801804781], AE loss: [0.28613042342476547], TF loss: [0.22679995582439005] took 39.43043375015259
# Validation loss EPOCH: [163|1000], validation loss: [0.29594078520312905], AE loss: [0.13492467487230897], TF loss: [0.16101611079648137]
# Training loss EPOCH: [164|1000], training loss: [0.5128907873295248], AE loss: [0.28624703432433307], TF loss: [0.22664375440217555] took 40.04603052139282
# Validation loss EPOCH: [164|1000], validation loss: [0.29542974196374416], AE loss: [0.13492501573637128], TF loss: [0.16050472296774387]
# Training loss EPOCH: [165|1000], training loss: [0.5124470442533493], AE loss: [0.28587495419196784], TF loss: [0.2265720907598734] took 38.57423448562622
# Validation loss EPOCH: [165|1000], validation loss: [0.2951533952727914], AE loss: [0.13494074903428555], TF loss: [0.16021264577284455]
# ...
# Validation loss EPOCH: [946|1000], validation loss: [0.31373156234622], AE loss: [0.14265817822888494], TF loss: [0.1710733831860125]
# Training loss EPOCH: [947|1000], training loss: [0.45540406461805105], AE loss: [0.25011442485265434], TF loss: [0.20528963976539671] took 26.43737292289734
# Validation loss EPOCH: [947|1000], validation loss: [0.31275567784905434], AE loss: [0.1425395137630403], TF loss: [0.1702161650173366]
# Training loss EPOCH: [948|1000], training loss: [0.4524798602797091], AE loss: [0.24709708336740732], TF loss: [0.20538277574814856] took 28.41298198699951
# Validation loss EPOCH: [948|1000], validation loss: [0.3146397387608886], AE loss: [0.1433812843170017], TF loss: [0.17125845467671752]
# Training loss EPOCH: [949|1000], training loss: [0.4540873649530113], AE loss: [0.2487756283953786], TF loss: [0.20531173492781818] took 25.197510242462158
# Validation loss EPOCH: [949|1000], validation loss: [0.3123005470260978], AE loss: [0.14239931432530284], TF loss: [0.16990123083814979]
# Training loss EPOCH: [950|1000], training loss: [0.4490118226967752], AE loss: [0.2437704592011869], TF loss: [0.20524136233143508] took 29.931142330169678
# Validation loss EPOCH: [950|1000], validation loss: [0.31429011560976505], AE loss: [0.14327174122445285], TF loss: [0.17101837741211057]
# Training loss EPOCH: [951|1000], training loss: [0.4573197443969548], AE loss: [0.25224031531251967], TF loss: [0.20507942931726575] took 25.98654055595398
# Validation loss EPOCH: [951|1000], validation loss: [0.3133777305483818], AE loss: [0.14250978850759566], TF loss: [0.1708679385483265]
# Training loss EPOCH: [952|1000], training loss: [0.45930617954581976], AE loss: [0.2540458410512656], TF loss: [0.20526033686473966] took 27.46890139579773
# Validation loss EPOCH: [952|1000], validation loss: [0.31384746078401804], AE loss: [0.1425361626315862], TF loss: [0.17131129978224635]
# Training loss EPOCH: [953|1000], training loss: [0.4517655740492046], AE loss: [0.24667238118126988], TF loss: [0.20509319310076535] took 23.427465438842773
# Validation loss EPOCH: [953|1000], validation loss: [0.31345160491764545], AE loss: [0.14296338125132024], TF loss: [0.17048822296783328]
# Training loss EPOCH: [954|1000], training loss: [0.4524986236356199], AE loss: [0.2473573093302548], TF loss: [0.2051413138397038] took 27.790456533432007
# Validation loss EPOCH: [954|1000], validation loss: [0.3142142593860626], AE loss: [0.1427797586657107], TF loss: [0.17143450025469065]
# Training loss EPOCH: [955|1000], training loss: [0.44822788890451193], AE loss: [0.24315585242584348], TF loss: [0.2050720346160233] took 29.076545238494873
# Validation loss EPOCH: [955|1000], validation loss: [0.31411286257207394], AE loss: [0.14334239880554378], TF loss: [0.17077046120539308]
# Training loss EPOCH: [956|1000], training loss: [0.45778412465006113], AE loss: [0.25256736180745065], TF loss: [0.20521676097996533] took 20.974968910217285
# Validation loss EPOCH: [956|1000], validation loss: [0.31514821108430624], AE loss: [0.1436449741013348], TF loss: [0.171503237914294]
# Training loss EPOCH: [957|1000], training loss: [0.4545394042506814], AE loss: [0.24933732557110488], TF loss: [0.20520207774825394] took 24.686529874801636
# Validation loss EPOCH: [957|1000], validation loss: [0.31366823986172676], AE loss: [0.14274877309799194], TF loss: [0.17091946955770254]
# Training loss EPOCH: [958|1000], training loss: [0.45369391376152635], AE loss: [0.2483337614685297], TF loss: [0.205360152060166] took 22.236146688461304
# Validation loss EPOCH: [958|1000], validation loss: [0.3149471627548337], AE loss: [0.1431134040467441], TF loss: [0.1718337582424283]
# Training loss EPOCH: [959|1000], training loss: [0.44960451824590564], AE loss: [0.24445504369214177], TF loss: [0.2051494736224413] took 27.828901767730713
# Validation loss EPOCH: [959|1000], validation loss: [0.3136917548254132], AE loss: [0.14298135414719582], TF loss: [0.17071039974689484]
# Training loss EPOCH: [960|1000], training loss: [0.44843898992985487], AE loss: [0.2431925639975816], TF loss: [0.20524642523378134] took 28.53121781349182
# Validation loss EPOCH: [960|1000], validation loss: [0.3137783231213689], AE loss: [0.1431172713637352], TF loss: [0.17066105036064982]
# Training loss EPOCH: [961|1000], training loss: [0.4596069846302271], AE loss: [0.25431381026282907], TF loss: [0.2052931736689061] took 25.518691539764404
# Validation loss EPOCH: [961|1000], validation loss: [0.3131914082914591], AE loss: [0.14230603026226163], TF loss: [0.1708853803575039]
# Training loss EPOCH: [962|1000], training loss: [0.45075895404443145], AE loss: [0.24553939467296004], TF loss: [0.2052195598371327] took 26.643873691558838
# Validation loss EPOCH: [962|1000], validation loss: [0.31431033834815025], AE loss: [0.1431088405661285], TF loss: [0.17120149824768305]
# Training loss EPOCH: [963|1000], training loss: [0.45116576785221696], AE loss: [0.24616864509880543], TF loss: [0.20499712508171797] took 26.478854417800903
# Validation loss EPOCH: [963|1000], validation loss: [0.3133679525926709], AE loss: [0.143180669285357], TF loss: [0.17018727865070105]
# Training loss EPOCH: [964|1000], training loss: [0.44934381265193224], AE loss: [0.24422480631619692], TF loss: [0.20511900633573532] took 25.37276291847229
# Validation loss EPOCH: [964|1000], validation loss: [0.3145216088742018], AE loss: [0.14358425699174404], TF loss: [0.17093735095113516]
# Training loss EPOCH: [965|1000], training loss: [0.4549139179289341], AE loss: [0.2498558305669576], TF loss: [0.20505808712914586] took 29.588438749313354
# Validation loss EPOCH: [965|1000], validation loss: [0.31395498383790255], AE loss: [0.14293124177493155], TF loss: [0.1710237404331565]
# Training loss EPOCH: [966|1000], training loss: [0.45462782960385084], AE loss: [0.24954819842241704], TF loss: [0.2050796295516193] took 28.76794743537903
# Validation loss EPOCH: [966|1000], validation loss: [0.3135993480682373], AE loss: [0.14266514498740435], TF loss: [0.17093420587480068]
# Training loss EPOCH: [967|1000], training loss: [0.45405619079247117], AE loss: [0.24908411595970392], TF loss: [0.20497207529842854] took 26.088982105255127
# Validation loss EPOCH: [967|1000], validation loss: [0.3143648514524102], AE loss: [0.14335198421031237], TF loss: [0.171012865845114]
# Training loss EPOCH: [968|1000], training loss: [0.45184944616630673], AE loss: [0.24666630732826889], TF loss: [0.20518313883803785] took 27.078941822052002
# Validation loss EPOCH: [968|1000], validation loss: [0.3134483937174082], AE loss: [0.14299376518465579], TF loss: [0.17045462876558304]
# Training loss EPOCH: [969|1000], training loss: [0.4506560177542269], AE loss: [0.24551390972919762], TF loss: [0.20514210546389222] took 29.12394404411316
# Validation loss EPOCH: [969|1000], validation loss: [0.3137925937771797], AE loss: [0.14296603458933532], TF loss: [0.17082655942067504]
# Training loss EPOCH: [970|1000], training loss: [0.4570764824748039], AE loss: [0.25204391428269446], TF loss: [0.20503257028758526] took 26.67833423614502
# Validation loss EPOCH: [970|1000], validation loss: [0.31293613091111183], AE loss: [0.14241323433816433], TF loss: [0.17052289750427008]
# Training loss EPOCH: [971|1000], training loss: [0.4510791474021971], AE loss: [0.24580098129808903], TF loss: [0.20527816866524518] took 27.8169686794281
# Validation loss EPOCH: [971|1000], validation loss: [0.3136731069535017], AE loss: [0.1427660493645817], TF loss: [0.17090705689042807]
# Training loss EPOCH: [972|1000], training loss: [0.4517909395508468], AE loss: [0.24660421046428382], TF loss: [0.20518672885373235] took 26.684273958206177
# Validation loss EPOCH: [972|1000], validation loss: [0.3141598515212536], AE loss: [0.1430796894710511], TF loss: [0.17108016135171056]
# Training loss EPOCH: [973|1000], training loss: [0.45566090289503336], AE loss: [0.2505576254334301], TF loss: [0.20510327839292586] took 28.099980115890503
# Validation loss EPOCH: [973|1000], validation loss: [0.3142202915623784], AE loss: [0.14290763856843114], TF loss: [0.1713126515969634]
# Training loss EPOCH: [974|1000], training loss: [0.4516550558619201], AE loss: [0.24640399729833007], TF loss: [0.2052510587964207] took 28.04895257949829
# Validation loss EPOCH: [974|1000], validation loss: [0.31348091177642345], AE loss: [0.14309539832174778], TF loss: [0.17038551811128855]
# Training loss EPOCH: [975|1000], training loss: [0.45214252080768347], AE loss: [0.24711823626421392], TF loss: [0.20502428454346955] took 26.8565890789032
# Validation loss EPOCH: [975|1000], validation loss: [0.3144619967788458], AE loss: [0.1434653690084815], TF loss: [0.1709966310299933]
# Training loss EPOCH: [976|1000], training loss: [0.4495175485499203], AE loss: [0.24443344376049936], TF loss: [0.2050841054879129] took 18.011208295822144
# Validation loss EPOCH: [976|1000], validation loss: [0.3133630771189928], AE loss: [0.14289524499326944], TF loss: [0.17046783305704594]
# Training loss EPOCH: [977|1000], training loss: [0.44686148408800364], AE loss: [0.24177751457318664], TF loss: [0.2050839716102928] took 27.25548815727234
# Validation loss EPOCH: [977|1000], validation loss: [0.3146820953115821], AE loss: [0.1433354071341455], TF loss: [0.17134668724611402]
# Training loss EPOCH: [978|1000], training loss: [0.4564473954960704], AE loss: [0.25133812171407044], TF loss: [0.2051092702895403] took 25.382097721099854
# Validation loss EPOCH: [978|1000], validation loss: [0.3134347777813673], AE loss: [0.14281219523400068], TF loss: [0.1706225834786892]
# Training loss EPOCH: [979|1000], training loss: [0.4485712517052889], AE loss: [0.2434424082748592], TF loss: [0.20512884273193777] took 27.039106607437134
# Validation loss EPOCH: [979|1000], validation loss: [0.3149807685986161], AE loss: [0.14366938173770905], TF loss: [0.17131138546392322]
# Training loss EPOCH: [980|1000], training loss: [0.45616578310728073], AE loss: [0.25119018694385886], TF loss: [0.2049755968619138] took 26.71399998664856
# Validation loss EPOCH: [980|1000], validation loss: [0.3118379535153508], AE loss: [0.14173501753248274], TF loss: [0.17010293575003743]
# Training loss EPOCH: [981|1000], training loss: [0.4527572034858167], AE loss: [0.2475484935566783], TF loss: [0.2052087103947997] took 24.972366333007812
# Validation loss EPOCH: [981|1000], validation loss: [0.31433446891605854], AE loss: [0.14310002559795976], TF loss: [0.17123444564640522]
# Training loss EPOCH: [982|1000], training loss: [0.4518408323638141], AE loss: [0.2468026306014508], TF loss: [0.2050382022280246] took 29.173888206481934
# Validation loss EPOCH: [982|1000], validation loss: [0.314265307970345], AE loss: [0.14315453451126814], TF loss: [0.1711107729934156]
# Training loss EPOCH: [983|1000], training loss: [0.4495180700905621], AE loss: [0.24437808245420456], TF loss: [0.20513998647220433] took 28.639365673065186
# Validation loss EPOCH: [983|1000], validation loss: [0.3143985737115145], AE loss: [0.14308501034975052], TF loss: [0.1713135652244091]
# Training loss EPOCH: [984|1000], training loss: [0.45198072120547295], AE loss: [0.24692806764505804], TF loss: [0.20505265449173748] took 27.558988571166992
# Validation loss EPOCH: [984|1000], validation loss: [0.31346617825329304], AE loss: [0.14298321143724024], TF loss: [0.1704829651862383]
# Training loss EPOCH: [985|1000], training loss: [0.45868537202477455], AE loss: [0.25373172922991216], TF loss: [0.2049536423292011] took 26.48685050010681
# Validation loss EPOCH: [985|1000], validation loss: [0.31440657656639814], AE loss: [0.14293067809194326], TF loss: [0.17147589707747102]
# Training loss EPOCH: [986|1000], training loss: [0.45738580729812384], AE loss: [0.2525781854055822], TF loss: [0.20480762142688036] took 26.392868280410767
# Validation loss EPOCH: [986|1000], validation loss: [0.3142639212310314], AE loss: [0.1426399031188339], TF loss: [0.17162401834502816]
# Training loss EPOCH: [987|1000], training loss: [0.45170483412221074], AE loss: [0.2467898998875171], TF loss: [0.20491493586450815] took 28.102560997009277
# Validation loss EPOCH: [987|1000], validation loss: [0.3133595287799835], AE loss: [0.14204877009615302], TF loss: [0.1713107582181692]
# Training loss EPOCH: [988|1000], training loss: [0.4580803466960788], AE loss: [0.25298159499652684], TF loss: [0.20509874913841486] took 31.178409576416016
# Validation loss EPOCH: [988|1000], validation loss: [0.3130936147645116], AE loss: [0.1428309939801693], TF loss: [0.17026261938735843]
# Training loss EPOCH: [989|1000], training loss: [0.45317394053563476], AE loss: [0.24817346036434174], TF loss: [0.2050004794728011] took 21.9028377532959
# Validation loss EPOCH: [989|1000], validation loss: [0.3141117412596941], AE loss: [0.14290049741975963], TF loss: [0.17121124221011996]
# Training loss EPOCH: [990|1000], training loss: [0.4487957078963518], AE loss: [0.2437227878253907], TF loss: [0.20507292007096112] took 27.656697750091553
# Validation loss EPOCH: [990|1000], validation loss: [0.3133146921172738], AE loss: [0.14282866101711988], TF loss: [0.1704860352911055]
# Training loss EPOCH: [991|1000], training loss: [0.4505715947598219], AE loss: [0.24566841963678598], TF loss: [0.2049031751230359] took 24.302966117858887
# Validation loss EPOCH: [991|1000], validation loss: [0.31457980535924435], AE loss: [0.14260325231589377], TF loss: [0.1719765542075038]
# Training loss EPOCH: [992|1000], training loss: [0.44772871024906635], AE loss: [0.24276051297783852], TF loss: [0.2049681949429214] took 26.94097661972046
# Validation loss EPOCH: [992|1000], validation loss: [0.31418085750192404], AE loss: [0.14298452762886882], TF loss: [0.17119633220136166]
# Training loss EPOCH: [993|1000], training loss: [0.4644905449822545], AE loss: [0.2594659700989723], TF loss: [0.20502457628026605] took 26.9514799118042
# Validation loss EPOCH: [993|1000], validation loss: [0.31304273940622807], AE loss: [0.14192831725813448], TF loss: [0.17111442424356937]
# Training loss EPOCH: [994|1000], training loss: [0.4543267199769616], AE loss: [0.24937194189988077], TF loss: [0.20495478063821793] took 27.63434672355652
# Validation loss EPOCH: [994|1000], validation loss: [0.31285124365240335], AE loss: [0.14245622884482145], TF loss: [0.1703950148075819]
# Training loss EPOCH: [995|1000], training loss: [0.4571485542692244], AE loss: [0.25206412584520876], TF loss: [0.205084428191185] took 28.219726085662842
# Validation loss EPOCH: [995|1000], validation loss: [0.31399523187428713], AE loss: [0.14225733513012528], TF loss: [0.1717378944158554]
# Training loss EPOCH: [996|1000], training loss: [0.44733908167108893], AE loss: [0.24232583050616086], TF loss: [0.20501325139775872] took 27.06695580482483
# Validation loss EPOCH: [996|1000], validation loss: [0.31397385988384485], AE loss: [0.14273251919075847], TF loss: [0.1712413402274251]
# Training loss EPOCH: [997|1000], training loss: [0.4572625649161637], AE loss: [0.25235939770936966], TF loss: [0.20490316534414887] took 28.36059260368347
# Validation loss EPOCH: [997|1000], validation loss: [0.31322366278618574], AE loss: [0.14258317067287862], TF loss: [0.17064049234613776]
# Training loss EPOCH: [998|1000], training loss: [0.45362016139551997], AE loss: [0.2487058131955564], TF loss: [0.20491434866562486] took 25.81874942779541
# Validation loss EPOCH: [998|1000], validation loss: [0.31415544357150793], AE loss: [0.14278622576966882], TF loss: [0.1713692182675004]
# Training loss EPOCH: [999|1000], training loss: [0.45013807294890285], AE loss: [0.24508603871800005], TF loss: [0.20505203306674957] took 20.68108057975769
# Validation loss EPOCH: [999|1000], validation loss: [0.31393340416252613], AE loss: [0.1430000071413815], TF loss: [0.17093339376151562]
# Training loss EPOCH: [1000|1000], training loss: [0.4489715415984392], AE loss: [0.24417182616889477], TF loss: [0.2047997135668993] took 27.751107931137085
# Validation loss EPOCH: [1000|1000], validation loss: [0.3138813842087984], AE loss: [0.14291998511180282], TF loss: [0.17096139956265688]

# %%
input_tensor = torch.rand(512, 10, 220, 10, 1)  # (b,t,c,h,w)

model = ConvGRU(input_size=(10, 1),
                input_dim=220,
                hidden_dim=[55,55,55],
                kernel_size=(3,3),
                num_layers=3,
                dtype=torch.FloatTensor,
                batch_first=True,
                bias = True,
                return_all_layers = False)
a,b = model(input_tensor)
print(len(a))
# Out:
# 3

# %%
model_name = 'SalGATConvGRUwo_saliency_MSL'
with open("result/model_" + model_name + "_best.pt", "rb") as f:
    SAVED_MODEL = torch.load(f)

print(SAVED_MODEL['best_epoch'])

# MODEL = SalGATSCINet(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
# MODEL = SalGATSCINetV2(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
# MODEL = SalGATConvLSTM(seq_len=window_size, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
# MODEL = SalGATConvGRU(seq_len=window_size, output_len=10, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
# MODEL = SalGATConvGRUwoSal(seq_len=window_size, output_len=10, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')
MODEL = SalConvGRUwoALL(seq_len=window_size, output_len=10, n_features=x_train.shape[1], out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2), kernel_size=3, cell='gru')

MODEL.cuda()    
MODEL.load_state_dict(SAVED_MODEL["state"])


# trained_encoder = list(MODEL.children())[0]
# trained_decoder = list(MODEL.children())[1]
 
# # Test the decoder
# x = trained_decoder(torch.Tensor(np.random.rand(512,1,12)).cuda())
# x.shape
# Out:
# 13
# <All keys matched successfully>

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(16, 4))
plt.title("Training Loss Graph")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.yscale("log")
plt.plot(SAVED_MODEL["loss_history"], label='loss')
plt.plot(SAVED_MODEL["loss_AE_history"], label='AE loss')
plt.plot(SAVED_MODEL["loss_TF_history"], label='TF loss')
plt.legend()
plt.show()

# %%
def inference(dataloader, model, batch_size, TF_alpha):
    dist, dist_sal, fin_dist, guess, sal_list = [], [], [], [], []
    mse = torch.nn.MSELoss()
    model.eval()
    with torch.no_grad():
        for i, (x,y) in enumerate(dataloader):
            x = x.cuda()
            y = y.cuda()
            
            sal, dec_x, out = model(x)
            
            for y_s, d, o in zip(y, dec_x, out):
                dist_sal.append(torch.sum(torch.abs(y_s - d)).cpu().numpy())
                # dist_sal.append(mse(y_s,d).item())
                # dist_sal.append(torch.cdist(y_s, d, p=2.0).cpu().numpy())  
                
                dist.append(torch.sum(torch.abs(y_s - o)).cpu().numpy())
                # dist.append(mse(y_s, o).item())
                # dist.append(torch.cdist(y_s, o, p=2.0).cpu().numpy())  

                fin_dist.append((1-TF_alpha)*torch.sum(torch.abs(y_s - d)).cpu().numpy() + TF_alpha*torch.sum(torch.abs(y_s - o)).cpu().numpy())
                # fin_dist.append((1-TF_alpha)*mse(y_s,d).item() + TF_alpha*mse(y_s, o).item())
                # fin_dist.append((TF_alpha*torch.cdist(y_s, o, p=2.0) + (1-TF_alpha)*torch.cdist(y_s, d, p=2.0)).cpu().numpy())

            guess.append(out.cpu().numpy())
            sal_list.append(sal.cpu().numpy())
        
            
    return (
        dist,
        dist_sal,
        fin_dist,
        np.concatenate(guess),
        np.concatenate(sal_list)
    )


def inference_SAL(dataloader, model, batch_size, TF_alpha):
    dist, dist_sal, fin_dist1, fin_dist2, guess, sal_list = [], [], [], [], [], []
    mse = torch.nn.MSELoss()
    model.eval()
    with torch.no_grad():
        for i, (x,y_recon,y_fore) in enumerate(dataloader):
            x = x.cuda()
            y_recon = y_recon.cuda()
            y_fore = y_fore.cuda()
            
            sal, dec_x, out = model(x)
            
            for y_r, y_f, d, o in zip(y_recon, y_fore, dec_x, out):
                d_s = torch.sum(torch.square(y_r - d)).cpu().numpy()
                d_o = torch.sum(torch.square(y_f - o)).cpu().numpy()
                # d_s = torch.mean(torch.square(y_r - d)).cpu().numpy()
                # d_o = torch.mean(torch.square(y_f - o)).cpu().numpy()
                
                dist_sal.append(d_s)
                dist.append(d_o)

                # inference_score1 = (d_s + d_o)/(1+TF_alpha)
                inference_score1 = ((1-TF_alpha)*d_s + TF_alpha*d_o)/(1+TF_alpha)
                inference_score2 = (d_s + TF_alpha*d_o)/(1+TF_alpha)
                fin_dist1.append(inference_score1)
                fin_dist2.append(inference_score2)
                # fin_dist.append((1-TF_alpha)*mse(y_s,d).item() + TF_alpha*mse(y_s, o).item())
                # fin_dist.append((TF_alpha*torch.cdist(y_s, o, p=2.0) + (1-TF_alpha)*torch.cdist(y_s, d, p=2.0)).cpu().numpy())

            guess.append(out.cpu().numpy())
            sal_list.append(sal.cpu().numpy())
        
            
    return (
        dist,
        dist_sal,
        fin_dist1,
        fin_dist2,
        np.concatenate(guess),
        np.concatenate(sal_list)
    )


def inference_DNN(dataloader, model, batch_size):
    ts, dist, att, guess_res, enc_list = [], [], [], [], []
    mse = torch.nn.MSELoss()
    with torch.no_grad():
        for i, (x,y) in enumerate(dataloader):  
            x = x.reshape(x.shape[0], x.shape[1]*x.shape[2]).cuda()
            y = y.reshape(y.shape[0], y.shape[1]*y.shape[2]).cuda()
            enc, guess = model(x)
            
            for y_s, g in zip(y, guess):
                dist.append(torch.sum(torch.abs(y_s - g)).cpu().numpy())  # Normal GRU

            guess_res.append(guess.cpu().numpy())
            enc_list.append(enc.cpu().numpy())
        
            
    return (
        dist,
        np.concatenate(guess_res),
        np.concatenate(enc_list)
    )

# %%
# %%time
MODEL.eval()
DIST, DIST_SAL, FIN_DIST1, FIN_DIST2, GUESS, SAL_LIST = inference_SAL(test_loader, MODEL, batch_size, TF_alpha=1.0)
DIST_train, DIST_SAL_train, FIN_DIST1_train, FIN_DIST2_train, GUESS_train, SAL_LIST_train = inference_SAL(train_loader, MODEL, batch_size, TF_alpha=1.0)
# Out:
# CPU times: user 20min 19s, sys: 33.4 s, total: 20min 52s
# Wall time: 29.2 s

# %%
from torch.autograd import Variable
import torch.nn.functional as F


def inference_decoder(ENC, trained_decoder, kernel_size):
    outputs, residuals, residual_recons = [], [], []

    # Average filter
    filter = torch.Tensor(np.ones((1, 1, kernel_size, kernel_size))/(kernel_size*kernel_size))
    print("filter:", filter)
    filter = Variable(filter)

    for i, enc in enumerate(ENC):
        x = torch.Tensor(enc.reshape(1,1,enc.shape[0],enc.shape[1]))

        input_v = Variable(x)
        output = F.conv2d(input_v, filter, padding=kernel_size//2)
        outputs.append(output.numpy())
        residuals.append(torch.abs(input_v - output).numpy())
        # k_size = 100
        # n_channels = 19
        # mean_conv = torch.nn.functional.conv2d(in_channels=n_channels,
        #                     out_channels=n_channels,
        #                     kernel_size=5,
        #                     padding=1,
        #                     bias=False,
        #                     stride=1)

        # Set kernel to calculate mean
        # kernel_weights = np.ones((k_size, n_channels))/k_size*n_channels
        # mean_conv.weight.data = torch.FloatTensor(kernel_weights).view(1, k_size, n_channels)
        # mean_conv.weight = torch.nn.Parameter(torch.ones((1,k_size,n_channels))/k_size*n_channels)
        # outputs.append(mean_conv(Variable(x)).numpy())



        # if i == 10:
        #     break

    outputs = np.array(outputs)
    outputs = outputs.reshape(outputs.shape[0],outputs.shape[3],outputs.shape[4]) 
    print(outputs.shape)

    residuals = np.array(residuals)
    residuals = residuals.reshape(residuals.shape[0],residuals.shape[3],residuals.shape[4]) 
    print(residuals.shape)

    print("Reconstructing with residuals")
    trained_decoder.eval()
    with torch.no_grad():
        for res in residuals:
            x = torch.Tensor(res.reshape(1, res.shape[0], res.shape[1]))[:, -1, :].cuda()
            dec_output = trained_decoder(x)
            residual_recons.append(dec_output.cpu().numpy())
    
    residual_recons = np.array(residual_recons)
    residual_recons = residual_recons.reshape(residual_recons.shape[0],residual_recons.shape[2],residual_recons.shape[3]) 
    print("residual_recons:", residual_recons.shape)
    
    return residuals, residual_recons

# %%
residuals, residual_recons = inference_decoder(ENC, trained_decoder, kernel_size=3)
residuals_FT, residual_recons_FT = inference_decoder(ENC_FT, trained_decoder, kernel_size=3)
# Out:
# filter: tensor([[[[0.1111, 0.1111, 0.1111],
#           [0.1111, 0.1111, 0.1111],
#           [0.1111, 0.1111, 0.1111]]]])
# (427517, 100, 12)
# (427517, 100, 12)
# Reconstructing with residuals
# residual_recons: (427517, 100, 25)
# filter: tensor([[[[0.1111, 0.1111, 0.1111],
#           [0.1111, 0.1111, 0.1111],
#           [0.1111, 0.1111, 0.1111]]]])
# (135083, 100, 12)
# (135083, 100, 12)
# Reconstructing with residuals
# residual_recons: (135083, 100, 25)

# %%
x_test_windowed, _ = split_series(x_test, 100, 1)
print(np.array(x_test_windowed).shape)
x_train_windowed, _ = split_series(x_train, 100, 1)
print(np.array(x_train_windowed).shape)

dist = []
for x_t, res in zip(x_test_windowed, residual_recons):
    dist.append(np.sum(np.abs(x_t - res)))
dist_ft = []
for x_t, res in zip(x_train_windowed, residual_recons_FT):
    dist_ft.append(np.sum(np.abs(x_t - res)))
# Out:
# (427517, 100, 25)
# (135083, 100, 25)

# %%
# 
res = SAL_LIST[:,-1:,:]
res = res.reshape(res.shape[0], res.shape[2])
res_mean = np.mean(res, axis=1)
FD1wSAL = np.array(FIN_DIST1)*res_mean

res_train = SAL_LIST_train[:,-1:,:]
res_train = res_train.reshape(res_train.shape[0], res_train.shape[2])
res_mean_train = np.mean(res_train, axis=1)
FD1wSAL_train = np.array(FIN_DIST1_train)*res_mean_train

# %%
res = SAL_LIST[:,-1:,:]
res = res.reshape(res.shape[0], res.shape[2])
res_mean = np.mean(res, axis=1)
FD2wSAL = np.array(FIN_DIST2)*res_mean

res_train = SAL_LIST_train[:,-1:,:]
res_train = res_train.reshape(res_train.shape[0], res_train.shape[2])
res_mean_train = np.mean(res_train, axis=1)
FD2wSAL_train = np.array(FIN_DIST2_train)*res_mean_train

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

plt.figure(figsize=(10,3))
res_plot = SAL_LIST[:,-1:,:]
res_plot = res_plot.reshape(res_plot.shape[0], res_plot.shape[2])
res_plot_mean = np.mean(res_plot, axis=1)
# plt.plot(res_plot_mean) 
# plt.plot(x_test[:,1:2])
# plt.plot(y_test*-1) 


sns.lineplot(data=res_plot_mean, legend=False)
sns.lineplot(data=x_test, legend=False)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,12))
res_plot = np.mean(GUESS[:,-1:,:], axis=2)
res_plot = res_plot.reshape(res_plot.shape[0], res_plot.shape[2])
res_plot_mean = np.mean(res_plot, axis=1)
plt.plot(res_plot)
plt.plot(y_test*-1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3215/2843145349.py in <module>
# ----> 1 plt.figure(figsize=(20,12))
#       2 res_plot = np.mean(GUESS[:,-1:,:], axis=2)
#       3 res_plot = res_plot.reshape(res_plot.shape[0], res_plot.shape[2])
#       4 res_plot_mean = np.mean(res_plot, axis=1)
#       5 plt.plot(res_plot)
#
# NameError: name 'plt' is not defined

# %%
from matplotlib import pyplot as plt 
plt.figure(figsize=(20,12))
total_len = len(x_test)

plt.plot(x_test[:total_len])
plt.plot(y_test[:total_len]*-1)

# %%
plt.figure(figsize=(20,12))
# plt.plot(DIST)
# plt.plot(DIST_SAL)

plt.plot(np.array(FD2wSAL))
# plt.plot(FIN_DIST2)
# plt.plot(np.array(FIN_DIST1) - np.array(FIN_DIST2))
plt.axis([-50, len(FIN_DIST1)+50, -100, 100])
plt.plot(y_test*-100)

# %%
from spot import SPOT, dSPOT
def adjust_predicts(score, label, threshold, pred=None, calc_latency=False):
    """
    Calculate adjusted predict labels using given `score`, `threshold` (or given `pred`) and `label`.
    Args:
            score (np.ndarray): The anomaly score
            label (np.ndarray): The ground-truth label
            threshold (float): The threshold of anomaly score.
                    A point is labeled as "anomaly" if its score is lower than the threshold.
            pred (np.ndarray or None): if not None, adjust `pred` and ignore `score` and `threshold`,
            calc_latency (bool):
    Returns:
            np.ndarray: predict labels

    Method from OmniAnomaly (https://github.com/NetManAIOps/OmniAnomaly)
    """
    if label is None:
        predict = score > threshold
        return predict, None

    if pred is None:
        if len(score) != len(label):
            raise ValueError("score and label must have the same length")
        predict = score > threshold
    else:
        predict = pred

    actual = label > 0.1
    anomaly_state = False
    anomaly_count = 0
    latency = 0

    for i in range(len(predict)):
        if any(actual[max(i, 0) : i + 1]) and predict[i] and not anomaly_state:
            anomaly_state = True
            anomaly_count += 1
            for j in range(i, 0, -1):
                if not actual[j]:
                    break
                else:
                    if not predict[j]:
                        predict[j] = True
                        latency += 1
        elif not actual[i]:
            anomaly_state = False
        if anomaly_state:
            predict[i] = True
    if calc_latency:
        return predict, latency / (anomaly_count + 1e-4)
    else:
        return predict

def calc_point2point(predict, actual):
    """
    calculate f1 score by predict and actual.
    Args:
            predict (np.ndarray): the predict label
            actual (np.ndarray): np.ndarray
    Method from OmniAnomaly (https://github.com/NetManAIOps/OmniAnomaly)
    """
    TP = np.sum(predict * actual)
    TN = np.sum((1 - predict) * (1 - actual))
    FP = np.sum(predict * (1 - actual))
    FN = np.sum((1 - predict) * actual)
    precision = TP / (TP + FP + 0.00001)
    recall = TP / (TP + FN + 0.00001)
    f1 = 2 * precision * recall / (precision + recall + 0.00001)
    return f1, precision, recall, TP, TN, FP, FN

def pot_eval(init_score, score, label, q=1e-3, level=0.99, dynamic=False):
    """
    Run POT method on given score.
    :param init_score (np.ndarray): The data to get init threshold.
                    For `OmniAnomaly`, it should be the anomaly score of train set.
    :param: score (np.ndarray): The data to run POT method.
                    For `OmniAnomaly`, it should be the anomaly score of test set.
    :param label (np.ndarray): boolean list of true anomalies in score
    :param q (float): Detection level (risk)
    :param level (float): Probability associated with the initial threshold t
    :return dict: pot result dict
    Method from OmniAnomaly (https://github.com/NetManAIOps/OmniAnomaly)
    """

    print(f"Running POT with q={q}, level={level}..")
    s = SPOT(q)  # SPOT object
    s.fit(init_score, score)
    s.initialize(level=level, min_extrema=False)  # Calibration step
    ret = s.run(dynamic=dynamic, with_alarm=False)

    print(len(ret["alarms"]))
    print(len(ret["thresholds"]))

    pot_th = np.mean(ret["thresholds"])
    pred, p_latency = adjust_predicts(score, label, pot_th, calc_latency=True)

    plt.figure(figsize=(20,12))
    plt.plot(score)
    plt.plot(label*-50)
    plt.plot(pred*-50, alpha=0.5)
    if dynamic:
        plt.plot(ret["thresholds"])
    else:
        plt.axhline(y=pot_th, color='r', linestyle='-')
    plt.axis([-50, len(score)+50, -100, 100])
    plt.show()


    if label is not None:
        p_t = calc_point2point(pred, label)
        return {
            "f1": p_t[0],
            "precision": p_t[1],
            "recall": p_t[2],
            "TP": p_t[3],
            "TN": p_t[4],
            "FP": p_t[5],
            "FN": p_t[6],
            "threshold": pot_th,
            "latency": p_latency,
        }
    else:
        return {
            "threshold": pot_th,
        }

# %%
window_size = 100
batch_size = 256

train_dataset = ReconDataset(x_train[:-100], window_size, 1)
test_dataset = ReconDataset(x_test[:-100], window_size, 1)
train_loader, val_loader, test_loader = create_data_loaders(train_dataset, batch_size, val_split=0.0, shuffle=False, test_dataset=test_dataset)
print(len(y_test))
print(len(FIN_DIST))
# Out:
# train_size: 58117
# test_size: 73529
# 73729
# 73629

# %%
latency = 1
pot_th = pot_eval(DIST_train[:-latency], DIST[:-latency], label=y_test[latency:-(len(y_test)-len(DIST))], q=0.01, level=0.99, dynamic=False)
pot_th
# Out:
# Running POT with q=0.01, level=0.99..
# Initial threshold : 7.002267
# Number of peaks : 404
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = 0
# 	σ = 0.41541195
# 	L = 49.09222057851299
# Extreme quantile (probability = 0.01): 7.001783888468453
# 100%|██████████| 73215/73215 [00:00<00:00, 1779259.57it/s]
# 0
# 73215
# {'f1': 0.7717254109703255,
#  'precision': 0.7903314149680479,
#  'recall': 0.7539848435406522,
#  'TP': 5771,
#  'TN': 64030,
#  'FP': 1531,
#  'FN': 1883,
#  'threshold': 7.001783888468453,
#  'latency': 77.13281911453923}

# %%
latency = 1
pot_th = pot_eval(FIN_DIST2_train[:-latency], FIN_DIST2[:-latency], label=y_test[latency:-(len(y_test)-len(FIN_DIST2))], q=0.01, level=0.9, dynamic=False)
pot_th
# Out:
# Running POT with q=0.01, level=0.9..
# Initial threshold : 21.370809078216553
# Number of peaks : 4044
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = 0
# 	σ = 4.520541374748951
# 	L = 10144.906836819055
# Extreme quantile (probability = 0.01): 31.77895784031177
# 100%|██████████| 73215/73215 [00:00<00:00, 2147349.20it/s]
# 0
# 73215
# {'f1': 0.2770430412426133,
#  'precision': 0.3770528675431882,
#  'recall': 0.21897047266923117,
#  'TP': 1676,
#  'TN': 62792,
#  'FP': 2769,
#  'FN': 5978,
#  'threshold': 31.778957840311765,
#  'latency': 124.83125281245313}

# %%
latency = 1   
pot_th = pot_eval(FD1wSAL_train[:-latency], FD1wSAL[:-latency], label=y_test[latency:-(len(y_test)-len(FD1wSAL))], q=1e-3, level=0.2, dynamic=False)
pot_th
# Out:
# Running POT with q=0.001, level=0.2..
# Initial threshold : 0.009188617607710059
# Number of peaks : 32357
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = -0.32455782563964997
# 	σ = 0.3224953968802675
# 	L = 14762.047789570384
# Extreme quantile (probability = 0.001): 0.889329434106069
# 100%|██████████| 73215/73215 [00:00<00:00, 2053990.56it/s]
# 0
# 73215
# {'f1': 0.26074148015100446,
#  'precision': 0.8689859299112811,
#  'recall': 0.15338385138047578,
#  'TP': 1174,
#  'TN': 65384,
#  'FP': 177,
#  'FN': 6480,
#  'threshold': 0.8893294341060687,
#  'latency': 46.24884377890553}

# %%
latency = 1   
pot_th = pot_eval(FD2wSAL_train[:-latency], FD2wSAL[:-latency], label=y_test[latency:-(len(y_test)-len(FD2wSAL))], q=0.1, level=0.1, dynamic=False)
pot_th
# Out:
# Running POT with q=0.1, level=0.1..
# Initial threshold : 0.5665296206027968
# Number of peaks : 36402
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = 0
# 	σ = 2.890202447411614
# 	L = 75036.40909779376
# Extreme quantile (probability = 0.1): 6.916929652589934
# 100%|██████████| 73215/73215 [00:00<00:00, 571462.01it/s]
# 0
# 73215
# {'f1': 0.3938814813606541,
#  'precision': 0.3051090698155073,
#  'recall': 0.5555265213541593,
#  'TP': 4252,
#  'TN': 55877,
#  'FP': 9684,
#  'FN': 3402,
#  'threshold': 6.91692965258993,
#  'latency': 16.166531945567122}

# %%
pot_th = pot_eval(FD1wSAL_train, FD1wSAL, label=y_test[:-(len(y_test)-len(FD1wSAL))], q=0.01, level=0.99, dynamic=False)
pot_th
# Out:
# Running POT with q=0.01, level=0.99..
# Initial threshold : 0.737727048279222
# Number of peaks : 404
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = -0.16156915529690286
# 	σ = 0.05953917992571149
# 	L = 801.0067003243196
# Extreme quantile (probability = 0.01): 0.7376563438677056
# 100%|██████████| 73216/73216 [00:00<00:00, 1917875.10it/s]
# 0
# 73216
# {'f1': 0.7490512404025241,
#  'precision': 0.8234925593993853,
#  'recall': 0.686961065211705,
#  'TP': 5258,
#  'TN': 64435,
#  'FP': 1127,
#  'FN': 2396,
#  'threshold': 0.7376563438677054,
#  'latency': 96.91585903450805}

# %%
latency = 1
pot_th = pot_eval(FD1wSAL_train[:-latency], FD1wSAL[:-latency], label=y_test[latency:-(len(y_test)-len(FD1wSAL))], q=0.01, level=0.99, dynamic=False)
print(pot_th)
latency = int(pot_th['latency'])
pot_th = pot_eval(FD1wSAL_train[:-latency], FD1wSAL[:-latency], label=y_test[latency:-(len(y_test)-len(FD1wSAL))], q=0.01, level=0.99, dynamic=False)
print(pot_th)
# Out:
# Running POT with q=0.01, level=0.99..
# Initial threshold : 0.737727048279222
# Number of peaks : 404
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = -0.16156915529690286
# 	σ = 0.05953917992571149
# 	L = 801.0067003243196
# Extreme quantile (probability = 0.01): 0.7376578161585676
# 100%|██████████| 73215/73215 [00:00<00:00, 2100451.21it/s]
# 0
# 73215
# {'f1': 0.7491579665099355, 'precision': 0.8237505862075034, 'recall': 0.686961065211705, 'TP': 5258, 'TN': 64436, 'FP': 1125, 'FN': 2396, 'threshold': 0.7376578161585676, 'latency': 97.7491854234548}
# Running POT with q=0.01, level=0.99..
# Initial threshold : 0.737544077774448
# Number of peaks : 403
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = -0.1628271809157542
# 	σ = 0.05982162705617604
# 	L = 797.6237287697745
# Extreme quantile (probability = 0.01): 0.7374684130575138
# 100%|██████████| 73119/73119 [00:00<00:00, 2115713.94it/s]
# 0
# 73119
# {'f1': 0.810790973892006, 'precision': 0.8546402188292455, 'recall': 0.7712307280229543, 'TP': 5903, 'TN': 64461, 'FP': 1004, 'FN': 1751, 'threshold': 0.7374684130575134, 'latency': 99.05824083387745}

# %%
latency = 1
pot_th = pot_eval(FIN_DIST1_train[:-latency], FIN_DIST1[:-latency], label=y_test[latency:-(len(y_test)-len(FIN_DIST1))], q=0.01, level=0.99, dynamic=False)
pot_th
# Out:
# Running POT with q=0.01, level=0.99..
# Initial threshold : 3.8317692279815674
# Number of peaks : 578
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = 0
# 	σ = 0.4823286904595715
# 	L = 156.56316811655176
# Extreme quantile (probability = 0.01): 3.831310482921258
# 100%|██████████| 73215/73215 [00:00<00:00, 1628075.47it/s]
# 0
# 73215
# {'f1': 0.7525832668278384,
#  'precision': 0.7647693542422858,
#  'recall': 0.7407891288988906,
#  'TP': 5670,
#  'TN': 63817,
#  'FP': 1744,
#  'FN': 1984,
#  'threshold': 3.8313104829212596,
#  'latency': 64.92810765637388}

# %%
from scipy import signal
b, a = signal.butter(1, 0.1, btype='lowpass')
ANOMALY_SCORE_smooth = signal.filtfilt(b,a,FIN_DIST1)
ANOMALY_SCORE_smooth_train = signal.filtfilt(b,a,FIN_DIST1_train)

# %%
latency = 1
pot_th = pot_eval(ANOMALY_SCORE_smooth_train[:-latency], ANOMALY_SCORE_smooth[:-latency], label=y_test[latency:-(len(y_test)-len(ANOMALY_SCORE_smooth))], q=0.01, level=0.99, dynamic=False)
pot_th
# Out:
# Running POT with q=0.01, level=0.99..
# Initial threshold : 33.6326588213243
# Number of peaks : 578
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = 0
# 	σ = 1.1941968730487602
# 	L = 680.579906500342
# Extreme quantile (probability = 0.01): 33.63152301512536
# 100%|██████████| 73215/73215 [00:00<00:00, 2164726.72it/s]
# 0
# 73215
# {'f1': 0.03894966295865868,
#  'precision': 0.08711433717280245,
#  'recall': 0.025084922883348678,
#  'TP': 192,
#  'TN': 63549,
#  'FP': 2012,
#  'FN': 7462,
#  'threshold': 33.63152301512536,
#  'latency': 0.0}

# %%
import more_itertools as mit

def epsilon_eval(train_scores, test_scores, test_labels, reg_level=1):
    best_epsilon = find_epsilon(train_scores, reg_level)
    pred, p_latency = adjust_predicts(test_scores, test_labels, best_epsilon, calc_latency=True)
    if test_labels is not None:
        p_t = calc_point2point(pred, test_labels)
        return {
            "f1": p_t[0],
            "precision": p_t[1],
            "recall": p_t[2],
            "TP": p_t[3],
            "TN": p_t[4],
            "FP": p_t[5],
            "FN": p_t[6],
            "threshold": best_epsilon,
            "latency": p_latency,
            "reg_level": reg_level,
        }
    else:
        return {"threshold": best_epsilon, "reg_level": reg_level}


def find_epsilon(errors, reg_level=1):
    """
    Threshold method proposed by Hundman et. al. (https://arxiv.org/abs/1802.04431)
    Code from TelemAnom (https://github.com/khundman/telemanom)
    """
    e_s = errors
    best_epsilon = None
    max_score = -10000000
    mean_e_s = np.mean(e_s)
    sd_e_s = np.std(e_s)

    for z in np.arange(2.5, 12, 0.5):
        epsilon = mean_e_s + sd_e_s * z
        pruned_e_s = e_s[e_s < epsilon]

        i_anom = np.argwhere(e_s >= epsilon).reshape(-1,)
        buffer = np.arange(1, 50)
        i_anom = np.sort(
            np.concatenate(
                (
                    i_anom,
                    np.array([i + buffer for i in i_anom]).flatten(),
                    np.array([i - buffer for i in i_anom]).flatten(),
                )
            )
        )
        i_anom = i_anom[(i_anom < len(e_s)) & (i_anom >= 0)]
        i_anom = np.sort(np.unique(i_anom))

        if len(i_anom) > 0:
            groups = [list(group) for group in mit.consecutive_groups(i_anom)]
            # E_seq = [(g[0], g[-1]) for g in groups if not g[0] == g[-1]]

            mean_perc_decrease = (mean_e_s - np.mean(pruned_e_s)) / mean_e_s
            sd_perc_decrease = (sd_e_s - np.std(pruned_e_s)) / sd_e_s
            if reg_level == 0:
                denom = 1
            elif reg_level == 1:
                denom = len(i_anom)
            elif reg_level == 2:
                denom = len(i_anom) ** 2

            score = (mean_perc_decrease + sd_perc_decrease) / denom

            if score >= max_score and len(i_anom) < (len(e_s) * 0.5):
                max_score = score
                best_epsilon = epsilon

    if best_epsilon is None:
        best_epsilon = np.max(e_s)
    return best_epsilon


def bf_search(score, label, start, end=None, step_num=1, display_freq=1, verbose=True):
    """
    Find the best-f1 score by searching best `threshold` in [`start`, `end`).
    Method from OmniAnomaly (https://github.com/NetManAIOps/OmniAnomaly)
    """

    print(f"Finding best f1-score by searching for threshold..")
    if step_num is None or end is None:
        end = start
        step_num = 1
    search_step, search_range, search_lower_bound = step_num, end - start, start
    if verbose:
        print("search range: ", search_lower_bound, search_lower_bound + search_range)
    threshold = search_lower_bound
    m = (-1.0, -1.0, -1.0)
    m_t = 0.0
    m_l = 0
    for i in range(search_step):
        threshold += search_range / float(search_step)
        target, latency = calc_seq(score, label, threshold)
        if target[0] > m[0]:
            m_t = threshold
            m = target
            m_l = latency
        if verbose and i % display_freq == 0:
            print("cur thr: ", threshold, target, m, m_t)

    return {
        "f1": m[0],
        "precision": m[1],
        "recall": m[2],
        "TP": m[3],
        "TN": m[4],
        "FP": m[5],
        "FN": m[6],
        "threshold": m_t,
        "latency": m_l,
    }


def calc_seq(score, label, threshold):
    predict, latency = adjust_predicts(score, label, threshold, calc_latency=True)
    return calc_point2point(predict, label), latency

# %%
best_valid_metrics = {}
t, th = bf_search(test_score, y_test[-len(test_score):],
                                      start=config.bf_search_min,
                                      end=config.bf_search_max,
                                      step_num=int(abs(config.bf_search_max - config.bf_search_min) /
                                                   config.bf_search_step_size),
                                      display_freq=50)
# get pot results
pot_result = pot_eval(train_score, test_score, y_test[-len(test_score):], level=config.level)

# output the results
best_valid_metrics.update({
    'best-f1': t[0],
    'precision': t[1],
    'recall': t[2],
    'TP': t[3],
    'TN': t[4],
    'FP': t[5],
    'FN': t[6],
    'latency': t[-1],
    'threshold': th
})
best_valid_metrics.update(pot_result)

# %%
dataset = 'MSL'
group = '1'
reg_level_dict = {"SMAP": 0, "MSL": 0, "SMD-1": 1, "SMD-2": 1, "SMD-3": 1}
key = "SMD-" + group if dataset == "SMD" else dataset
reg_level = reg_level_dict[key]

FD1wSAL_train = np.array(FD1wSAL_train)
FD1wSAL = np.array(FD1wSAL)
e_eval = epsilon_eval(FD1wSAL_train, FD1wSAL, y_test[:-(len(y_test)-len(FD1wSAL))], reg_level=reg_level)
print("e_eval:", e_eval)

bf_eval = bf_search(FD1wSAL, y_test[:-(len(y_test)-len(FD1wSAL))], start=0, end=200, step_num=100, verbose=False)
print("bf_eval;", bf_eval)
# Out:
# e_eval: {'f1': 0.6030345550057847, 'precision': 0.49670162339588836, 'recall': 0.7673112088224312, 'TP': 5873, 'TN': 59611, 'FP': 5951, 'FN': 1781, 'threshold': 1.1618808547432227, 'latency': 42.999747060311414, 'reg_level': 0}
# Finding best f1-score by searching for threshold..
# bf_eval; {'f1': 0.6565492040918467, 'precision': 0.9156147711182451, 'recall': 0.5117585569483165, 'TP': 3917, 'TN': 65201, 'FP': 361, 'FN': 3737, 'threshold': 2.0, 'latency': 326.28105312781247}

# %%
dataset = 'MSL'
group = '1'
reg_level_dict = {"SMAP": 0, "MSL": 0, "SMD-1": 1, "SMD-2": 1, "SMD-3": 1}
key = "SMD-" + group if dataset == "SMD" else dataset
reg_level = reg_level_dict[key]

FIN_DIST1_train = np.array(FIN_DIST1_train)
FIN_DIST1 = np.array(FIN_DIST1)
e_eval = epsilon_eval(FIN_DIST1_train, FIN_DIST1, y_test[:-(len(y_test)-len(FIN_DIST1))], reg_level=reg_level)
print("e_eval:", e_eval)

bf_eval = bf_search(FIN_DIST1, y_test[:-(len(y_test)-len(FIN_DIST1))], start=0, end=200, step_num=100, verbose=False)
print("bf_eval;", bf_eval)

p_eval = pot_eval(FIN_DIST1_train, FIN_DIST1, y_test[:-(len(y_test)-len(FIN_DIST1))],
                    q=0.01, level=0.9, dynamic=True)
print("p_eval:", p_eval)
# Out:
# e_eval: {'f1': 0.742653302451278, 'precision': 0.6970773630979056, 'recall': 0.7946171925860763, 'TP': 6082, 'TN': 62919, 'FP': 2643, 'FN': 1572, 'threshold': 3.591116697218308, 'latency': 43.44420308776063, 'reg_level': 0}
# Finding best f1-score by searching for threshold..
# bf_eval; {'f1': 0.7191525181934691, 'precision': 0.7961611662497444, 'recall': 0.6557355622475365, 'TP': 5019, 'TN': 64277, 'FP': 1285, 'FN': 2635, 'threshold': 4.0, 'latency': 68.38408935315883}
# Running POT with q=0.01, level=0.9..
# Initial threshold : 2.6148886680603027
# Number of peaks : 5785
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = 0
# 	σ = 0.5741386235945165
# 	L = 2574.9937037693303
# Extreme quantile (probability = 0.01): 3.9368321594957116
# 100%|██████████| 73216/73216 [06:19<00:00, 193.10it/s]
# 0
# 73216
# p_eval: {'f1': 0.04564300247853736, 'precision': 0.6534295792985712, 'recall': 0.023647765843156827, 'TP': 181, 'TN': 65466, 'FP': 96, 'FN': 7473, 'threshold': 45.89773801041539, 'latency': 0.0}

# %%
pot_th = pot_eval(FIN_DIST_train, FIN_DIST, label=y_test[:-(len(y_test)-len(FIN_DIST))], q=0.05, level=0.99, dynamic=True)
pot_th
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2053/3611097649.py in <module>
# ----> 1 pot_th = pot_eval(FIN_DIST_train, FIN_DIST, label=y_test[:-(len(y_test)-len(FIN_DIST))], q=0.05, level=0.99, dynamic=True)
#       2 pot_th
#
# NameError: name 'pot_eval' is not defined

# %%
pot_th = pot_eval(DIST_SAL_train, DIST_SAL, label=y_test[:len(y_test)-100], q=1e-2, level=0.99, dynamic=False)
pot_th
# Out:
# Running POT with q=0.01, level=0.99..
# Initial threshold : 132.33325
# Number of peaks : 582
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = 0
# 	σ = 4.6696057
# 	L = 1478.905441884447
# Extreme quantile (probability = 0.01): 132.33188817810918
# 100%|██████████| 73629/73629 [00:00<00:00, 2149017.49it/s]
# 0
# 73629
# {'f1': 0.28107621036246055,
#  'precision': 0.5425414344657774,
#  'recall': 0.18967293305476057,
#  'TP': 1473,
#  'TN': 64621,
#  'FP': 1242,
#  'FN': 6293,
#  'threshold': 132.33188817810924,
#  'latency': 243.99186693776872}

# %% [markdown]
# ### Concat input and train

# %%
window_size = 100
batch_size = 128

temp_FT = residual_recons_FT[:,-1:,:]
res_train = temp_FT.reshape(temp_FT.shape[0], temp_FT.shape[2])
temp = residual_recons[:,-1:,:]
res_test = temp.reshape(temp.shape[0], temp.shape[2])


res_train_dataset = ReconDataset(res_train, window_size, 1)
res_test_dataset = ReconDataset(res_test, window_size, 1)
res_train_loader, res_val_loader, res_test_loader = create_data_loaders(res_train_dataset, batch_size, val_split=0.0, shuffle=False, test_dataset=res_test_dataset)
# Out:
# train_size: 134983
# test_size: 427417

# %%
def train_concat(dataloader, res_dataloader, model, batch_size, n_epochs):
    # dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    optimizer = torch.optim.AdamW(model.parameters())
    loss_fn = torch.nn.MSELoss()
    epochs = range(n_epochs)
    best = {"loss": sys.float_info.max}
    loss_history = []
    for e in epochs:
        epoch_loss = 0
        for i, ((x,y), (res_x, res_y)) in enumerate(zip(dataloader, res_dataloader)):  
            optimizer.zero_grad()
            x = x.cuda()
            res_x = res_x.cuda()
            x_res = torch.cat([x, res_x], dim=2)
            enc_output, guess = model(x_res)  # AE
            y = y.cuda()
            # res_y = res_y.cuda()
            # y_res = torch.cat([y, res_y], dim=2)

            loss = loss_fn(y, guess)
            loss.backward()
            epoch_loss += loss.item()
            optimizer.step()
        loss_history.append(epoch_loss)
#         epochs.set_postfix_str(f"loss: {epoch_loss:.6f}")
        
        print(f'Training loss EPOCH: [{e+1}|{len(epochs)}], training loss: [{epoch_loss}]')
        if epoch_loss < best["loss"]:
            best["state"] = model.state_dict()
            best["loss"] = epoch_loss
            best["epoch"] = e + 1
    return best, loss_history

# %%
MODEL = RecurrentAutoencoder(seq_len=window_size, n_features=x_train.shape[1]*2, out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2))
MODEL.cuda()
# Out:
# RecurrentAutoencoder(
#   (encoder): RecurEncoder(
#     (rnn1): LSTM(50, 24, batch_first=True)
#     (rnn2): LSTM(24, 12, batch_first=True)
#   )
#   (decoder): RecurDecoder(
#     (rnn1): LSTM(12, 12, batch_first=True)
#     (rnn2): LSTM(12, 24, batch_first=True)
#     (output_layer): Linear(in_features=24, out_features=25, bias=True)
#     (timedist): TimeDistributed(
#       (module): Linear(in_features=24, out_features=25, bias=True)
#     )
#   )
# )

# %%
BEST_MODEL, LOSS_HISTORY = train_concat(train_loader, res_train_loader, MODEL, batch_size, 1000)
with open("result/model_VANLSTMAE_saliency_res_SMAP.pt", "wb") as f:
    torch.save(
        {
            "state": BEST_MODEL["state"],
            "best_epoch": BEST_MODEL["epoch"],
            "loss_history": LOSS_HISTORY,
        },
        f,
    )
# Out:
# Training loss EPOCH: [1|1000], training loss: [4.732401983987074]
# Training loss EPOCH: [2|1000], training loss: [4.6379594555764925]
# Training loss EPOCH: [3|1000], training loss: [4.497341679467354]
# Training loss EPOCH: [4|1000], training loss: [4.349543998760055]
# Training loss EPOCH: [5|1000], training loss: [4.349176435527625]
# Training loss EPOCH: [6|1000], training loss: [4.347822166411788]
# Training loss EPOCH: [7|1000], training loss: [4.378227562236134]
# Training loss EPOCH: [8|1000], training loss: [4.33640863441542]
# Training loss EPOCH: [9|1000], training loss: [4.311939880484715]
# Training loss EPOCH: [10|1000], training loss: [4.3115411050239345]
# Training loss EPOCH: [11|1000], training loss: [4.298871330844122]
# Training loss EPOCH: [12|1000], training loss: [4.290227390414657]
# Training loss EPOCH: [13|1000], training loss: [4.281493877533649]
# Training loss EPOCH: [14|1000], training loss: [4.290150342378183]
# Training loss EPOCH: [15|1000], training loss: [4.308580595636158]
# Training loss EPOCH: [16|1000], training loss: [4.294807319980464]
# Training loss EPOCH: [17|1000], training loss: [4.2445441657582705]
# Training loss EPOCH: [18|1000], training loss: [4.210876061297313]
# Training loss EPOCH: [19|1000], training loss: [4.200380695412605]
# Training loss EPOCH: [20|1000], training loss: [4.193691072443471]
# Training loss EPOCH: [21|1000], training loss: [4.1947099702283595]
# Training loss EPOCH: [22|1000], training loss: [4.240633366673137]
# Training loss EPOCH: [23|1000], training loss: [4.147257145317781]
# Training loss EPOCH: [24|1000], training loss: [4.13366572162704]
# Training loss EPOCH: [25|1000], training loss: [4.129941038161633]
# Training loss EPOCH: [26|1000], training loss: [4.124922362680081]
# Training loss EPOCH: [27|1000], training loss: [4.110137917727116]
# Training loss EPOCH: [28|1000], training loss: [4.097501976426429]
# Training loss EPOCH: [29|1000], training loss: [4.095650352195662]
# Training loss EPOCH: [30|1000], training loss: [4.104665146891421]
# Training loss EPOCH: [31|1000], training loss: [4.094262438617079]
# Training loss EPOCH: [32|1000], training loss: [4.081027197982621]
# Training loss EPOCH: [33|1000], training loss: [4.105407205393931]
# Training loss EPOCH: [34|1000], training loss: [4.08313161467413]
# Training loss EPOCH: [35|1000], training loss: [4.081151749192031]
# Training loss EPOCH: [36|1000], training loss: [4.094163989486333]
# Training loss EPOCH: [37|1000], training loss: [4.076480346012431]
# Training loss EPOCH: [38|1000], training loss: [4.092936990588896]
# Training loss EPOCH: [39|1000], training loss: [4.0992497744337015]
# Training loss EPOCH: [40|1000], training loss: [4.0881831713086285]
# Training loss EPOCH: [41|1000], training loss: [4.097536438651332]
# Training loss EPOCH: [42|1000], training loss: [4.095305159818054]
# Training loss EPOCH: [43|1000], training loss: [4.080292716614167]
# Training loss EPOCH: [44|1000], training loss: [4.07338743001992]
# Training loss EPOCH: [45|1000], training loss: [4.075954341007673]
# Training loss EPOCH: [46|1000], training loss: [4.095229493465013]
# Training loss EPOCH: [47|1000], training loss: [4.099632505626687]
# Training loss EPOCH: [48|1000], training loss: [4.076959560137311]
# Training loss EPOCH: [49|1000], training loss: [4.070989475436363]
# Training loss EPOCH: [50|1000], training loss: [4.072714533696853]
# Training loss EPOCH: [51|1000], training loss: [4.0741031629127065]
# Training loss EPOCH: [52|1000], training loss: [4.084033741966778]
# Training loss EPOCH: [53|1000], training loss: [4.070883149753172]
# Training loss EPOCH: [54|1000], training loss: [4.093959944976177]
# Training loss EPOCH: [55|1000], training loss: [4.114627707090676]
# Training loss EPOCH: [56|1000], training loss: [4.071033853178051]
# Training loss EPOCH: [57|1000], training loss: [4.066610951123948]
# Training loss EPOCH: [58|1000], training loss: [4.066871621091195]
# Training loss EPOCH: [59|1000], training loss: [4.074035591732354]
# Training loss EPOCH: [60|1000], training loss: [4.080527277510555]
# Training loss EPOCH: [61|1000], training loss: [4.087525320376699]
# Training loss EPOCH: [62|1000], training loss: [4.06941926766649]
# Training loss EPOCH: [63|1000], training loss: [4.069308680391714]
# Training loss EPOCH: [64|1000], training loss: [4.069308171231569]
# Training loss EPOCH: [65|1000], training loss: [4.074758391057003]
# Training loss EPOCH: [66|1000], training loss: [4.073071568929208]
# Training loss EPOCH: [67|1000], training loss: [4.067381766373728]
# Training loss EPOCH: [68|1000], training loss: [4.066630141636324]
# Training loss EPOCH: [69|1000], training loss: [4.073830275808632]
# Training loss EPOCH: [70|1000], training loss: [4.0864312715025335]
# Training loss EPOCH: [71|1000], training loss: [4.092758655026046]
# Training loss EPOCH: [72|1000], training loss: [4.065496679899297]
# Training loss EPOCH: [73|1000], training loss: [4.06881784955317]
# Training loss EPOCH: [74|1000], training loss: [4.067310894321963]
# Training loss EPOCH: [75|1000], training loss: [4.065790556048569]
# Training loss EPOCH: [76|1000], training loss: [4.066603205743377]
# Training loss EPOCH: [77|1000], training loss: [4.085987418803143]
# Training loss EPOCH: [78|1000], training loss: [4.079847176160001]
# Training loss EPOCH: [79|1000], training loss: [4.06446302306631]
# Training loss EPOCH: [80|1000], training loss: [4.064503365256769]
# Training loss EPOCH: [81|1000], training loss: [4.063533847036524]
# Training loss EPOCH: [82|1000], training loss: [4.057667588395816]
# Training loss EPOCH: [83|1000], training loss: [4.057591766582391]
# Training loss EPOCH: [84|1000], training loss: [4.063853379973807]
# Training loss EPOCH: [85|1000], training loss: [4.046297043935738]
# Training loss EPOCH: [86|1000], training loss: [4.050044544146658]
# Training loss EPOCH: [87|1000], training loss: [4.105203985897674]
# Training loss EPOCH: [88|1000], training loss: [4.092206227020142]
# Training loss EPOCH: [89|1000], training loss: [4.015554556501229]
# Training loss EPOCH: [90|1000], training loss: [3.990098422727897]
# Training loss EPOCH: [91|1000], training loss: [3.9737136649732747]
# Training loss EPOCH: [92|1000], training loss: [3.9640965400071764]
# Training loss EPOCH: [93|1000], training loss: [3.9420552465139735]
# Training loss EPOCH: [94|1000], training loss: [3.9568860954582306]
# Training loss EPOCH: [95|1000], training loss: [3.9434309158186807]
# Training loss EPOCH: [96|1000], training loss: [3.915238145049898]
# Training loss EPOCH: [97|1000], training loss: [3.9331981365735373]
# Training loss EPOCH: [98|1000], training loss: [3.925075690842732]
# Training loss EPOCH: [99|1000], training loss: [3.9153821177746977]
# Training loss EPOCH: [100|1000], training loss: [3.8973569548484193]
# Training loss EPOCH: [101|1000], training loss: [3.767633483629652]
# Training loss EPOCH: [102|1000], training loss: [3.718651339518374]
# Training loss EPOCH: [103|1000], training loss: [3.6824591512202005]
# Training loss EPOCH: [104|1000], training loss: [3.6506849160527963]
# Training loss EPOCH: [105|1000], training loss: [3.700534081218393]
# Training loss EPOCH: [106|1000], training loss: [3.6122405191235885]
# Training loss EPOCH: [107|1000], training loss: [3.536454622358633]
# Training loss EPOCH: [108|1000], training loss: [3.46932925978399]
# Training loss EPOCH: [109|1000], training loss: [3.4920171881094575]
# Training loss EPOCH: [110|1000], training loss: [3.466233066503264]
# Training loss EPOCH: [111|1000], training loss: [3.3889303418245618]
# Training loss EPOCH: [112|1000], training loss: [3.2661308462493253]
# Training loss EPOCH: [113|1000], training loss: [3.2258186605849914]
# Training loss EPOCH: [114|1000], training loss: [3.139372437282873]
# Training loss EPOCH: [115|1000], training loss: [3.1032201637085564]
# Training loss EPOCH: [116|1000], training loss: [3.125025952969736]
# Training loss EPOCH: [117|1000], training loss: [3.1029493982605345]
# Training loss EPOCH: [118|1000], training loss: [3.0429301161866533]
# Training loss EPOCH: [119|1000], training loss: [3.0512491436811615]
# Training loss EPOCH: [120|1000], training loss: [3.1013759264242253]
# Training loss EPOCH: [121|1000], training loss: [3.0653308873643255]
# Training loss EPOCH: [122|1000], training loss: [3.0243264437203834]
# Training loss EPOCH: [123|1000], training loss: [2.9712180601445652]
# Training loss EPOCH: [124|1000], training loss: [3.0148059640528118]
# Training loss EPOCH: [125|1000], training loss: [2.9909919008214274]
# Training loss EPOCH: [126|1000], training loss: [2.9919008932031375]
# Training loss EPOCH: [127|1000], training loss: [2.974790381870662]
# Training loss EPOCH: [128|1000], training loss: [2.956868253810171]
# Training loss EPOCH: [129|1000], training loss: [2.912694040887345]
# Training loss EPOCH: [130|1000], training loss: [3.5600941352745394]
# Training loss EPOCH: [131|1000], training loss: [3.213306912482949]
# Training loss EPOCH: [132|1000], training loss: [3.0291940253518987]
# Training loss EPOCH: [133|1000], training loss: [2.902217776542784]
# Training loss EPOCH: [134|1000], training loss: [2.928117517616556]
# Training loss EPOCH: [135|1000], training loss: [3.034776766576215]
# Training loss EPOCH: [136|1000], training loss: [2.870318563059527]
# Training loss EPOCH: [137|1000], training loss: [2.908584359843644]
# Training loss EPOCH: [138|1000], training loss: [2.9046725845596484]
# Training loss EPOCH: [139|1000], training loss: [2.868641727684917]
# Training loss EPOCH: [140|1000], training loss: [2.912827404364407]
# Training loss EPOCH: [141|1000], training loss: [2.7951112289665616]
# Training loss EPOCH: [142|1000], training loss: [2.7535342996336567]
# Training loss EPOCH: [143|1000], training loss: [2.7701089401816716]
# Training loss EPOCH: [144|1000], training loss: [2.7706525849262107]
# Training loss EPOCH: [145|1000], training loss: [2.81209023953852]
# Training loss EPOCH: [146|1000], training loss: [2.9106103303502096]
# Training loss EPOCH: [147|1000], training loss: [2.8299733649910195]
# Training loss EPOCH: [148|1000], training loss: [2.8581774328413303]
# Training loss EPOCH: [149|1000], training loss: [2.7588228787717526]
# Training loss EPOCH: [150|1000], training loss: [2.6989329763891874]
# Training loss EPOCH: [151|1000], training loss: [2.7385209814383416]
# Training loss EPOCH: [152|1000], training loss: [2.9267802281501645]
# Training loss EPOCH: [153|1000], training loss: [2.958771651742609]
# Training loss EPOCH: [154|1000], training loss: [2.7017037358473317]
# Training loss EPOCH: [155|1000], training loss: [2.7265451294442755]
# Training loss EPOCH: [156|1000], training loss: [2.658225217172003]
# Training loss EPOCH: [157|1000], training loss: [2.7516782278098617]
# Training loss EPOCH: [158|1000], training loss: [2.6697288481902888]
# Training loss EPOCH: [159|1000], training loss: [2.675587051002367]
# Training loss EPOCH: [160|1000], training loss: [2.6145260948146642]
# Training loss EPOCH: [161|1000], training loss: [2.6368826203608933]
# Training loss EPOCH: [162|1000], training loss: [2.592665881049925]
# Training loss EPOCH: [163|1000], training loss: [2.669374530127925]
# Training loss EPOCH: [164|1000], training loss: [2.7341235007679643]
# Training loss EPOCH: [165|1000], training loss: [2.6546345019078217]
# Training loss EPOCH: [166|1000], training loss: [2.57580469476261]
# Training loss EPOCH: [167|1000], training loss: [2.747850347817348]
# Training loss EPOCH: [168|1000], training loss: [2.6979764449456525]
# Training loss EPOCH: [169|1000], training loss: [2.5498948147296687]
# Training loss EPOCH: [170|1000], training loss: [2.596690553838471]
# Training loss EPOCH: [171|1000], training loss: [2.6292925948830543]
# Training loss EPOCH: [172|1000], training loss: [3.039343544692656]
# Training loss EPOCH: [173|1000], training loss: [2.7055800204821026]
# Training loss EPOCH: [174|1000], training loss: [2.6865834215404902]
# Training loss EPOCH: [175|1000], training loss: [2.636103956563602]
# Training loss EPOCH: [176|1000], training loss: [2.515795688271737]
# Training loss EPOCH: [177|1000], training loss: [2.6297255572917493]
# Training loss EPOCH: [178|1000], training loss: [2.5515472165093342]
# Training loss EPOCH: [179|1000], training loss: [2.5793368392967295]
# Training loss EPOCH: [180|1000], training loss: [2.5598460376822914]
# Training loss EPOCH: [181|1000], training loss: [2.536213584133293]
# Training loss EPOCH: [182|1000], training loss: [2.550622129701651]
# Training loss EPOCH: [183|1000], training loss: [2.6918332771638234]
# Training loss EPOCH: [184|1000], training loss: [2.513261084052374]
# Training loss EPOCH: [185|1000], training loss: [2.5771923715842604]
# Training loss EPOCH: [186|1000], training loss: [2.533570710897493]
# Training loss EPOCH: [187|1000], training loss: [2.708500655419357]
# Training loss EPOCH: [188|1000], training loss: [2.637169073178029]
# Training loss EPOCH: [189|1000], training loss: [2.5705289080021885]
# Training loss EPOCH: [190|1000], training loss: [2.522587679504113]
# Training loss EPOCH: [191|1000], training loss: [2.5464038782865828]
# Training loss EPOCH: [192|1000], training loss: [2.5663217916467147]
# Training loss EPOCH: [193|1000], training loss: [2.5299742097804483]
# Training loss EPOCH: [194|1000], training loss: [2.544838050548151]
# Training loss EPOCH: [195|1000], training loss: [2.9440264391400888]
# Training loss EPOCH: [196|1000], training loss: [2.74053056585808]
# Training loss EPOCH: [197|1000], training loss: [2.515896718562999]
# Training loss EPOCH: [198|1000], training loss: [2.4772304273442387]
# Training loss EPOCH: [199|1000], training loss: [2.4715067149763854]
# Training loss EPOCH: [200|1000], training loss: [2.5050426567031536]
# Training loss EPOCH: [201|1000], training loss: [2.5068611926990343]
# Training loss EPOCH: [202|1000], training loss: [2.440436051009101]
# Training loss EPOCH: [203|1000], training loss: [2.473006436849573]
# Training loss EPOCH: [204|1000], training loss: [2.4146527467107717]
# Training loss EPOCH: [205|1000], training loss: [2.4695450728975175]
# Training loss EPOCH: [206|1000], training loss: [2.4711188668941304]
# Training loss EPOCH: [207|1000], training loss: [2.4577667180833487]
# Training loss EPOCH: [208|1000], training loss: [2.4490906999203617]
# Training loss EPOCH: [209|1000], training loss: [2.4797264737176192]
# Training loss EPOCH: [210|1000], training loss: [2.5462469476506158]
# Training loss EPOCH: [211|1000], training loss: [2.700750369504476]
# Training loss EPOCH: [212|1000], training loss: [2.4542675391594457]
# Training loss EPOCH: [213|1000], training loss: [2.370279774469509]
# Training loss EPOCH: [214|1000], training loss: [2.418116879092395]
# Training loss EPOCH: [215|1000], training loss: [2.4108443754139444]
# Training loss EPOCH: [216|1000], training loss: [2.477297818640409]
# Training loss EPOCH: [217|1000], training loss: [2.5652057770444117]
# Training loss EPOCH: [218|1000], training loss: [2.4777102234079393]
# Training loss EPOCH: [219|1000], training loss: [2.758780371928424]
# Training loss EPOCH: [220|1000], training loss: [2.6222921765847786]
# Training loss EPOCH: [221|1000], training loss: [2.4795101376357707]
# Training loss EPOCH: [222|1000], training loss: [2.520573275422521]
# Training loss EPOCH: [223|1000], training loss: [2.4573139711537806]
# Training loss EPOCH: [224|1000], training loss: [2.3800234203708897]
# Training loss EPOCH: [225|1000], training loss: [2.402092964982785]
# Training loss EPOCH: [226|1000], training loss: [2.4253000551198056]
# Training loss EPOCH: [227|1000], training loss: [2.3622879669824215]
# Training loss EPOCH: [228|1000], training loss: [2.409797690397909]
# Training loss EPOCH: [229|1000], training loss: [2.3667947330793595]
# Training loss EPOCH: [230|1000], training loss: [2.569399109531332]
# Training loss EPOCH: [231|1000], training loss: [2.3944883371882497]
# Training loss EPOCH: [232|1000], training loss: [2.4235485797248657]
# Training loss EPOCH: [233|1000], training loss: [2.5276096208758645]
# Training loss EPOCH: [234|1000], training loss: [2.435388623642666]
# Training loss EPOCH: [235|1000], training loss: [2.6150050419514628]
# Training loss EPOCH: [236|1000], training loss: [2.56223343840702]
# Training loss EPOCH: [237|1000], training loss: [2.4258581798071646]
# Training loss EPOCH: [238|1000], training loss: [2.4177043352765395]
# Training loss EPOCH: [239|1000], training loss: [2.5832564509091753]
# Training loss EPOCH: [240|1000], training loss: [2.4191413979933714]
# Training loss EPOCH: [241|1000], training loss: [2.398455222501525]
# Training loss EPOCH: [242|1000], training loss: [2.6469435374333443]
# Training loss EPOCH: [243|1000], training loss: [2.3937260043671813]
# Training loss EPOCH: [244|1000], training loss: [2.349068048071331]
# Training loss EPOCH: [245|1000], training loss: [2.4166183329207342]
# Training loss EPOCH: [246|1000], training loss: [2.426072339024813]
# Training loss EPOCH: [247|1000], training loss: [2.3531139015585723]
# Training loss EPOCH: [248|1000], training loss: [2.3451401380075367]
# Training loss EPOCH: [249|1000], training loss: [2.4088313907498105]
# Training loss EPOCH: [250|1000], training loss: [2.6288011813589947]
# Training loss EPOCH: [251|1000], training loss: [2.485059333512254]
# Training loss EPOCH: [252|1000], training loss: [2.4315408894872235]
# Training loss EPOCH: [253|1000], training loss: [2.4836402531163912]
# Training loss EPOCH: [254|1000], training loss: [2.317050881580144]
# Training loss EPOCH: [255|1000], training loss: [2.4321860680133796]
# Training loss EPOCH: [256|1000], training loss: [2.3811335866216723]
# Training loss EPOCH: [257|1000], training loss: [2.3535820640736347]
# Training loss EPOCH: [258|1000], training loss: [2.458148027984862]
# Training loss EPOCH: [259|1000], training loss: [2.2984941426184378]
# Training loss EPOCH: [260|1000], training loss: [2.3399065389171483]
# Training loss EPOCH: [261|1000], training loss: [2.3771365251359384]
# Training loss EPOCH: [262|1000], training loss: [2.2755298501087964]
# Training loss EPOCH: [263|1000], training loss: [2.355836330612874]
# Training loss EPOCH: [264|1000], training loss: [2.525522201457079]
# Training loss EPOCH: [265|1000], training loss: [2.2816631480527576]
# Training loss EPOCH: [266|1000], training loss: [2.277725215619739]
# Training loss EPOCH: [267|1000], training loss: [2.2536084123285036]
# Training loss EPOCH: [268|1000], training loss: [2.318534600121893]
# Training loss EPOCH: [269|1000], training loss: [2.409284235188352]
# Training loss EPOCH: [270|1000], training loss: [2.377058893033791]
# Training loss EPOCH: [271|1000], training loss: [2.33252764779445]
# Training loss EPOCH: [272|1000], training loss: [2.4402257761159944]
# Training loss EPOCH: [273|1000], training loss: [2.366125464192919]
# Training loss EPOCH: [274|1000], training loss: [2.281280449658425]
# Training loss EPOCH: [275|1000], training loss: [2.275494792109839]
# Training loss EPOCH: [276|1000], training loss: [2.3416854818497086]
# Training loss EPOCH: [277|1000], training loss: [2.426763220007615]
# Training loss EPOCH: [278|1000], training loss: [2.3344173109376243]
# Training loss EPOCH: [279|1000], training loss: [2.2635787207495923]
# Training loss EPOCH: [280|1000], training loss: [2.290096486731727]
# Training loss EPOCH: [281|1000], training loss: [2.2875981897325346]
# Training loss EPOCH: [282|1000], training loss: [2.2292200479682833]
# Training loss EPOCH: [283|1000], training loss: [2.266942412968092]
# Training loss EPOCH: [284|1000], training loss: [2.237536980130244]
# Training loss EPOCH: [285|1000], training loss: [2.3007153555895457]
# Training loss EPOCH: [286|1000], training loss: [2.2811623451925698]
# Training loss EPOCH: [287|1000], training loss: [2.248793680104882]
# Training loss EPOCH: [288|1000], training loss: [2.4731011508306437]
# Training loss EPOCH: [289|1000], training loss: [2.459460818059142]
# Training loss EPOCH: [290|1000], training loss: [2.300585704549576]
# Training loss EPOCH: [291|1000], training loss: [2.3249611236064993]
# Training loss EPOCH: [292|1000], training loss: [2.271403584434438]
# Training loss EPOCH: [293|1000], training loss: [2.2315433645494522]
# Training loss EPOCH: [294|1000], training loss: [2.2172260952720535]
# Training loss EPOCH: [295|1000], training loss: [2.266226489758992]
# Training loss EPOCH: [296|1000], training loss: [2.258483537614211]
# Training loss EPOCH: [297|1000], training loss: [2.1727667914947233]
# Training loss EPOCH: [298|1000], training loss: [2.2741136087488485]
# Training loss EPOCH: [299|1000], training loss: [2.332733075826127]
# Training loss EPOCH: [300|1000], training loss: [2.337577100237013]
# Training loss EPOCH: [301|1000], training loss: [2.1854051488226105]
# Training loss EPOCH: [302|1000], training loss: [2.302784234048886]
# Training loss EPOCH: [303|1000], training loss: [2.2188026410708517]
# Training loss EPOCH: [304|1000], training loss: [2.258049069171193]
# Training loss EPOCH: [305|1000], training loss: [2.27776901348534]
# Training loss EPOCH: [306|1000], training loss: [2.334338455119905]
# Training loss EPOCH: [307|1000], training loss: [2.243741771121222]
# Training loss EPOCH: [308|1000], training loss: [2.3400323249716166]
# Training loss EPOCH: [309|1000], training loss: [2.186873317788013]
# Training loss EPOCH: [310|1000], training loss: [2.183945741359821]
# Training loss EPOCH: [311|1000], training loss: [2.160222540266659]
# Training loss EPOCH: [312|1000], training loss: [2.3259816354179748]
# Training loss EPOCH: [313|1000], training loss: [2.16549448289652]
# Training loss EPOCH: [314|1000], training loss: [2.2640179245267973]
# Training loss EPOCH: [315|1000], training loss: [2.252954645293812]
# Training loss EPOCH: [316|1000], training loss: [2.2631772971649298]
# Training loss EPOCH: [317|1000], training loss: [2.2098935122248804]
# Training loss EPOCH: [318|1000], training loss: [2.264878841503105]
# Training loss EPOCH: [319|1000], training loss: [2.2986364772036723]
# Training loss EPOCH: [320|1000], training loss: [2.354632993135965]
# Training loss EPOCH: [321|1000], training loss: [2.28378408530898]
# Training loss EPOCH: [322|1000], training loss: [2.1857888487561468]
# Training loss EPOCH: [323|1000], training loss: [2.2002300788881257]
# Training loss EPOCH: [324|1000], training loss: [2.28572851111403]
# Training loss EPOCH: [325|1000], training loss: [2.1841818545308342]
# Training loss EPOCH: [326|1000], training loss: [2.201321803044266]
# Training loss EPOCH: [327|1000], training loss: [2.2652544223660698]
# Training loss EPOCH: [328|1000], training loss: [2.271096535099332]
# Training loss EPOCH: [329|1000], training loss: [2.3467594646995167]
# Training loss EPOCH: [330|1000], training loss: [2.2545957769425513]
# Training loss EPOCH: [331|1000], training loss: [2.2197691485689575]
# Training loss EPOCH: [332|1000], training loss: [2.1877440188368382]
# Training loss EPOCH: [333|1000], training loss: [2.2052097933997175]
# Training loss EPOCH: [334|1000], training loss: [2.3078892087123677]
# Training loss EPOCH: [335|1000], training loss: [2.217151343041678]
# Training loss EPOCH: [336|1000], training loss: [2.1691784966983505]
# Training loss EPOCH: [337|1000], training loss: [2.118941491590249]
# Training loss EPOCH: [338|1000], training loss: [2.1773909966095744]
# Training loss EPOCH: [339|1000], training loss: [2.5459790760287433]
# Training loss EPOCH: [340|1000], training loss: [2.2805850189820376]
# Training loss EPOCH: [341|1000], training loss: [2.1700480026024707]
# Training loss EPOCH: [342|1000], training loss: [2.2935275198642557]
# Training loss EPOCH: [343|1000], training loss: [2.2496079362304044]
# Training loss EPOCH: [344|1000], training loss: [2.179212479614307]
# Training loss EPOCH: [345|1000], training loss: [2.1833654727488465]
# Training loss EPOCH: [346|1000], training loss: [2.264230517633223]
# Training loss EPOCH: [347|1000], training loss: [2.250472747848562]
# Training loss EPOCH: [348|1000], training loss: [2.1619608397086267]
# Training loss EPOCH: [349|1000], training loss: [2.205583885384385]
# Training loss EPOCH: [350|1000], training loss: [2.1337218053440665]
# Training loss EPOCH: [351|1000], training loss: [2.187028660674514]
# Training loss EPOCH: [352|1000], training loss: [2.1436444547034625]
# Training loss EPOCH: [353|1000], training loss: [2.1032708631782953]
# Training loss EPOCH: [354|1000], training loss: [2.154008953848461]
# Training loss EPOCH: [355|1000], training loss: [2.0899208732284933]
# Training loss EPOCH: [356|1000], training loss: [2.0987483489843726]
# Training loss EPOCH: [357|1000], training loss: [2.2192527389570387]
# Training loss EPOCH: [358|1000], training loss: [2.2676081195859297]
# Training loss EPOCH: [359|1000], training loss: [2.1638420089743704]
# Training loss EPOCH: [360|1000], training loss: [2.330848966038957]
# Training loss EPOCH: [361|1000], training loss: [2.1927294605711722]
# Training loss EPOCH: [362|1000], training loss: [2.1368147040611802]
# Training loss EPOCH: [363|1000], training loss: [2.206219156554198]
# Training loss EPOCH: [364|1000], training loss: [2.1698337517859727]
# Training loss EPOCH: [365|1000], training loss: [2.2323405440151873]
# Training loss EPOCH: [366|1000], training loss: [2.1816167312867947]
# Training loss EPOCH: [367|1000], training loss: [2.273672884422467]
# Training loss EPOCH: [368|1000], training loss: [2.092959802126188]
# Training loss EPOCH: [369|1000], training loss: [2.1774743530399974]
# Training loss EPOCH: [370|1000], training loss: [2.1115413471561624]
# Training loss EPOCH: [371|1000], training loss: [2.122636386038721]
# Training loss EPOCH: [372|1000], training loss: [2.1185361154384736]
# Training loss EPOCH: [373|1000], training loss: [2.2660027929032367]
# Training loss EPOCH: [374|1000], training loss: [2.3383123449639243]
# Training loss EPOCH: [375|1000], training loss: [2.1174786802766903]
# Training loss EPOCH: [376|1000], training loss: [2.070159622096071]
# Training loss EPOCH: [377|1000], training loss: [2.1507354679506534]
# Training loss EPOCH: [378|1000], training loss: [2.2091618453396222]
# Training loss EPOCH: [379|1000], training loss: [2.100039851643487]
# Training loss EPOCH: [380|1000], training loss: [2.1183040117621204]
# Training loss EPOCH: [381|1000], training loss: [2.1533503999817185]
# Training loss EPOCH: [382|1000], training loss: [2.286380747554176]
# Training loss EPOCH: [383|1000], training loss: [2.264651991660685]
# Training loss EPOCH: [384|1000], training loss: [2.153892650758735]
# Training loss EPOCH: [385|1000], training loss: [2.1382447626369867]
# Training loss EPOCH: [386|1000], training loss: [2.0823195411594497]
# Training loss EPOCH: [387|1000], training loss: [2.1964542053756304]
# Training loss EPOCH: [388|1000], training loss: [2.129083069635726]
# Training loss EPOCH: [389|1000], training loss: [2.199184191281347]
# Training loss EPOCH: [390|1000], training loss: [2.2379165290094534]
# Training loss EPOCH: [391|1000], training loss: [2.184999345392498]
# Training loss EPOCH: [392|1000], training loss: [2.159047371675115]
# Training loss EPOCH: [393|1000], training loss: [2.06994697346704]
# Training loss EPOCH: [394|1000], training loss: [2.11869246422566]
# Training loss EPOCH: [395|1000], training loss: [2.2169043855265045]
# Training loss EPOCH: [396|1000], training loss: [2.0962615200064647]
# Training loss EPOCH: [397|1000], training loss: [2.244955879277313]
# Training loss EPOCH: [398|1000], training loss: [2.1198270988315926]
# Training loss EPOCH: [399|1000], training loss: [2.064601341030084]
# Training loss EPOCH: [400|1000], training loss: [2.100811984289976]
# Training loss EPOCH: [401|1000], training loss: [2.0281423873993845]
# Training loss EPOCH: [402|1000], training loss: [2.1281734008871354]
# Training loss EPOCH: [403|1000], training loss: [2.1484953479218802]
# Training loss EPOCH: [404|1000], training loss: [2.097139644398794]
# Training loss EPOCH: [405|1000], training loss: [2.1917599589774]
# Training loss EPOCH: [406|1000], training loss: [2.1275284464268225]
# Training loss EPOCH: [407|1000], training loss: [2.20146616909733]
# Training loss EPOCH: [408|1000], training loss: [2.0990967091383936]
# Training loss EPOCH: [409|1000], training loss: [2.1000949714666604]
# Training loss EPOCH: [410|1000], training loss: [2.100291121663304]
# Training loss EPOCH: [411|1000], training loss: [2.1867856814196784]
# Training loss EPOCH: [412|1000], training loss: [2.219969042196226]
# Training loss EPOCH: [413|1000], training loss: [2.2485093600191703]
# Training loss EPOCH: [414|1000], training loss: [2.194759839422204]
# Training loss EPOCH: [415|1000], training loss: [2.1591143913765336]
# Training loss EPOCH: [416|1000], training loss: [2.0269477291026305]
# Training loss EPOCH: [417|1000], training loss: [2.1011184088672508]
# Training loss EPOCH: [418|1000], training loss: [2.1026501474734687]
# Training loss EPOCH: [419|1000], training loss: [2.0447319026866353]
# Training loss EPOCH: [420|1000], training loss: [2.050360918957267]
# Training loss EPOCH: [421|1000], training loss: [2.2226552342663126]
# Training loss EPOCH: [422|1000], training loss: [2.2883440383457128]
# Training loss EPOCH: [423|1000], training loss: [2.1693253884336627]
# Training loss EPOCH: [424|1000], training loss: [2.1428153636420575]
# Training loss EPOCH: [425|1000], training loss: [2.143870261430493]
# Training loss EPOCH: [426|1000], training loss: [2.0621133579343223]
# Training loss EPOCH: [427|1000], training loss: [2.120582095035388]
# Training loss EPOCH: [428|1000], training loss: [2.085679667745808]
# Training loss EPOCH: [429|1000], training loss: [2.1040693730737985]
# Training loss EPOCH: [430|1000], training loss: [2.0617168986318575]
# Training loss EPOCH: [431|1000], training loss: [2.173775818154809]
# Training loss EPOCH: [432|1000], training loss: [2.141473083521305]
# Training loss EPOCH: [433|1000], training loss: [2.188427743597913]
# Training loss EPOCH: [434|1000], training loss: [2.1964380861024893]
# Training loss EPOCH: [435|1000], training loss: [2.0663770935625507]
# Training loss EPOCH: [436|1000], training loss: [2.0852798869455]
# Training loss EPOCH: [437|1000], training loss: [2.0927991346179624]
# Training loss EPOCH: [438|1000], training loss: [2.1669376104578078]
# Training loss EPOCH: [439|1000], training loss: [2.1153517549130356]
# Training loss EPOCH: [440|1000], training loss: [2.1107324692866314]
# Training loss EPOCH: [441|1000], training loss: [2.099088422265595]
# Training loss EPOCH: [442|1000], training loss: [2.053620255068381]
# Training loss EPOCH: [443|1000], training loss: [2.117222849036807]
# Training loss EPOCH: [444|1000], training loss: [2.0864788614121608]
# Training loss EPOCH: [445|1000], training loss: [2.027663025617585]
# Training loss EPOCH: [446|1000], training loss: [2.0687446947604258]
# Training loss EPOCH: [447|1000], training loss: [2.061794966782145]
# Training loss EPOCH: [448|1000], training loss: [2.0005782583079963]
# Training loss EPOCH: [449|1000], training loss: [1.9560521108082867]
# Training loss EPOCH: [450|1000], training loss: [2.0676221258163423]
# Training loss EPOCH: [451|1000], training loss: [2.115122366466494]
# Training loss EPOCH: [452|1000], training loss: [2.0343694948815028]
# Training loss EPOCH: [453|1000], training loss: [2.1319555527579723]
# Training loss EPOCH: [454|1000], training loss: [2.049287752107375]
# Training loss EPOCH: [455|1000], training loss: [2.270571559184191]
# Training loss EPOCH: [456|1000], training loss: [2.076227789200857]
# Training loss EPOCH: [457|1000], training loss: [2.0658644877121333]
# Training loss EPOCH: [458|1000], training loss: [2.176959678014555]
# Training loss EPOCH: [459|1000], training loss: [2.0111096994305626]
# Training loss EPOCH: [460|1000], training loss: [2.2022154205842526]
# Training loss EPOCH: [461|1000], training loss: [2.0047499015895482]
# Training loss EPOCH: [462|1000], training loss: [2.1002366156799326]
# Training loss EPOCH: [463|1000], training loss: [2.0341038482224576]
# Training loss EPOCH: [464|1000], training loss: [2.009208000783474]
# Training loss EPOCH: [465|1000], training loss: [1.9728872323616997]
# Training loss EPOCH: [466|1000], training loss: [2.2256954375711757]
# Training loss EPOCH: [467|1000], training loss: [2.1071512482621984]
# Training loss EPOCH: [468|1000], training loss: [2.1407391124084825]
# Training loss EPOCH: [469|1000], training loss: [2.2372868843449396]
# Training loss EPOCH: [470|1000], training loss: [1.9999825688828423]
# Training loss EPOCH: [471|1000], training loss: [2.1549730437127437]
# Training loss EPOCH: [472|1000], training loss: [1.9748671653378551]
# Training loss EPOCH: [473|1000], training loss: [2.050268502700419]
# Training loss EPOCH: [474|1000], training loss: [2.2204967653651693]
# Training loss EPOCH: [475|1000], training loss: [2.183039794466822]
# Training loss EPOCH: [476|1000], training loss: [2.120759511633878]
# Training loss EPOCH: [477|1000], training loss: [2.0501320978382864]
# Training loss EPOCH: [478|1000], training loss: [2.1095467110899335]
# Training loss EPOCH: [479|1000], training loss: [2.0214301835039805]
# Training loss EPOCH: [480|1000], training loss: [1.9894521695696312]
# Training loss EPOCH: [481|1000], training loss: [2.1039982831280213]
# Training loss EPOCH: [482|1000], training loss: [2.298430064260174]
# Training loss EPOCH: [483|1000], training loss: [2.1482564756515785]
# Training loss EPOCH: [484|1000], training loss: [2.039658576882175]
# Training loss EPOCH: [485|1000], training loss: [1.9828342789223825]
# Training loss EPOCH: [486|1000], training loss: [2.182264155069788]
# Training loss EPOCH: [487|1000], training loss: [2.064300965073926]
# Training loss EPOCH: [488|1000], training loss: [2.0666050387590076]
# Training loss EPOCH: [489|1000], training loss: [2.021475215358805]
# Training loss EPOCH: [490|1000], training loss: [2.1516466485618366]
# Training loss EPOCH: [491|1000], training loss: [2.1702209335671796]
# Training loss EPOCH: [492|1000], training loss: [2.183854253962636]
# Training loss EPOCH: [493|1000], training loss: [2.181235988578919]
# Training loss EPOCH: [494|1000], training loss: [2.040640248762429]
# Training loss EPOCH: [495|1000], training loss: [2.0282213662503636]
# Training loss EPOCH: [496|1000], training loss: [2.0282511556397367]
# Training loss EPOCH: [497|1000], training loss: [1.9692825861939127]
# Training loss EPOCH: [498|1000], training loss: [2.023899747329324]
# Training loss EPOCH: [499|1000], training loss: [1.9635458102416123]
# Training loss EPOCH: [500|1000], training loss: [2.1054110284858325]
# Training loss EPOCH: [501|1000], training loss: [2.037094962903211]
# Training loss EPOCH: [502|1000], training loss: [2.136071519466441]
# Training loss EPOCH: [503|1000], training loss: [1.9793791158972454]
# Training loss EPOCH: [504|1000], training loss: [2.188164745258746]
# Training loss EPOCH: [505|1000], training loss: [2.302773730752051]
# Training loss EPOCH: [506|1000], training loss: [2.1617356256574567]
# Training loss EPOCH: [507|1000], training loss: [2.098874870360305]
# Training loss EPOCH: [508|1000], training loss: [2.151100232063527]
# Training loss EPOCH: [509|1000], training loss: [2.181984348050719]
# Training loss EPOCH: [510|1000], training loss: [2.1346540513332]
# Training loss EPOCH: [511|1000], training loss: [1.9877971241749037]
# Training loss EPOCH: [512|1000], training loss: [2.008021375191447]
# Training loss EPOCH: [513|1000], training loss: [2.0642228148271897]
# Training loss EPOCH: [514|1000], training loss: [1.9899673269683262]
# Training loss EPOCH: [515|1000], training loss: [1.9064579949122162]
# Training loss EPOCH: [516|1000], training loss: [1.9480344261742175]
# Training loss EPOCH: [517|1000], training loss: [1.9471445697240597]
# Training loss EPOCH: [518|1000], training loss: [2.0439619809999385]
# Training loss EPOCH: [519|1000], training loss: [2.032137434705419]
# Training loss EPOCH: [520|1000], training loss: [2.0490057890410753]
# Training loss EPOCH: [521|1000], training loss: [2.1188772432524274]
# Training loss EPOCH: [522|1000], training loss: [2.0930584685720532]
# Training loss EPOCH: [523|1000], training loss: [2.240844244867276]
# Training loss EPOCH: [524|1000], training loss: [1.9941350915282783]
# Training loss EPOCH: [525|1000], training loss: [2.076860514933287]
# Training loss EPOCH: [526|1000], training loss: [2.025793426586006]
# Training loss EPOCH: [527|1000], training loss: [1.967721226627873]
# Training loss EPOCH: [528|1000], training loss: [2.0034161403309554]
# Training loss EPOCH: [529|1000], training loss: [2.0210989213969697]
# Training loss EPOCH: [530|1000], training loss: [2.090384341754998]
# Training loss EPOCH: [531|1000], training loss: [2.1273365029526303]
# Training loss EPOCH: [532|1000], training loss: [2.157069520204459]
# Training loss EPOCH: [533|1000], training loss: [2.0198510915333827]
# Training loss EPOCH: [534|1000], training loss: [2.1456451706114876]
# Training loss EPOCH: [535|1000], training loss: [2.0581645192150972]
# Training loss EPOCH: [536|1000], training loss: [1.9975675002979187]
# Training loss EPOCH: [537|1000], training loss: [1.9403768434394806]
# Training loss EPOCH: [538|1000], training loss: [2.09258867857352]
# Training loss EPOCH: [539|1000], training loss: [2.0460527486548017]
# Training loss EPOCH: [540|1000], training loss: [1.9894616567698904]
# Training loss EPOCH: [541|1000], training loss: [2.125971497325736]
# Training loss EPOCH: [542|1000], training loss: [2.1504101367850126]
# Training loss EPOCH: [543|1000], training loss: [2.196641439661107]
# Training loss EPOCH: [544|1000], training loss: [2.1293176823328395]
# Training loss EPOCH: [545|1000], training loss: [1.9714098495512644]
# Training loss EPOCH: [546|1000], training loss: [1.914083858988306]
# Training loss EPOCH: [547|1000], training loss: [2.1441966203828997]
# Training loss EPOCH: [548|1000], training loss: [1.9255241998121164]
# Training loss EPOCH: [549|1000], training loss: [1.957398725008261]
# Training loss EPOCH: [550|1000], training loss: [2.0602822500140974]
# Training loss EPOCH: [551|1000], training loss: [2.096237864136583]
# Training loss EPOCH: [552|1000], training loss: [2.010814350592682]
# Training loss EPOCH: [553|1000], training loss: [2.133371635957701]
# Training loss EPOCH: [554|1000], training loss: [2.1498052118004125]
# Training loss EPOCH: [555|1000], training loss: [1.9712907141902178]
# Training loss EPOCH: [556|1000], training loss: [1.9371084415943187]
# Training loss EPOCH: [557|1000], training loss: [1.9827912246337291]
# Training loss EPOCH: [558|1000], training loss: [2.1239814523096356]
# Training loss EPOCH: [559|1000], training loss: [1.9367550424121873]
# Training loss EPOCH: [560|1000], training loss: [1.9960865410316728]
# Training loss EPOCH: [561|1000], training loss: [1.9866001389336816]
# Training loss EPOCH: [562|1000], training loss: [1.8917175363176284]
# Training loss EPOCH: [563|1000], training loss: [2.0604413910700714]
# Training loss EPOCH: [564|1000], training loss: [1.8922572850206052]
# Training loss EPOCH: [565|1000], training loss: [1.9355083408436258]
# Training loss EPOCH: [566|1000], training loss: [2.0467315950349985]
# Training loss EPOCH: [567|1000], training loss: [1.9060153801810884]
# Training loss EPOCH: [568|1000], training loss: [2.012137332975726]
# Training loss EPOCH: [569|1000], training loss: [2.0196097206367085]
# Training loss EPOCH: [570|1000], training loss: [2.0021685176957362]
# Training loss EPOCH: [571|1000], training loss: [1.9039701027913907]
# Training loss EPOCH: [572|1000], training loss: [2.1241103287547958]
# Training loss EPOCH: [573|1000], training loss: [1.8892229226116797]
# Training loss EPOCH: [574|1000], training loss: [1.9133853445073328]
# Training loss EPOCH: [575|1000], training loss: [2.1459408082901064]
# Training loss EPOCH: [576|1000], training loss: [2.0269102158263195]
# Training loss EPOCH: [577|1000], training loss: [2.0708654273571483]
# Training loss EPOCH: [578|1000], training loss: [1.952318286461832]
# Training loss EPOCH: [579|1000], training loss: [2.01745674169797]
# Training loss EPOCH: [580|1000], training loss: [1.9828644441849974]
# Training loss EPOCH: [581|1000], training loss: [1.970711648514225]
# Training loss EPOCH: [582|1000], training loss: [1.9744010232261644]
# Training loss EPOCH: [583|1000], training loss: [2.099801948451386]
# Training loss EPOCH: [584|1000], training loss: [1.903037930921073]
# Training loss EPOCH: [585|1000], training loss: [1.971351085662718]
# Training loss EPOCH: [586|1000], training loss: [2.0012902099247185]
# Training loss EPOCH: [587|1000], training loss: [1.9546370622520044]
# Training loss EPOCH: [588|1000], training loss: [1.973586758546844]
# Training loss EPOCH: [589|1000], training loss: [1.957857756505291]
# Training loss EPOCH: [590|1000], training loss: [1.9361015223894356]
# Training loss EPOCH: [591|1000], training loss: [2.123169000416965]
# Training loss EPOCH: [592|1000], training loss: [2.0390051894592034]
# Training loss EPOCH: [593|1000], training loss: [1.8634190662073706]
# Training loss EPOCH: [594|1000], training loss: [2.031075525281267]
# Training loss EPOCH: [595|1000], training loss: [2.089494657263458]
# Training loss EPOCH: [596|1000], training loss: [1.9702679234178504]
# Training loss EPOCH: [597|1000], training loss: [2.107649668275826]
# Training loss EPOCH: [598|1000], training loss: [2.0225118865005243]
# Training loss EPOCH: [599|1000], training loss: [1.92574702794127]
# Training loss EPOCH: [600|1000], training loss: [2.0555841566438176]
# Training loss EPOCH: [601|1000], training loss: [2.0636543297682692]
# Training loss EPOCH: [602|1000], training loss: [2.1618874436253464]
# Training loss EPOCH: [603|1000], training loss: [2.0473274659780145]
# Training loss EPOCH: [604|1000], training loss: [1.8810005437471773]
# Training loss EPOCH: [605|1000], training loss: [1.9362070692723137]
# Training loss EPOCH: [606|1000], training loss: [2.1247722384650842]
# Training loss EPOCH: [607|1000], training loss: [2.00590307368293]
# Training loss EPOCH: [608|1000], training loss: [2.1532300968865457]
# Training loss EPOCH: [609|1000], training loss: [2.078528777261454]
# Training loss EPOCH: [610|1000], training loss: [1.8630055141384219]
# Training loss EPOCH: [611|1000], training loss: [1.8729524399182083]
# Training loss EPOCH: [612|1000], training loss: [2.0282080474989925]
# Training loss EPOCH: [613|1000], training loss: [1.9459458762776194]
# Training loss EPOCH: [614|1000], training loss: [2.050387037598739]
# Training loss EPOCH: [615|1000], training loss: [2.0367615248474067]
# Training loss EPOCH: [616|1000], training loss: [2.1252472571277394]
# Training loss EPOCH: [617|1000], training loss: [1.9531022372111693]
# Training loss EPOCH: [618|1000], training loss: [1.9493090693408703]
# Training loss EPOCH: [619|1000], training loss: [2.051531084077851]
# Training loss EPOCH: [620|1000], training loss: [1.957807833530751]
# Training loss EPOCH: [621|1000], training loss: [2.213980429987714]
# Training loss EPOCH: [622|1000], training loss: [2.0708331323985476]
# Training loss EPOCH: [623|1000], training loss: [2.00483654850359]
# Training loss EPOCH: [624|1000], training loss: [2.070270743061883]
# Training loss EPOCH: [625|1000], training loss: [1.994254032047138]
# Training loss EPOCH: [626|1000], training loss: [1.8925744008956826]
# Training loss EPOCH: [627|1000], training loss: [1.9865648587838223]
# Training loss EPOCH: [628|1000], training loss: [1.9572756953793942]
# Training loss EPOCH: [629|1000], training loss: [2.0100084825062368]
# Training loss EPOCH: [630|1000], training loss: [2.137792751784218]
# Training loss EPOCH: [631|1000], training loss: [2.0349604944531166]
# Training loss EPOCH: [632|1000], training loss: [1.8912122333181287]
# Training loss EPOCH: [633|1000], training loss: [1.9712742653591704]
# Training loss EPOCH: [634|1000], training loss: [1.9535987785488942]
# Training loss EPOCH: [635|1000], training loss: [1.8845354985619451]
# Training loss EPOCH: [636|1000], training loss: [2.145922496730236]
# Training loss EPOCH: [637|1000], training loss: [2.0052967568594795]
# Training loss EPOCH: [638|1000], training loss: [2.072846760077937]
# Training loss EPOCH: [639|1000], training loss: [1.9642529394122903]
# Training loss EPOCH: [640|1000], training loss: [1.9331876684345843]
# Training loss EPOCH: [641|1000], training loss: [1.9997486407646647]
# Training loss EPOCH: [642|1000], training loss: [1.9823963924091004]
# Training loss EPOCH: [643|1000], training loss: [1.974097840921786]
# Training loss EPOCH: [644|1000], training loss: [2.0827663486415986]
# Training loss EPOCH: [645|1000], training loss: [2.0118435714143743]
# Training loss EPOCH: [646|1000], training loss: [1.9084215114894505]
# Training loss EPOCH: [647|1000], training loss: [2.0879914360066323]
# Training loss EPOCH: [648|1000], training loss: [2.041010469595676]
# Training loss EPOCH: [649|1000], training loss: [2.0610428888203387]
# Training loss EPOCH: [650|1000], training loss: [2.0596231461140633]
# Training loss EPOCH: [651|1000], training loss: [1.9369493619628884]
# Training loss EPOCH: [652|1000], training loss: [2.017544708353853]
# Training loss EPOCH: [653|1000], training loss: [2.0553638735132154]
# Training loss EPOCH: [654|1000], training loss: [1.9385790855835694]
# Training loss EPOCH: [655|1000], training loss: [1.930859519018668]
# Training loss EPOCH: [656|1000], training loss: [2.0433747290389874]
# Training loss EPOCH: [657|1000], training loss: [1.992817006446785]
# Training loss EPOCH: [658|1000], training loss: [2.058543598553115]
# Training loss EPOCH: [659|1000], training loss: [1.9183464678349083]
# Training loss EPOCH: [660|1000], training loss: [2.091631465156752]
# Training loss EPOCH: [661|1000], training loss: [2.2032010015705055]
# Training loss EPOCH: [662|1000], training loss: [1.9285658559883814]
# Training loss EPOCH: [663|1000], training loss: [2.1826489681902785]
# Training loss EPOCH: [664|1000], training loss: [2.0873597647314455]
# Training loss EPOCH: [665|1000], training loss: [2.06560110620876]
# Training loss EPOCH: [666|1000], training loss: [2.080299696468046]
# Training loss EPOCH: [667|1000], training loss: [1.916253176452301]
# Training loss EPOCH: [668|1000], training loss: [1.9007005368184764]
# Training loss EPOCH: [669|1000], training loss: [2.2130092097186207]
# Training loss EPOCH: [670|1000], training loss: [1.9908324496291243]
# Training loss EPOCH: [671|1000], training loss: [2.1129953594936524]
# Training loss EPOCH: [672|1000], training loss: [1.9687337825703253]
# Training loss EPOCH: [673|1000], training loss: [1.9558234012401954]
# Training loss EPOCH: [674|1000], training loss: [1.8956609616302558]
# Training loss EPOCH: [675|1000], training loss: [2.0800699028377494]
# Training loss EPOCH: [676|1000], training loss: [2.032278694608067]
# Training loss EPOCH: [677|1000], training loss: [1.9100149124678865]
# Training loss EPOCH: [678|1000], training loss: [1.908501170186355]
# Training loss EPOCH: [679|1000], training loss: [1.895125874385485]
# Training loss EPOCH: [680|1000], training loss: [1.9568128415821775]
# Training loss EPOCH: [681|1000], training loss: [1.8886560434725652]
# Training loss EPOCH: [682|1000], training loss: [2.122847669330895]
# Training loss EPOCH: [683|1000], training loss: [1.9270182213977023]
# Training loss EPOCH: [684|1000], training loss: [1.881605562201912]
# Training loss EPOCH: [685|1000], training loss: [1.9149480935138854]
# Training loss EPOCH: [686|1000], training loss: [2.0684160834816794]
# Training loss EPOCH: [687|1000], training loss: [2.015696109709552]
# Training loss EPOCH: [688|1000], training loss: [1.9511460728876955]
# Training loss EPOCH: [689|1000], training loss: [2.122966088245903]
# Training loss EPOCH: [690|1000], training loss: [2.0220035729676056]
# Training loss EPOCH: [691|1000], training loss: [2.029538687432705]
# Training loss EPOCH: [692|1000], training loss: [1.938619603351981]
# Training loss EPOCH: [693|1000], training loss: [2.0674006890844794]
# Training loss EPOCH: [694|1000], training loss: [2.0819772447230207]
# Training loss EPOCH: [695|1000], training loss: [2.0254663775576773]
# Training loss EPOCH: [696|1000], training loss: [1.9057569912379222]
# Training loss EPOCH: [697|1000], training loss: [1.9755276664950543]
# Training loss EPOCH: [698|1000], training loss: [1.863482626311452]
# Training loss EPOCH: [699|1000], training loss: [1.9042293723605326]
# Training loss EPOCH: [700|1000], training loss: [2.2076939655980823]
# Training loss EPOCH: [701|1000], training loss: [2.047399229151324]
# Training loss EPOCH: [702|1000], training loss: [2.015121940730751]
# ...
# Training loss EPOCH: [769|1000], training loss: [1.8891812334368296]
# Training loss EPOCH: [770|1000], training loss: [2.0043895629537474]
# Training loss EPOCH: [771|1000], training loss: [1.8431065962627144]
# Training loss EPOCH: [772|1000], training loss: [2.0057418345641054]
# Training loss EPOCH: [773|1000], training loss: [1.7747528720601622]
# Training loss EPOCH: [774|1000], training loss: [2.014493598797344]
# Training loss EPOCH: [775|1000], training loss: [1.960076735965231]
# Training loss EPOCH: [776|1000], training loss: [2.0819820496226384]
# Training loss EPOCH: [777|1000], training loss: [2.1602625742143573]
# Training loss EPOCH: [778|1000], training loss: [1.919313706230696]
# Training loss EPOCH: [779|1000], training loss: [1.8033523045660331]
# Training loss EPOCH: [780|1000], training loss: [1.9607443242666704]
# Training loss EPOCH: [781|1000], training loss: [1.9045726022281997]
# Training loss EPOCH: [782|1000], training loss: [1.9673511584951484]
# Training loss EPOCH: [783|1000], training loss: [1.8019536117576536]
# Training loss EPOCH: [784|1000], training loss: [2.0535252254644547]
# Training loss EPOCH: [785|1000], training loss: [1.806895604586316]
# Training loss EPOCH: [786|1000], training loss: [1.963155914334493]
# Training loss EPOCH: [787|1000], training loss: [1.9291126493844786]
# Training loss EPOCH: [788|1000], training loss: [1.8631508021244372]
# Training loss EPOCH: [789|1000], training loss: [2.0082682761917567]
# Training loss EPOCH: [790|1000], training loss: [1.8978338410579454]
# Training loss EPOCH: [791|1000], training loss: [1.7579429850948145]
# Training loss EPOCH: [792|1000], training loss: [1.844843895385111]
# Training loss EPOCH: [793|1000], training loss: [1.8872288375869175]
# Training loss EPOCH: [794|1000], training loss: [1.9111214575686972]
# Training loss EPOCH: [795|1000], training loss: [1.8524987614860038]
# Training loss EPOCH: [796|1000], training loss: [2.0083744279859275]
# Training loss EPOCH: [797|1000], training loss: [2.11934578875389]
# Training loss EPOCH: [798|1000], training loss: [1.8641716258671295]
# Training loss EPOCH: [799|1000], training loss: [2.084194507608572]
# Training loss EPOCH: [800|1000], training loss: [1.8422982078973291]
# Training loss EPOCH: [801|1000], training loss: [2.0085763622300874]
# Training loss EPOCH: [802|1000], training loss: [2.077746028450747]
# Training loss EPOCH: [803|1000], training loss: [1.8540683885084945]
# Training loss EPOCH: [804|1000], training loss: [1.8814116098292288]
# Training loss EPOCH: [805|1000], training loss: [2.0050771142923622]
# Training loss EPOCH: [806|1000], training loss: [1.904541016899202]
# Training loss EPOCH: [807|1000], training loss: [1.921147096790719]
# Training loss EPOCH: [808|1000], training loss: [1.8653439713989428]
# Training loss EPOCH: [809|1000], training loss: [2.0679562978566537]
# Training loss EPOCH: [810|1000], training loss: [2.093589071500446]
# Training loss EPOCH: [811|1000], training loss: [1.999285053271251]
# Training loss EPOCH: [812|1000], training loss: [1.7516108523113871]
# Training loss EPOCH: [813|1000], training loss: [1.8864772765073212]
# Training loss EPOCH: [814|1000], training loss: [1.768530595548782]
# Training loss EPOCH: [815|1000], training loss: [1.9076689872454153]
# Training loss EPOCH: [816|1000], training loss: [1.8776175126899943]
# Training loss EPOCH: [817|1000], training loss: [2.0848874720877575]
# Training loss EPOCH: [818|1000], training loss: [1.8694335541727014]
# Training loss EPOCH: [819|1000], training loss: [1.7762839676215663]
# Training loss EPOCH: [820|1000], training loss: [1.8614906968823561]
# Training loss EPOCH: [821|1000], training loss: [2.100733395754105]
# Training loss EPOCH: [822|1000], training loss: [2.011854516117637]
# Training loss EPOCH: [823|1000], training loss: [1.8540213468186266]
# Training loss EPOCH: [824|1000], training loss: [1.9563646555716332]
# Training loss EPOCH: [825|1000], training loss: [1.793497370530531]
# Training loss EPOCH: [826|1000], training loss: [1.8411346423363284]
# Training loss EPOCH: [827|1000], training loss: [1.9357055997288626]
# Training loss EPOCH: [828|1000], training loss: [1.7523801305901543]
# Training loss EPOCH: [829|1000], training loss: [1.7561736416264466]
# Training loss EPOCH: [830|1000], training loss: [1.8059108133106747]
# Training loss EPOCH: [831|1000], training loss: [1.8402899516959224]
# Training loss EPOCH: [832|1000], training loss: [1.7593070905918466]
# Training loss EPOCH: [833|1000], training loss: [1.8262955751879417]
# Training loss EPOCH: [834|1000], training loss: [1.8228047242978391]
# Training loss EPOCH: [835|1000], training loss: [2.045728764041087]
# Training loss EPOCH: [836|1000], training loss: [1.868487288963479]
# Training loss EPOCH: [837|1000], training loss: [2.0489331082762874]
# Training loss EPOCH: [838|1000], training loss: [1.8460323934459666]
# Training loss EPOCH: [839|1000], training loss: [1.8732873266917522]
# Training loss EPOCH: [840|1000], training loss: [1.754545501967641]
# Training loss EPOCH: [841|1000], training loss: [1.891658390939483]
# Training loss EPOCH: [842|1000], training loss: [1.9558950933246706]
# Training loss EPOCH: [843|1000], training loss: [2.1484266483894316]
# Training loss EPOCH: [844|1000], training loss: [1.941902192769703]
# Training loss EPOCH: [845|1000], training loss: [1.996555065418761]
# Training loss EPOCH: [846|1000], training loss: [1.945073895150017]
# Training loss EPOCH: [847|1000], training loss: [1.9049537044907083]
# Training loss EPOCH: [848|1000], training loss: [1.8458325740534747]
# Training loss EPOCH: [849|1000], training loss: [1.7673550751951552]
# Training loss EPOCH: [850|1000], training loss: [1.8640445874157194]
# Training loss EPOCH: [851|1000], training loss: [1.8207729039322658]
# Training loss EPOCH: [852|1000], training loss: [1.8103783581632342]
# Training loss EPOCH: [853|1000], training loss: [1.875340321116255]
# Training loss EPOCH: [854|1000], training loss: [2.0254797466741365]
# Training loss EPOCH: [855|1000], training loss: [1.9773305705257371]
# Training loss EPOCH: [856|1000], training loss: [2.1040569635210886]
# Training loss EPOCH: [857|1000], training loss: [1.9852048453603857]
# Training loss EPOCH: [858|1000], training loss: [1.8490112333784054]
# Training loss EPOCH: [859|1000], training loss: [1.754232866861912]
# Training loss EPOCH: [860|1000], training loss: [2.0147270710053817]
# Training loss EPOCH: [861|1000], training loss: [1.932865248741109]
# Training loss EPOCH: [862|1000], training loss: [1.7958108066286513]
# Training loss EPOCH: [863|1000], training loss: [1.8829477971812594]
# Training loss EPOCH: [864|1000], training loss: [1.7382710619103818]
# Training loss EPOCH: [865|1000], training loss: [2.1223041488583476]
# Training loss EPOCH: [866|1000], training loss: [1.8141410248554166]
# Training loss EPOCH: [867|1000], training loss: [1.8686699036411483]
# Training loss EPOCH: [868|1000], training loss: [1.9341973978139322]
# Training loss EPOCH: [869|1000], training loss: [1.8016823256680254]
# Training loss EPOCH: [870|1000], training loss: [1.8065523404620762]
# Training loss EPOCH: [871|1000], training loss: [2.051566919774359]
# Training loss EPOCH: [872|1000], training loss: [1.9427685318178192]
# Training loss EPOCH: [873|1000], training loss: [1.9397805463750046]
# Training loss EPOCH: [874|1000], training loss: [1.801865483770598]
# Training loss EPOCH: [875|1000], training loss: [1.8190675987120812]
# Training loss EPOCH: [876|1000], training loss: [1.9803571696515974]
# Training loss EPOCH: [877|1000], training loss: [1.9705017487603982]
# Training loss EPOCH: [878|1000], training loss: [1.8837470394182674]
# Training loss EPOCH: [879|1000], training loss: [1.8769679721335706]
# Training loss EPOCH: [880|1000], training loss: [1.7402558296817006]
# Training loss EPOCH: [881|1000], training loss: [1.9005636543915898]
# Training loss EPOCH: [882|1000], training loss: [2.0291475312910734]
# Training loss EPOCH: [883|1000], training loss: [1.8194067151734998]
# Training loss EPOCH: [884|1000], training loss: [1.7638999513565068]
# Training loss EPOCH: [885|1000], training loss: [1.791032291000647]
# Training loss EPOCH: [886|1000], training loss: [1.8076375099535653]
# Training loss EPOCH: [887|1000], training loss: [1.9595044621410125]
# Training loss EPOCH: [888|1000], training loss: [1.9909816259987565]
# Training loss EPOCH: [889|1000], training loss: [1.70663543291721]
# Training loss EPOCH: [890|1000], training loss: [1.8685616266798206]
# Training loss EPOCH: [891|1000], training loss: [1.8898446570924534]
# Training loss EPOCH: [892|1000], training loss: [1.946762633506296]
# Training loss EPOCH: [893|1000], training loss: [1.9296784310067778]
# Training loss EPOCH: [894|1000], training loss: [1.8227729009886389]
# Training loss EPOCH: [895|1000], training loss: [1.926502449324289]
# Training loss EPOCH: [896|1000], training loss: [1.930398985193733]
# Training loss EPOCH: [897|1000], training loss: [1.9692188432782132]
# Training loss EPOCH: [898|1000], training loss: [1.733133648803232]
# Training loss EPOCH: [899|1000], training loss: [1.851960347750719]
# Training loss EPOCH: [900|1000], training loss: [1.900093329912579]
# Training loss EPOCH: [901|1000], training loss: [1.8543691573158867]
# Training loss EPOCH: [902|1000], training loss: [1.9984041783040993]
# Training loss EPOCH: [903|1000], training loss: [1.7915845497736882]
# Training loss EPOCH: [904|1000], training loss: [1.8921632812307507]
# Training loss EPOCH: [905|1000], training loss: [2.086485080955754]
# Training loss EPOCH: [906|1000], training loss: [1.939106906768302]
# Training loss EPOCH: [907|1000], training loss: [1.8269382467128708]
# Training loss EPOCH: [908|1000], training loss: [1.937392078502853]
# Training loss EPOCH: [909|1000], training loss: [2.0236579225638707]
# Training loss EPOCH: [910|1000], training loss: [1.7579179441345332]
# Training loss EPOCH: [911|1000], training loss: [1.9127788173825593]
# Training loss EPOCH: [912|1000], training loss: [1.8601610732407607]
# Training loss EPOCH: [913|1000], training loss: [1.974590869669555]
# Training loss EPOCH: [914|1000], training loss: [1.9163065455086326]
# Training loss EPOCH: [915|1000], training loss: [1.9866233084362648]
# Training loss EPOCH: [916|1000], training loss: [1.907781983062705]
# Training loss EPOCH: [917|1000], training loss: [1.7697245565605044]
# Training loss EPOCH: [918|1000], training loss: [1.799565309123409]
# Training loss EPOCH: [919|1000], training loss: [1.7281437458218534]
# Training loss EPOCH: [920|1000], training loss: [2.0623731015070916]
# Training loss EPOCH: [921|1000], training loss: [1.8925012883046293]
# Training loss EPOCH: [922|1000], training loss: [1.7295155786650867]
# Training loss EPOCH: [923|1000], training loss: [1.8232979179570066]
# Training loss EPOCH: [924|1000], training loss: [2.1060610800218456]
# Training loss EPOCH: [925|1000], training loss: [1.7851166772520628]
# Training loss EPOCH: [926|1000], training loss: [1.8061187193134174]
# Training loss EPOCH: [927|1000], training loss: [1.80299766591952]
# Training loss EPOCH: [928|1000], training loss: [1.840280566347701]
# Training loss EPOCH: [929|1000], training loss: [1.7375089286406364]
# Training loss EPOCH: [930|1000], training loss: [1.8994126909415172]
# Training loss EPOCH: [931|1000], training loss: [1.9857539783720313]
# Training loss EPOCH: [932|1000], training loss: [1.6468795931573368]
# Training loss EPOCH: [933|1000], training loss: [1.823499644862295]
# Training loss EPOCH: [934|1000], training loss: [1.834929594028381]
# Training loss EPOCH: [935|1000], training loss: [1.8445658722171174]
# Training loss EPOCH: [936|1000], training loss: [1.8316941804973794]
# Training loss EPOCH: [937|1000], training loss: [1.9559783190006783]
# Training loss EPOCH: [938|1000], training loss: [1.9439293965970137]
# Training loss EPOCH: [939|1000], training loss: [1.9944133660851548]
# Training loss EPOCH: [940|1000], training loss: [1.7627994591480274]
# Training loss EPOCH: [941|1000], training loss: [1.8632275651161763]
# Training loss EPOCH: [942|1000], training loss: [1.8134736905053614]
# Training loss EPOCH: [943|1000], training loss: [1.7529395475980891]
# Training loss EPOCH: [944|1000], training loss: [1.7603819116529849]
# Training loss EPOCH: [945|1000], training loss: [1.8096877649286398]
# Training loss EPOCH: [946|1000], training loss: [1.6828291722013091]
# Training loss EPOCH: [947|1000], training loss: [1.9916357195306773]
# Training loss EPOCH: [948|1000], training loss: [1.8899453062726934]
# Training loss EPOCH: [949|1000], training loss: [1.7882829857289835]
# Training loss EPOCH: [950|1000], training loss: [2.0286472359284744]
# Training loss EPOCH: [951|1000], training loss: [1.939359143519141]
# Training loss EPOCH: [952|1000], training loss: [1.9632720125891865]
# Training loss EPOCH: [953|1000], training loss: [1.9885707564390032]
# Training loss EPOCH: [954|1000], training loss: [1.8379410332272528]
# Training loss EPOCH: [955|1000], training loss: [1.7993492793461883]
# Training loss EPOCH: [956|1000], training loss: [1.9554115696969347]
# Training loss EPOCH: [957|1000], training loss: [1.8659501090655795]
# Training loss EPOCH: [958|1000], training loss: [1.939679508334848]
# Training loss EPOCH: [959|1000], training loss: [1.990819028250371]
# Training loss EPOCH: [960|1000], training loss: [1.7294744766768417]
# Training loss EPOCH: [961|1000], training loss: [1.9755640024282002]
# Training loss EPOCH: [962|1000], training loss: [1.815320152304139]
# Training loss EPOCH: [963|1000], training loss: [1.7768248042093546]
# Training loss EPOCH: [964|1000], training loss: [1.9291073169983974]
# Training loss EPOCH: [965|1000], training loss: [1.9033811140998296]
# Training loss EPOCH: [966|1000], training loss: [1.836245281909214]
# Training loss EPOCH: [967|1000], training loss: [1.79463246642581]
# Training loss EPOCH: [968|1000], training loss: [2.076902874378902]
# Training loss EPOCH: [969|1000], training loss: [2.055002962355502]
# Training loss EPOCH: [970|1000], training loss: [1.8655755955319364]
# Training loss EPOCH: [971|1000], training loss: [1.8810633256712208]
# Training loss EPOCH: [972|1000], training loss: [1.8059235777832328]
# Training loss EPOCH: [973|1000], training loss: [1.8197870100989348]
# Training loss EPOCH: [974|1000], training loss: [1.8513203429015448]
# Training loss EPOCH: [975|1000], training loss: [1.7470310422390867]
# Training loss EPOCH: [976|1000], training loss: [1.8643864794885303]
# Training loss EPOCH: [977|1000], training loss: [1.8451107685427814]
# Training loss EPOCH: [978|1000], training loss: [2.0366886058191085]
# Training loss EPOCH: [979|1000], training loss: [1.882610675358137]
# Training loss EPOCH: [980|1000], training loss: [1.6809827073861925]
# Training loss EPOCH: [981|1000], training loss: [1.7774590655380962]
# Training loss EPOCH: [982|1000], training loss: [1.9815049282319706]
# Training loss EPOCH: [983|1000], training loss: [1.8109299796537925]
# Training loss EPOCH: [984|1000], training loss: [1.8242991964361863]
# Training loss EPOCH: [985|1000], training loss: [1.6886802522217295]
# Training loss EPOCH: [986|1000], training loss: [1.7868178779554]
# Training loss EPOCH: [987|1000], training loss: [1.9765092922284566]
# Training loss EPOCH: [988|1000], training loss: [1.8816203881160618]
# Training loss EPOCH: [989|1000], training loss: [1.979689211832465]
# Training loss EPOCH: [990|1000], training loss: [1.8936066733563166]
# Training loss EPOCH: [991|1000], training loss: [1.7939412341747811]
# Training loss EPOCH: [992|1000], training loss: [1.9197989741151105]
# Training loss EPOCH: [993|1000], training loss: [1.9177549134656147]
# Training loss EPOCH: [994|1000], training loss: [1.7930128828938905]
# Training loss EPOCH: [995|1000], training loss: [2.018096187604897]
# Training loss EPOCH: [996|1000], training loss: [1.775141229230485]
# Training loss EPOCH: [997|1000], training loss: [1.7758355782198123]
# Training loss EPOCH: [998|1000], training loss: [1.7243561656900965]
# Training loss EPOCH: [999|1000], training loss: [1.7992020460383173]
# Training loss EPOCH: [1000|1000], training loss: [1.9059841430125743]

# %%
with open("result/model_VANLSTMAE_saliency_res_SMD1-2.pt", "rb") as f:
    SAVED_MODEL = torch.load(f)

print(SAVED_MODEL['best_epoch'])

MODEL_res = RecurrentAutoencoder(seq_len=window_size, n_features=x_train.shape[1]*2, out_n_features=x_train.shape[1], embedding_dim=int(x_train.shape[1]/2))
MODEL_res.cuda()
MODEL_res.load_state_dict(SAVED_MODEL["state"])
MODEL_res
# Out:
# 998
# RecurrentAutoencoder(
#   (encoder): RecurEncoder(
#     (rnn1): LSTM(76, 38, batch_first=True)
#     (rnn2): LSTM(38, 19, batch_first=True)
#   )
#   (decoder): RecurDecoder(
#     (rnn1): LSTM(19, 19, batch_first=True)
#     (rnn2): LSTM(19, 38, batch_first=True)
#     (output_layer): Linear(in_features=38, out_features=76, bias=True)
#     (timedist): TimeDistributed(
#       (module): Linear(in_features=38, out_features=76, bias=True)
#     )
#   )
# )

# %%
def inference_concat(dataloader, res_dataloader, model, batch_size):
    ts, dist, att, guess_res, enc_list = [], [], [], [], []
    mse = torch.nn.MSELoss()
    with torch.no_grad():
        for i, ((x,y),(res_x,res_y)) in enumerate(zip(dataloader, res_dataloader)):
            x = x.cuda()
            res_x = res_x.cuda()
            x_res = torch.cat([x, res_x], dim=2)
            y = y.cuda()
            res_y = res_y.cuda()
            y_res = torch.cat([y, res_y], dim=2)
            enc, guess = model(x_res)
            # ts.append(np.array(batch["ts"]))
            
            for y_s, g in zip(y_res, guess):
                dist.append(torch.sum(torch.abs(y_s - g)).cpu().numpy())  # Normal GRU

            guess_res.append(guess.cpu().numpy())
            enc_list.append(enc.cpu().numpy())
        
            
    return (
        # np.concatenate(ts),
        # np.concatenate(dist),
        dist,
        np.concatenate(guess_res),
        np.concatenate(enc_list)
    )

# %%
MODEL.eval()
CHECK_DIST, GUESS_RES, ENC = inference_concat(test_loader, res_test_loader, MODEL_res, batch_size)
CHECK_DIST_FT, GUESS_RES_FT, ENC_FT = inference_concat(train_loader, res_train_loader, MODEL_res, batch_size)

# %%
len(y_test)
# Out:
# 23694

# %%
pot_th = pot_eval(CHECK_DIST_FT, CHECK_DIST, label=y_test[:len(y_test)-200], q=1e-2, level=0.99, dynamic=False)
pot_th
# Out:
# Running POT with q=0.01, level=0.99..
# Initial threshold : 220.43707
# Number of peaks : 234
# Grimshaw maximum log-likelihood estimation ... [done]
# 	γ = 0
# 	σ = 17.196493
# 	L = 899.66108146221
# Extreme quantile (probability = 0.01): 220.36813120398338
# 100%|██████████| 23494/23494 [00:00<00:00, 1161245.59it/s]
# 0
# 23494
# {'f1': 0.27534882638157626,
#  'precision': 0.15979839857753217,
#  'recall': 0.9944649263013852,
#  'TP': 539.0,
#  'TN': 20118.0,
#  'FP': 2834.0,
#  'FN': 3.0,
#  'threshold': 220.36813120398344,
#  'latency': 0.0}

# %%
from torch.autograd import Variable
# x = torch.randn(1, 1, 100)
reshape_len = len(ENC)
x = torch.Tensor(np.array(ENC).reshape(ENC.shape[0],ENC.shape[2],ENC.shape[1])) 
k_size = 100
mean_conv = torch.nn.Conv1d(in_channels=19,
                      out_channels=19,
                      kernel_size=k_size)

# Set kernel to calculate mean
kernel_weights = np.ones((k_size, 19))/k_size
mean_conv.weight.data = torch.FloatTensor(kernel_weights).view(1, 19, k_size)
output = mean_conv(Variable(x))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_18609/2591458265.py in <module>
#      11 kernel_weights = np.ones((k_size, 19))/k_size
#      12 mean_conv.weight.data = torch.FloatTensor(kernel_weights).view(1, 19, k_size)
# ---> 13 output = mean_conv(Variable(x))
#
# ~/anaconda3/envs/saliency/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/saliency/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     261
#     262     def forward(self, input: Tensor) -> Tensor:
# --> 263         return self._conv_forward(input, self.weight, self.bias)
#     264
#     265
#
# ~/anaconda3/envs/saliency/lib/python3.7/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     258                             _single(0), self.dilation, self.groups)
#     259         return F.conv1d(input, weight, bias, self.stride,
# --> 260                         self.padding, self.dilation, self.groups)
#     261
#     262     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: Given weight of size [1, 19, 100], expected bias to be 1-dimensional with 1 elements, but got bias of size [19] instead

# %%
plt.figure(figsize=(20,12))
x_np = x.numpy().reshape(reshape_len)
plt.plot(x_np[k_size-1:], label='Input')
output_np = output.detach().numpy().reshape(reshape_len - k_size + 1)
plt.plot(output_np, label='Average filter')
plt.plot(abs(x_np[k_size-1:] - output_np), label='Residuals')
plt.legend()

# %%
# MODEL2 = torch.nn.Transformer(d_model=x_train.shape[1], nhead=int(x_train.shape[1]/2), num_encoder_layers=6)
MODEL2 = torch.nn.TransformerAE(d_model=x_train.shape[1], nhead=int(x_train.shape[1]/2), num_encoder_layers=6)
MODEL2.cuda()
# Out:
# TransformerAE(
#   (encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#   )
#   (decoder): TransformerDecoder(
#     (layers): ModuleList(
#       (0): TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#       (2): TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#       (3): TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#       (4): TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#       (5): TransformerDecoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (multihead_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=38, out_features=38, bias=True)
#         )
#         (linear1): Linear(in_features=38, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=38, bias=True)
#         (norm1): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (norm3): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#         (dropout3): Dropout(p=0.1, inplace=False)
#       )
#     )
#     (norm): LayerNorm((38,), eps=1e-05, elementwise_affine=True)
#   )
# )

# %%
def train_transformer(dataloader, model, batch_size, n_epochs):
    # dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    optimizer = torch.optim.AdamW(model.parameters())
    loss_fn = torch.nn.MSELoss()
    epochs = range(n_epochs)
    best = {"loss": sys.float_info.max}
    loss_history = []
    for e in epochs:
        epoch_loss = 0
        for i, (x,y) in enumerate(dataloader):  
            optimizer.zero_grad()
            x = x.cuda()
            enc_output, guess = model(x,x)  # Transformer
            y = y.cuda()
            loss = loss_fn(y, guess)
            loss.backward()
            epoch_loss += loss.item()
            optimizer.step()
        loss_history.append(epoch_loss)
#         epochs.set_postfix_str(f"loss: {epoch_loss:.6f}")
        
        print(f'Training loss EPOCH: [{e+1}|{len(epochs)}], training loss: [{epoch_loss}]')
        if epoch_loss < best["loss"]:
            best["state"] = model.state_dict()
            best["loss"] = epoch_loss
            best["epoch"] = e + 1
    return best, loss_history

# %%
BEST_MODEL2, LOSS_HISTORY2 = train_transformer(train_loader, MODEL2, batch_size, 1000)
with open("result/model_transformerAE_saliency.pt", "wb") as f:
    torch.save(
        {
            "state": BEST_MODEL2["state"],
            "best_epoch": BEST_MODEL2["epoch"],
            "loss_history": LOSS_HISTORY2,
        },
        f,
    )
# Out:
# Training loss EPOCH: [1|1000], training loss: [79.69933512806892]
# Training loss EPOCH: [2|1000], training loss: [32.63320318609476]
# Training loss EPOCH: [3|1000], training loss: [8.479595061391592]
# Training loss EPOCH: [4|1000], training loss: [2.684080082923174]
# Training loss EPOCH: [5|1000], training loss: [1.7842128300108016]
# Training loss EPOCH: [6|1000], training loss: [1.7028404148295522]
# Training loss EPOCH: [7|1000], training loss: [1.6957667423412204]
# Training loss EPOCH: [8|1000], training loss: [1.6935093654319644]
# Training loss EPOCH: [9|1000], training loss: [1.692588483914733]
# Training loss EPOCH: [10|1000], training loss: [1.6864340733736753]
# Training loss EPOCH: [11|1000], training loss: [1.6859813164919615]
# Training loss EPOCH: [12|1000], training loss: [1.6856106729246676]
# Training loss EPOCH: [13|1000], training loss: [1.6818020781502128]
# Training loss EPOCH: [14|1000], training loss: [1.6826780391857028]
# Training loss EPOCH: [15|1000], training loss: [1.6863424303010106]
# Training loss EPOCH: [16|1000], training loss: [1.6856651809066534]
# Training loss EPOCH: [17|1000], training loss: [1.6828803000971675]
# Training loss EPOCH: [18|1000], training loss: [1.68458042293787]
# Training loss EPOCH: [19|1000], training loss: [1.6872541159391403]
# Training loss EPOCH: [20|1000], training loss: [1.684028861578554]
# Training loss EPOCH: [21|1000], training loss: [1.6875389497727156]
# Training loss EPOCH: [22|1000], training loss: [1.6824989272281528]
# Training loss EPOCH: [23|1000], training loss: [1.6817891197279096]
# Training loss EPOCH: [24|1000], training loss: [1.6860527405515313]
# Training loss EPOCH: [25|1000], training loss: [1.6859823972918093]
# Training loss EPOCH: [26|1000], training loss: [1.6793472706340253]
# Training loss EPOCH: [27|1000], training loss: [1.6835835250094533]
# Training loss EPOCH: [28|1000], training loss: [1.6813123244792223]
# Training loss EPOCH: [29|1000], training loss: [1.6796693494543433]
# Training loss EPOCH: [30|1000], training loss: [1.67895732447505]
# Training loss EPOCH: [31|1000], training loss: [1.6786596961319447]
# Training loss EPOCH: [32|1000], training loss: [1.6809618389233947]
# Training loss EPOCH: [33|1000], training loss: [1.6763256341218948]
# Training loss EPOCH: [34|1000], training loss: [1.6749432533979416]
# Training loss EPOCH: [35|1000], training loss: [1.680027193389833]
# Training loss EPOCH: [36|1000], training loss: [1.6769936229102314]
# Training loss EPOCH: [37|1000], training loss: [1.6785343931987882]
# Training loss EPOCH: [38|1000], training loss: [1.6740759876556695]
# Training loss EPOCH: [39|1000], training loss: [1.680026637390256]
# Training loss EPOCH: [40|1000], training loss: [1.6763573754578829]
# Training loss EPOCH: [41|1000], training loss: [1.6770711964927614]
# Training loss EPOCH: [42|1000], training loss: [1.6763384556397796]
# Training loss EPOCH: [43|1000], training loss: [1.6742122890427709]
# Training loss EPOCH: [44|1000], training loss: [1.6761599956080317]
# Training loss EPOCH: [45|1000], training loss: [1.6808528332039714]
# Training loss EPOCH: [46|1000], training loss: [1.6746483813039958]
# Training loss EPOCH: [47|1000], training loss: [1.6806539678946137]
# Training loss EPOCH: [48|1000], training loss: [1.679487206041813]
# Training loss EPOCH: [49|1000], training loss: [1.6770120523869991]
# Training loss EPOCH: [50|1000], training loss: [1.6785933240316808]
# Training loss EPOCH: [51|1000], training loss: [1.6761758606880903]

# %%
with open("result/model_transformerAE_saliency.pt", "rb") as f:
    SAVED_MODEL = torch.load(f)

print(SAVED_MODEL['best_epoch'])

MODEL2 = torch.nn.Transformer(d_model=x_train.shape[1], nhead=int(x_train.shape[1]/2), num_encoder_layers=6)
MODEL2.cuda()
MODEL2.load_state_dict(SAVED_MODEL["state"])
# Out:
# 749
# <All keys matched successfully>

# %%
MODEL2.eval()
CHECK_DIST, GUESS_RES, ENC = inference(test_loader, MODEL2, batch_size)
CHECK_DIST_FT, GUESS_RES_FT, ENC_FT = inference(train_loader, MODEL2, batch_size)

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(16, 4))
plt.title("Training Loss Graph")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.yscale("log")
plt.plot(SAVED_MODEL["loss_history"])
plt.show()

# %%
def inference_transformer(dataloader, model, batch_size):
    # dataloader = DataLoader(dataset, batch_size=batch_size)
    ts, dist, att, enc_val_res, guess_res = [], [], [], [], []
    mse = torch.nn.MSELoss()
    with torch.no_grad():
        for i, (x,y) in enumerate(dataloader):
            x = x.cuda()
            y = y.cuda()
            # guess = model(given, given)
            enc_val, guess = model(x,x)
            
            # ts.append(np.array(batch["ts"]))
            for j, (guess, y_s) in enumerate(zip(x,y)):
                dist.append(torch.abs(y_s - guess).cpu().numpy())
            # dist.append(np.asscalar(torch.sum(torch.abs(y - guess)).cpu().numpy()))
            # dist.append(torch.abs(answer - guess).cpu().numpy())  # Normal GRU

            # for i, (ans, gue) in enumerate(zip(answer, guess)):
            #     dist.append(mse(ans, gue).item())  # Transformer / AE structure
            enc_val_res.append(enc_val.cpu().numpy())
            guess_res.append(guess.cpu().numpy())
            # try:
            #     att.append(np.array(batch["attack"]))
            # except:
            #     att.append(np.zeros(batch_size))
        
            
    return (
        # np.concatenate(ts),
        np.concatenate(dist),
        # np.concatenate(att),
        np.concatenate(enc_val_res),
        np.concatenate(guess_res)
    )

# %%
MODEL2.eval()

CHECK_TS, CHECK_DIST, CHECK_ATT, ENC_LIST_TRANS, GUESS_RES = inference_transformer(test_loader, MODEL2, batch_size)
CHECK_TS_TRAIN, CHECK_DIST_TRAIN, CHECK_ATT_TRAIN, ENC_LIST_TRANS_TRAIN, GUESS_RES_TRAIN = inference_transformer(test_loader, MODEL2, batch_size)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_918/1922628635.py in <module>
#       1 MODEL2.eval()
#       2
# ----> 3 CHECK_TS, CHECK_DIST, CHECK_ATT, ENC_LIST_TRANS, GUESS_RES = inference_transformer(test_loader, MODEL2, batch_size)
#       4 CHECK_TS_TRAIN, CHECK_DIST_TRAIN, CHECK_ATT_TRAIN, ENC_LIST_TRANS_TRAIN, GUESS_RES_TRAIN = inference_transformer(test_loader, MODEL2, batch_size)
#
# ValueError: not enough values to unpack (expected 5, got 3)
